# %%
# Python 2/3 compatibility
try:
    from urllib.parse import unquote_plus
except ImportError:
    from urllib import unquote_plus
import time, re, requests
from bs4 import BeautifulSoup

class Scraper:

    def __init__(self):
        self.base_url = 'http://www.fanfiction.net/'
        self.rate_limit = 1
        self.parser = "html.parser"

    def get_genres(self, genre_text):
        genres = genre_text.split('/')
        # Hurt/Comfort is annoying because of the '/'
        corrected_genres = []
        for genre in genres:
            if genre == 'Hurt':
                corrected_genres.append('Hurt/Comfort')
            elif genre == 'Comfort':
                continue
            else:
                corrected_genres.append(genre)
        return corrected_genres

    def scrape_story_metadata(self, story_id):
        """
        Returns a dictionary with the metadata for the story.

        Attributes:
            -id: the id of the story
            -canon_type: the type of canon
            -canon: the name of the canon
            -author_id: the user id of the author
            -title: the title of the story
            -updated: the timestamp of the last time the story was updated
            -published: the timestamp of when the story was originally published
            -lang: the language the story is written in
            -genres: a list of the genres that the author categorized the story as
            -num_reviews
            -num_favs
            -num_follows
            -num_words: total number of words in all chapters of the story
            -rated: the story's rating.
        """
        url = '{0}/s/{1}'.format(self.base_url, story_id)
        result = requests.get(url)
        html = result.content
        soup = BeautifulSoup(html, self.parser)
        soup.prettify()
        print(soup)

        if soup.find(id='pre_story_links'):
            pre_story_links = soup.find(id='pre_story_links').find_all('a')
        else:
            pre_story_links = None
        author_id = int(re.search(r"var userid = (.*);", str(soup)).groups()[0]);
        title = re.search(r"var title = (.*);", str(soup)).groups()[0];
        title = unquote_plus(title)[1:-1]
        metadata_div = soup.find(id='profile_top')
        times = metadata_div.find_all(attrs={'data-xutime':True})
        metadata_text = metadata_div.find(class_='xgray xcontrast_txt').text
        metadata_parts = metadata_text.split('-')
        genres = self.get_genres(metadata_parts[2].strip())
        metadata = {
            'id': story_id,
            'canon_type': pre_story_links[0].text,
            'canon': pre_story_links[1].text,
            'author_id': author_id,
            'title': title,
            'updated': int(times[0]['data-xutime']),
            'published': int(times[1]['data-xutime']),
            'lang': metadata_parts[1].strip(),
            'genres': genres
        }
        for parts in metadata_parts:
            parts = parts.strip()
            tag_and_val = parts.split(':')
            if len(tag_and_val) != 2:
                continue
            tag, val = tag_and_val
            tag = tag.strip().lower()
            if tag not in metadata:
                val = val.strip()
                try:
                    val = int(val.replace(',', ''))
                    metadata['num_'+tag] = val
                except:
                    metadata[tag] = val
        if 'status' not in metadata:
            metadata['status'] = 'Incomplete'
        return metadata

    def scrape_story(self, story_id, keep_html=False):
        metadata = self.scrape_story_metadata(story_id)
        metadata['chapters'] = {}
        metadata['reviews'] = {}
        num_chapters = metadata['num_chapters']
        # rate limit to follow fanfiction.net TOS
        time.sleep(self.rate_limit)
        for chapter_id in range(1, num_chapters + 1):
            time.sleep(self.rate_limit)
            chapter = self.scrape_chapter(story_id, chapter_id)
            time.sleep(self.rate_limit)
            chapter_reviews = self.scrape_reviews_for_chapter(
                story_id, chapter_id)
            metadata['chapters'][chapter_id] = chapter
            metadata['reviews'][chapter_id] = chapter_reviews
        return metadata

    def scrape_chapter(self, story_id, chapter_id, keep_html=False):
        url = '{0}/s/{1}/{2}'.format(self.base_url, story_id, chapter_id)
        result = requests.get(url)
        html = result.content
        soup = BeautifulSoup(html, self.parser)
        chapter = soup.find(class_='storytext')
        if not keep_html:
            chapter_text = chapter.get_text(' ').encode('utf8')
        return chapter_text

    def scrape_reviews_for_chapter(self, story_id, chapter_id):
        """
        Scrape reviews for chapter in story.

        Returns:
            Array of review dicts.
            Each review dict contains the user id of the reviewer if it exists,
            the timestamp of the review, and the text of the review.
        """
        url = '{0}/r/{1}/{2}'.format(self.base_url, story_id, chapter_id)
        result = requests.get(url)
        html = result.content
        soup = BeautifulSoup(html, self.parser)
        reviews_table = soup.find(class_='table-striped').tbody
        reviews_tds = reviews_table.find_all('td')
        reviews = []
        for review_td in reviews_tds:
            match = re.search(r'href="/u/(.*)/.*">.*</a>', str(review_td))
            if match is not None:
                user_id = int(match.groups()[0])
            else:
                user_id = None
            time = review_td.find('span', attrs={'data-xutime':True})
            time = int(time['data-xutime'])
            review = {
                'time': time,
                'user_id': user_id,
                'text': review_td.div.text.encode('utf8')
            }
            reviews.append(review)
        return reviews

# %%
scraper = Scraper()
metadata = scraper.scrape_story_metadata(13857851)
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><title>Just a moment...</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="noindex,nofollow" name="robots"/><meta content="width=device-width,initial-scale=1" name="viewport"/><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;max-width:60rem;padding-left:1.5rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{font-size:1.5rem;font-weight:500;line-height:2.25rem}@media (width <= 720px){.h2{font-size:1.25rem;line-height:1.5rem}}#challenge-error-text{background-image:url(data:image/svg+xml;base64,...);background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}}</style><meta content="390" http-equiv="refresh"/></head><body class="no-js"><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt={cvId: '3',cZone: "www.fanfiction.net",cType: 'interactive',cNounce: '93117',cRay: '8d4187bb7e0e7c8e',cHash: 'b540b5ee9100678',cH: 'k8QjmoQ.JAPglI5OsKgdIMOGBaix6KxOoKt3FEKzk3Y-1729181126-1.1.1.1-_FWGuC6ZkADd2nSAgHGfF3jvYXnAMscwGBMloXJIndWyF2cNeAUFaFuUYxyisB1A',cUPMDTk: "\/s\/13857851?__cf_chl_tk=qHawPw23_wEfAF.VwISySFO2YjBoRITOiYOUHWHy7xs-1729181126-1.0.1.1-yWrgN2GZ82nXb.iKdAn05iWHQoALpJMEm2KQ2bBPDQI",cFPWv: 'b',cITimeS: '1729181126',cTTimeMs: '1000',cMTimeMs: '390000',cTplV: 5,cTplB: 'cf',cK: "",fa: "\/s\/13857851?__cf_chl_f_tk=qHawPw23_wEfAF.VwISySFO2YjBoRITOiYOUHWHy7xs-1729181126-1.0.1.1-yWrgN2GZ82nXb.iKdAn05iWHQoALpJMEm2KQ2bBPDQI",md: ".aLFD1mVYfpSJ3JSrgxF1Tq2cMxVrMOP_Ye_OKujH9g-1729181126-1.1.1.1-Bl7_edbFT8hu1WWCfFwPfS6ZU5B1y8gT0D21P1.N4MwQk5XngkOxUeHSGHpHaoozQz1LoS8ogz1Jc13oNMd3mBPn5hMixtxVDZW15nX0U46jN5vYelgN9ybLK.IcXoWc9a7PzYXjaWVmRGHfuf1fAyBGLQq3rECTsHkuVEUbYuSfjU.GiUscfWVgAyWDmesVd3xKGzCO2mlPlxugI9iO2PJkqPEemXZz1bIFKWSnWQQA0pavB9nZyY1nm1brdKBn7.IRu_Qvn5dUOi0NbS8_kRqSYIr7JJWP3R3egFaPv9Xd10MSEdSiWoVJW.84hQ.W61b09kI8RlT0VC3rswAlQ3foHy61W0hyMIA8uPbf1uBOJx6MxyUVamzwn3GSgSG22sHlg8MhH4fro8kaWdKDS6eQcehSQohiUB0HbrjuNKnj_YVt9MOs8OmAPX_ADk6scCPD4Lb4hLeoRvI6htcaf9AA_UCpwSNJtDrR33GRZ85EiwVQd4cCA80wKEj7h05.0.ru9gKghBD2lWSACSh1Vbm0ST0FJ.Goun_.sc4EKUxxU.hWqqsR3CS4jZtztCidiq2wxpM5FRLpCIA.XPP.eW9fPgfRcdlk3m.SGZfuIEmMHF85Bov0KS2cSdInz7QiWwEfm66XWIf3KGVoacndkW.T8JE44X.Qp4HGkroswRWmXt.CmGDmm8p6v_g6syq6kaXZmLHCGTe.CQMO0JAdUdIwcquFr7B9_k1PfzZem2jmgoFzDoyTgWwbxLZj5kKRRoy8IbCdZa4Chu1l7iCYCx4zCr5NO_vtMwsir_mNqEvVaap7FdomVs9_TdOT6952izJNz6KjnF0Bg0J1.6cjsnfswzxZPgAL0pL8Xp6uB3UndzRte0n0yia3_QyqsdGCTQmGOMTRHjB6jM.FuR0mga3MM9I0YdPikJ95uigYtAjmbbqyeKv9m8w9v9vUicTteuRo6NoIODicb5RAks4G5BUaoxnolb2HNWN4z6YUGHSh.vlcPkgp2BbJ7b9FpNPwrDxKlrppmFfM19GP0sGFOR0i7KZvgYzOmF13A_o1IC0FmIgFZ...He8A5IhNv.KzT2wNVn5xingAzMfUt67pCfdZhE2rgASzEi2UpM8961lmAZqQalNsRjAwme4O1Br8HkG9zstwyqFCnUTK80SvyQSt5vjWP9IcZbW3gCm7.OHm7vc.d0Y6fyZaZ_z5qiG8Nft5t.236UpNK9EiyK6_PDTUwPK8D2kbRmIloary_v9DTjmof817c.9uA54g0BZB9qBNfyf3oEARIsJo_4bySZoVsTCETmqHBc4q2XDNlOz7JHkDncbLF0KceKAwHt9YjMVjA.vygCxLiSKOBSRFGDiZCqvMBX1F_2nu4iqSGrJl54W89l_CG0g0g.dWRUGTzInFQGek2zQLBmxrAfT3n2X9i7oOqxc9UL3KM8D27IKBO79C3yrydd6TI_pXIUMWQlD5J.pIo5LANEXC5wRaUVcTbE51p_FWRQIlkKWoLhjBqHC9NVmqM.ZjT9SET5oZMSTik2dAP.j.aTr6CzOMUx5Y6g.8Q9xwl6HQbekN1QWHoDzgoprrYVhROdIgJSCrOcGozMJR0dHeStX.DE3YVhnLtdp1I8NtTD8i9N1I90Z5kPds5UUkGl2051jfWA2TrIOhu1XxHrsN3cQ4nMCZYFngQwhymUWs32GMH_.gocIN0GruYGP26.CSiXN.w.Ey",mdrd: "0Dt2_fHwrl3pJ70.rlHqMA2ILiudwJnmNP1MIYLvB9s-1729181126-1.1.1.1-MaQBkbF6H_BxG7XE_FZm5ff1BmIkAVTUZKu0WsBz2O1Rohb66 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 scraper = Scraper()
# ----> 2 metadata = scraper.scrape_story_metadata(13857851)
#
# Cell In[16], line 60, in Scraper.scrape_story_metadata(self, story_id)
#      58 else:
#      59     pre_story_links = None
# ---> 60 author_id = int(re.search(r"var userid = (.*);", str(soup)).groups()[0]);
#      61 title = re.search(r"var title = (.*);", str(soup)).groups()[0];
#      62 title = unquote_plus(title)[1:-1]
#
# AttributeError: 'NoneType' object has no attribute 'groups'
