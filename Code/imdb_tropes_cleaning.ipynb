# %%
import pandas as pd
import re
#!pip install IMDbPY
import imdb

# %%
imdb_link =imdb.IMDb()

# %%
import os

def find_repo_root(start_path):
    """
    useful general function for finding the (first, closest) repo root so github file paths work the same on different machines 
    """
    current_path = os.path.abspath(start_path)
    
    while True:
        # Check for the existence of the .git directory or other indicators
        if os.path.isdir(os.path.join(current_path, '.git')) or \
           os.path.isfile(os.path.join(current_path, 'README.md')):
            return current_path
        
        parent_path = os.path.dirname(current_path)
        
        # Stop if we reach the root directory
        if parent_path == current_path:
            break
        
        current_path = parent_path

    return None  # Return None if not found

root = find_repo_root(os.getcwd())
print(root)
# Out:
# c:\Users\fitsl\Documents\Programming\UVM Programming Classes\PoCS\pocs_project

# %%
# try to download one...

path = f'{root}/Data/international-movies-json/international-movies-json/0a0dd971-0c66-4fd2-8391-d5c460d6d675.json'

df = pd.read_json(path)
print(df.columns)
print(df.shape)
# Out:
# Index(['ImdbId', '_id', 'name', 'poster_url', 'year', 'certificate', 'runtime',
#        'genre', 'ratingValue', 'summary_text', 'ratingCount', 'director',
#        'cast'],
#       dtype='object')
# (250, 13)

# %%
# looks good so download a second...

df_2 = f"{root}/Data/international-movies-json/international-movies-json/0a5dba0c-d6e3-4b79-a699-ccefa442b86d.json"
df_2 = pd.read_json(df_2)
print(df_2.columns)
print(df_2.shape)
df_2.head()
# Out:
# Index(['ImdbId', '_id', 'name', 'poster_url', 'year', 'certificate', 'runtime',
#        'genre', 'ratingValue', 'summary_text', 'ratingCount', 'director',
#        'cast'],
#       dtype='object')
# (250, 13)
#        ImdbId         _id                       name  \
# 0  tt10521318  tt10521318  Music for Getting Married
# 1  tt10521312  tt10521312                    Mi Hijo
# 2  tt10521310  tt10521310             Un Tal Eduardo
# 3  tt10521308  tt10521308   Jonas Kaufmann: My Italy
# 4  tt10521306  tt10521306                    Colmena
#
#                                           poster_url  year certificate  \
# 0  https://m.media-amazon.com/images/S/sash/NapCx...  2018
# 1  https://m.media-amazon.com/images/S/sash/NapCx...  2018
# 2  https://m.media-amazon.com/images/M/MV5BNWE0OW...  2018
# 3  https://m.media-amazon.com/images/M/MV5BOWMwND...  2017
# 4  https://m.media-amazon.com/images/S/sash/NapCx...  2018
#
#   runtime    genre ratingValue summary_text ratingCount  \
# 0               []               Add a Plot
# 1               []               Add a Plot
# 2               []               Add a Plot
# 3  85 min  [Music]               Add a Plot
# 4               []               Add a Plot
#
#                                          director cast
# 0                                             NaN  NaN
# 1                                             NaN  NaN
# 2  {'name': 'Aldo Garay', 'name_id': 'nm1212968'}   []
# 3                                             NaN  NaN
# 4                                             NaN  NaN

# %%
#see if they combine painlessly

df_combo = pd.concat([df, df_2], ignore_index=True)
print(df_combo.columns)
print(df_combo.shape)
# Out:
# Index(['ImdbId', '_id', 'name', 'poster_url', 'year', 'certificate', 'runtime',
#        'genre', 'ratingValue', 'summary_text', 'ratingCount', 'director',
#        'cast'],
#       dtype='object')
# (500, 13)

# %%
## see how many folders we have
print(len([f for f in os.listdir(f'{root}/Data/international-movies-json/international-movies-json')]))
# Out:
# 2535

# %%
# #cool. Now we can get programmatic about it and combine them all... 


# # once you run this, comment it out to save space

# i=0
# df_combo = pd.DataFrame()
# for filename in os.listdir(f"{root}/Data/international-movies-json/international-movies-json"):
#     i += 1
#     print(f"processing {i} :  {filename}")
#     df_combo = pd.concat(
#         [
#             df_combo, pd.read_json(f"{root}/Data/international-movies-json/international-movies-json/{filename}")
#             ], 
#          ignore_index=True)

# %%
print(df_combo.shape)
print(df_combo.columns)
# Out:
# (500, 13)
# Index(['ImdbId', '_id', 'name', 'poster_url', 'year', 'certificate', 'runtime',
#        'genre', 'ratingValue', 'summary_text', 'ratingCount', 'director',
#        'cast'],
#       dtype='object')

# %%
## this dataframe at least initially looks pretty good so we save it as a csv for later. 
# Note that we add this to gitignore because it's too large to push back and forth. so you'll have to make it yourself by running all this code


# df_combo.to_csv(f"{root}/Data/IMBD_Dataframe.csv", index=False )

# %%
imdb_df = pd.read_csv(f"{root}/Data/IMBD_Dataframe.csv")
imdb_df.columns
# Out:
# Index(['ImdbId', '_id', 'name', 'poster_url', 'year', 'certificate', 'runtime',
#        'genre', 'ratingValue', 'summary_text', 'ratingCount', 'director',
#        'cast'],
#       dtype='object')

# %%
imdb_df[imdb_df['name'].str.contains("Better Off").astype("bool")]
# Out:
#             ImdbId         _id                name  \
# 8050     tt0158963   tt0158963   A Site Better Off
# 61038    tt4799172   tt4799172          Better Off
# 185193  tt11575508  tt11575508     Better Off Dead
# 325100   tt2081374   tt2081374   Better Off Single
# 458687   tt5774076   tt5774076                 NaN
# 507092   tt7248518   tt7248518      Better Off Zed
# 520102   tt0088794   tt0088794  Better Off Dead...
# 576582   tt0106398   tt0106398     Better Off Dead
#
#                                                poster_url           year  \
# 8050    https://m.media-amazon.com/images/S/sash/NapCx...  1989 TV Movie
# 61038   https://m.media-amazon.com/images/M/MV5BNzhjN2...  2015 TV Movie
# 185193  https://m.media-amazon.com/images/S/sash/NapCx...           2021
# 325100  https://m.media-amazon.com/images/M/MV5BMjMwNT...           2016
# 458687  https://m.media-amazon.com/images/M/MV5BNDExZT...           2015
# 507092  https://m.media-amazon.com/images/M/MV5BYmE5Yj...           2018
# 520102  https://m.media-amazon.com/images/M/MV5BMzRmMj...           1985
# 576582  https://m.media-amazon.com/images/M/MV5BMDZkOT...  1993 TV Movie
#
#        certificate  runtime                             genre  ratingValue  \
# 8050           NaN      NaN                   ['Documentary']          NaN
# 61038          NaN   22 min                        ['Comedy']          NaN
# 185193         NaN   50 min                        ['Horror']          NaN
# 325100   Not Rated   85 min                        ['Comedy']          4.3
# 458687         NaN      NaN  ['Action', ' Drama', ' Mystery']          NaN
# 507092       TV-MA   88 min   ['Comedy', ' Drama', ' Horror']          4.4
# 520102          PG   97 min            ['Comedy', ' Romance']          7.1
# 576582         NaN  120 min                         ['Drama']          6.5
#
#                                              summary_text ratingCount  \
# 8050                                           Add a Plot         NaN
# 61038   After 20 years of marriage, Blanton and Celest...         NaN
# 185193                                         Add a Plot         NaN
# 325100  "Better Off Single" is the NYC dating comedy t...         728
# 458687  Two boys throw a party while their parents are...         NaN
# 507092  What if the apocalypse came... and you were ha...         215
# 520102  After his girlfriend ditches him for a boorish...      41,870
# 576582  A lawyer fights a losing battle against the co...          95
#
#                                                  director  \
# 8050    {'name': 'Martin Denning', 'name_id': 'nm02193...
# 61038   {'name': 'Peter Hyoguchi', 'name_id': 'nm04052...
# 185193  {'name': 'Lakota Hawkins', 'name_id': 'nm10940...
# 325100   {'name': 'Benjamin Cox', 'name_id': 'nm1639704'}
# 458687   {'name': 'G.M. Whiting', 'name_id': 'nm6825011'}
# 507092  {'name': 'Travis Stevens', 'name_id': 'nm21176...
# 520102  {'name': 'Savage Steve Holland', 'name_id': 'n...
# 576582  {'name': 'Neema Barnette', 'name_id': 'nm00560...
#
#                                                      cast
# 8050                                                   []
# 61038   [{'name': 'Tiffany Abney', 'name_id': 'nm45892...
# 185193  [{'name': 'Lakota Hawkins', 'name_id': 'nm1094...
# 325100  [{'name': 'Aaron Tveit', 'name_id': 'nm3117836...
# 458687  [{'name': 'Israel Adam', 'name_id': 'nm6833864...
# 507092  [{'name': 'Christine Woods', 'name_id': 'nm214...
# 520102  [{'name': 'John Cusack', 'name_id': 'nm0000131...
# 576582  [{'name': 'Mare Winningham', 'name_id': 'nm000...

# %%
df_tropes = pd.read_csv(f"{root}/Data/movies-vs-tropes.csv", sep=';')
df_tropes.shape
# Out:
# (14560, 2)

# %%
imdb_df.shape
# Out:
# (633719, 13)

# %%
df_tropes['Movie'] = df_tropes['Movie'].map(lambda text :  re.sub(r'(?<!^)(?=[A-Z])', ' ', text)) ## puts a space before any capital letter 
df_tropes['Movie'] = df_tropes['Movie'].map(lambda text : re.sub(r'(?<!\d)(19[0-9]{2}|20[0-1][0-9]|202[0-4])(?!\d)', r' \1', text)) #puts a space between any four year sequence (used to tell apart sequels)
df_tropes.head(30)
# Out:
#                                          Movie  \
# 0                             Puerta De Hierro
# 1                           Better Off Dead...
# 2                                        A War
# 3                    Team America World Police
# 4                     The Hills Have Eyes 2006
# 5                        The Face Of Fu Manchu
# 6                        The Trip To Bountiful
# 7                                       Frantz
# 8                             Bad Company 2002
# 9                               The Last Stand
# 10                                Gosford Park
# 11                    The Dawns Here Are Quiet
# 12                 The Best Years Of Our Lives
# 13                                    Biutiful
# 14                                  Inside Man
# 15                        Clothes Of Deception
# 16                       The Time Machine 1978
# 17  The Immaculate Conception Of Little Dizzle
# 18                              Night On Earth
# 19                          On The Wrong Track
# 20                          Out Of The Furnace
# 21                                   The Purge
# 22                                Night School
# 23                                    Mr Nanny
# 24                                   Nightwish
# 25                              Gods Not Dead2
# 26                         Reform School Girls
# 27                 The Monster Of Phantom Lake
# 28                          Final Destination4
# 29                                        Tart
#
#                                                Tropes
# 0    ArgentineMedia,BlackMagic,ChekhovsGun,Chekhov...
# 1    AbhorrentAdmirer,AcceptableTargets,ActorAllus...
# 2    CallBack,CigaretteOfAnxiety,CouldSayItBut,Dan...
# 3    ADegreeInUseless,AHeroToHisHometown,AbstractS...
# 4    AdaptationDistillation,AdaptationExpansion,Ad...
# 5    ActuallyADoombot,AffablyEvil,ArchEnemy,Awesom...
# 6    BittersweetEnding,EarnYourHappyEnding,ElderAb...
# 7    AllLoveIsUnrequited,AnArmAndALeg,DaydreamSurp...
# 8    BackUpTwin,BackupTwin,CoupDeGrace,EmergencyIm...
# 9    ActionGirl,ArtisticLicenseCars,ArtisticLicens...
# 10   AcceptableCulturalTargets,AllForNothing,Ambig...
# 11   AbsenceMakesTheHeartGoYonder,AllMyFriendsAreD...
# 12   AbilityOverAppearance,AnArmAndALeg,ArtificIal...
# 13   AbusiveParents,AdultFear,AwardBait,Bitterswee...
# 14   AbsenceOfEvidence,AfricanAmericanMedia,Asshol...
# 15   AsYouKnow,BathtubScene,CatFight,ChekhovsGunma...
# 16   AdaptationExpansion,ArmsDealer,ArtisticLicens...
# 17   BizarreAlienBiology,BookEnds,ChekhovsGun,Corr...
# 18   AccidentalMisnaming,AdultFear,AnthologyFilm,A...
# 19   BoomHeadshot,CallingTheOldManOut,ComingOfAge,...
# 20   AntiHero,BigBad,CorruptHick,DisproportionateR...
# 21   AbortedArc,AdultFear,AdvertisingByAssociation...
# 22   AfricanAmericanMedia,BewareTheNiceOnes,BookDu...
# 23   AmusingInjuries,DoubleStandardViolenceChildOn...
# 24   AndYouWereThere,ChestBurster,Chestburster,Cre...
# 25   AffablyEvil,AlwaysChaoticEvil,AlwaysLawfulEvi...
# 26   AbusiveParents,BigEater,ButtBrand,CannedOrder...
# 27   AssholeVictim,BeatCop,BodyHorror,BotanicalAbo...
# 28   AllThereInTheManual,AssholeVictim,BloodFromTh...
# 29   AnnoyingYoungerSibling,BathTubBonding,Bathtub...

# %%
df_tropes['Movie'].isna().sum()
# Out:
# np.int64(0)

# %%
df_tropes[df_tropes['Movie'].str.match(r'.*\d{4}$')]
# Out:
#                             Movie  \
# 4        The Hills Have Eyes 2006
# 8                Bad Company 2002
# 16          The Time Machine 1978
# 30                      Roma 1972
# 32                     Venom 2018
# ...                           ...
# 14525  The Magnificent Seven 2016
# 14526             The Master 1980
# 14549                Dracula 2000
# 14551                Berserk 1967
# 14554                 Edmond 2019
#
#                                                   Tropes
# 4       AdaptationDistillation,AdaptationExpansion,Ad...
# 8       BackUpTwin,BackupTwin,CoupDeGrace,EmergencyIm...
# 16      AdaptationExpansion,ArmsDealer,ArtisticLicens...
# 30      AnachronicOrder,AsideGlance,AutoErotica,Blood...
# 32      ADHD,AbledInTheAdaptation,AbortedArc,Acclaime...
# ...                                                  ...
# 14525   AFistfulOfRehashes,AGoodWayToDie,AGoodWaytoDi...
# 14526   ActionPrologue,BadassTeacher,BareFistedMonk,B...
# 14549   AdaptationalVillainy,AnnualTitle,ArtisticLice...
# 14551   AlphaBitch,BerserkButton,BloodlessCarnage,Bra...
# 14554   ARoundOfDrinksForTheHouse,AccidentalMisnaming...
#
# [1148 rows x 2 columns]

# %%
def strip_year(text):
    if pd.isna(text):
        print(text)
        return text # Return NaN and None if text is NaN
    
    match = pd.Series(text).str.extract(r'(\s(\d{4}))$')
    if not match.empty:
        return text.replace(str(match[0][0]), '').strip()
    return text


def get_year(text):
    if pd.isna(text):
        return None # Return NaN and None if text is NaN
    
    match = pd.Series(text).str.extract(r'(\s(\d{4}))$')
    if not match.empty:
        return match[1][0]
    return None

df_tropes['Movie_strip'] = df_tropes['Movie'].map(lambda x: strip_year(x))
df_tropes['year'] = df_tropes['Movie'].map(lambda x: get_year(x))

# %%
df_tropes
# Out:
#                            Movie  \
# 0               Puerta De Hierro
# 1             Better Off Dead...
# 2                          A War
# 3      Team America World Police
# 4       The Hills Have Eyes 2006
# ...                          ...
# 14555        Remember The Titans
# 14556                Deep Impact
# 14557               Lost Horizon
# 14558       Kamen Rider The Next
# 14559               Princess Cyd
#
#                                                   Tropes  \
# 0       ArgentineMedia,BlackMagic,ChekhovsGun,Chekhov...
# 1       AbhorrentAdmirer,AcceptableTargets,ActorAllus...
# 2       CallBack,CigaretteOfAnxiety,CouldSayItBut,Dan...
# 3       ADegreeInUseless,AHeroToHisHometown,AbstractS...
# 4       AdaptationDistillation,AdaptationExpansion,Ad...
# ...                                                  ...
# 14555   AfricanAmericanMedia,AmbiguouslyGay,ArmorPier...
# 14556   ActionFilmQuietDramaScene,AltarTheSpeed,Alumi...
# 14557   AcceptableReligiousTargets,AdaptationalJobCha...
# 14558   AdaptationalVillainy,AdaptedOut,AssKickingPos...
# 14559   ADateWithRosiePalms,ADateWithrosiePalms,Armor...
#
#                      Movie_strip  year
# 0               Puerta De Hierro   NaN
# 1             Better Off Dead...   NaN
# 2                          A War   NaN
# 3      Team America World Police   NaN
# 4            The Hills Have Eyes  2006
# ...                          ...   ...
# 14555        Remember The Titans   NaN
# 14556                Deep Impact   NaN
# 14557               Lost Horizon   NaN
# 14558       Kamen Rider The Next   NaN
# 14559               Princess Cyd   NaN
#
# [14560 rows x 4 columns]

# %%
df_tropes['Movie'] = df_tropes['Movie_strip']
df_tropes = df_tropes.rename(columns=
                 {
                     ' Tropes' : "Tropes"
                 })
df_tropes['Movie'] = df_tropes['Movie'].map(lambda text :  re.sub(r'(?<!^)(?=[A-Z])', ' ', text))

# %%
# df_tropes['Movie'] =  df_tropes['Movie'].map(lambda x: re.sub(r'(\d)', r' \1', x, count=1))
# df_tropes['Movie'] = df_tropes['Movie'].map(lambda x : x.strip().lower())
# imdb_df['Movie'] = imdb_df['Movie'].map(lambda x : str(x)).map(lambda s: re.sub(r'[^\w\s]', '', s))
# imdb_df['Movie'] = imdb_df['Movie'].map(lambda x : x.strip().lower()).map(lambda s: re.sub(r'[^\w\s]', '', s))

# %%
imdb_link.search_movie("venom")
# Out:
# [<Movie id:16366836[http] title:_Venom: The Last Dance (2024)_>,
#  <Movie id:1270797[http] title:_Venom (2018)_>,
#  <Movie id:7097896[http] title:_Venom: Let There Be Carnage (2021)_>,
#  <Movie id:0428251[http] title:_Venom (2005)_>,
#  <Movie id:0084854[http] title:_Venom (1981)_>,
#  <Movie id:6254596[http] title:_"Venom" (None)_>,
#  <Movie id:0125764[http] title:_Venom (1966)_>,
#  <Movie id:0067934[http] title:_The Legend of Spider Forest (1971)_>,
#  <Movie id:1931601[http] title:_Venom (2011)_>,
#  <Movie id:0417148[http] title:_Snakes on a Plane (2006)_>,
#  <Movie id:7412114[http] title:_Red Venom Kills (2017)_>,
#  <Movie id:5019312[http] title:_Venom (2015)_>,
#  <Movie id:16911700[http] title:_Medusa's Venom (2023) (V)_>,
#  <Movie id:14153900[http] title:_Venom Coast (2021)_>,
#  <Movie id:1241018[http] title:_Silent Venom (2009) (V)_>,
#  <Movie id:0416287[http] title:_Venom (2004)_>,
#  <Movie id:3083812[http] title:_Venom: Truth in Journalism (2013)_>,
#  <Movie id:10755644[http] title:_Lego Marvel Spider-Man: Vexed by Venom (2019) (TV)_>,
#  <Movie id:0207801[http] title:_Venom and Eternity (1951)_>,
#  <Movie id:13154232[http] title:_Spider-Man: The Venom Saga (2005) (V)_>]

# %%
imdb_link =imdb.IMDb()

def search_movie(link, title, year=None):
    if pd.isna(year):
        year = None
    else:
        year = str(year)
        # print(year)
    
    # Search for movies with the given title
    results = link.search_movie(title)

    if not results:  # Check if there are any results
        print("No results found for:", title)
        return None
    
    # Filter results by year
    if year:
        for movie in results:
            # print(movie)
            if movie.get('year') == year:
                return movie.movieID # Return the movie data if found
    return results[0].movieID

# %%
result = search_movie(imdb_link, 'venom')

# %%
df_tropes
# Out:
#                               Movie  \
# 0                Puerta  De  Hierro
# 1              Better  Off  Dead...
# 2                            A  War
# 3      Team  America  World  Police
# 4            The  Hills  Have  Eyes
# ...                             ...
# 14555         Remember  The  Titans
# 14556                  Deep  Impact
# 14557                 Lost  Horizon
# 14558       Kamen  Rider  The  Next
# 14559                 Princess  Cyd
#
#                                                   Tropes  \
# 0       ArgentineMedia,BlackMagic,ChekhovsGun,Chekhov...
# 1       AbhorrentAdmirer,AcceptableTargets,ActorAllus...
# 2       CallBack,CigaretteOfAnxiety,CouldSayItBut,Dan...
# 3       ADegreeInUseless,AHeroToHisHometown,AbstractS...
# 4       AdaptationDistillation,AdaptationExpansion,Ad...
# ...                                                  ...
# 14555   AfricanAmericanMedia,AmbiguouslyGay,ArmorPier...
# 14556   ActionFilmQuietDramaScene,AltarTheSpeed,Alumi...
# 14557   AcceptableReligiousTargets,AdaptationalJobCha...
# 14558   AdaptationalVillainy,AdaptedOut,AssKickingPos...
# 14559   ADateWithRosiePalms,ADateWithrosiePalms,Armor...
#
#                      Movie_strip  year
# 0               Puerta De Hierro   NaN
# 1             Better Off Dead...   NaN
# 2                          A War   NaN
# 3      Team America World Police   NaN
# 4            The Hills Have Eyes  2006
# ...                          ...   ...
# 14555        Remember The Titans   NaN
# 14556                Deep Impact   NaN
# 14557               Lost Horizon   NaN
# 14558       Kamen Rider The Next   NaN
# 14559               Princess Cyd   NaN
#
# [14560 rows x 4 columns]

# %%
tropes_small = df_tropes[0:10].copy()
tropes_small.columns = tropes_small.columns.str.strip()
print(tropes_small['year'])
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4    2006
# 5     NaN
# 6     NaN
# 7     NaN
# 8    2002
# 9     NaN
# Name: year, dtype: object

# %%
tropes_small.dtypes
# Out:
# Movie          object
# Tropes         object
# Movie_strip    object
# year           object
# dtype: object

# %%
tropes_small['imdb_id'] = tropes_small.apply(lambda row: search_movie(
    imdb_link, row['Movie_strip'], row['year']) , 
     axis=1)

tropes_small
# Out:
# 2006
# 2002
#                           Movie  \
# 0            Puerta  De  Hierro
# 1          Better  Off  Dead...
# 2                        A  War
# 3  Team  America  World  Police
# 4        The  Hills  Have  Eyes
# 5     The  Face  Of  Fu  Manchu
# 6      The  Trip  To  Bountiful
# 7                        Frantz
# 8                  Bad  Company
# 9              The  Last  Stand
#
#                                               Tropes  \
# 0   ArgentineMedia,BlackMagic,ChekhovsGun,Chekhov...
# 1   AbhorrentAdmirer,AcceptableTargets,ActorAllus...
# 2   CallBack,CigaretteOfAnxiety,CouldSayItBut,Dan...
# 3   ADegreeInUseless,AHeroToHisHometown,AbstractS...
# 4   AdaptationDistillation,AdaptationExpansion,Ad...
# 5   ActuallyADoombot,AffablyEvil,ArchEnemy,Awesom...
# 6   BittersweetEnding,EarnYourHappyEnding,ElderAb...
# 7   AllLoveIsUnrequited,AnArmAndALeg,DaydreamSurp...
# 8   BackUpTwin,BackupTwin,CoupDeGrace,EmergencyIm...
# 9   ActionGirl,ArtisticLicenseCars,ArtisticLicens...
#
#                  Movie_strip  year   imdb_id
# 0           Puerta De Hierro   NaN   2512204
# 1         Better Off Dead...   NaN   0088794
# 2                      A War   NaN  17279496
# 3  Team America World Police   NaN   0372588
# 4        The Hills Have Eyes  2006   0454841
# 5      The Face Of Fu Manchu   NaN   0059162
# 6      The Trip To Bountiful   NaN   0090203
# 7                     Frantz   NaN   5029608
# 8                Bad Company  2002   0280486
# 9             The Last Stand   NaN   1549920

# %%
print(root)
# Out:
# c:\Users\fitsl\Documents\Programming\UVM Programming Classes\PoCS\pocs_project

# %%
df_tropes.columns  = df_tropes.columns.str.strip()
## see most recent printout to know where to start 
chunk_size = 100
for start in range(12200  , len(df_tropes), chunk_size):
    end = start + chunk_size
    print(f"starting {start} to {end}")
    chunk = df_tropes.iloc[start:end].copy()

    # Apply the search_movie function to the chunk
    chunk['imdb_'] = chunk.apply(
        lambda row: search_movie(imdb_link, row['Movie_strip'], row['year']),
        axis=1
    )
    
    # Save the chunk to a CSV or append to an existing one
    chunk.to_csv(f'{root}/Data/tropes_with_imfb.csv', mode='a', header=not pd.io.common.file_exists('results.csv'), index=False)
    print(f"completed {start} to {end} \n\n")
# Out:
# starting 12200 to 12300
# completed 12200 to 12300
#
#
# starting 12300 to 12400
# completed 12300 to 12400
#
#
# starting 12400 to 12500
# completed 12400 to 12500
#
#
# starting 12500 to 12600
# No results found for: Noob La Quete Legendaire
# completed 12500 to 12600
#
#
# starting 12600 to 12700
# completed 12600 to 12700
#
#
# starting 12700 to 12800
# completed 12700 to 12800
#
#
# starting 12800 to 12900
# completed 12800 to 12900
#
#
# starting 12900 to 13000
# completed 12900 to 13000
#
#
# starting 13000 to 13100
# completed 13000 to 13100
#
#
# starting 13100 to 13200
# completed 13100 to 13200
#
#
# starting 13200 to 13300
# No results found for: Himitsu Sentai Goranger Fire Mountains Final Explosion
# completed 13200 to 13300
#
#
# starting 13300 to 13400
# completed 13300 to 13400
#
#
# starting 13400 to 13500
# completed 13400 to 13500
#
#
# starting 13500 to 13600
# completed 13500 to 13600
#
#
# starting 13600 to 13700
# completed 13600 to 13700
#
#
# starting 13700 to 13800
# completed 13700 to 13800
#
#
# starting 13800 to 13900
# completed 13800 to 13900
#
#
# starting 13900 to 14000
# completed 13900 to 14000
#
#
# starting 14000 to 14100
# completed 14000 to 14100
#
#
# starting 14100 to 14200
# completed 14100 to 14200
#
#
# starting 14200 to 14300
# completed 14200 to 14300
#
#
# starting 14300 to 14400
# completed 14300 to 14400
#
#
# starting 14400 to 14500
# completed 14400 to 14500
#
#
# starting 14500 to 14600
# completed 14500 to 14600

# %%
df_tropes.columns  = df_tropes.columns.str.strip()
## see most recent printout to know where to start 
chunk_size = 100
for start in range(10000, len(df_tropes), chunk_size):
    end = start + chunk_size
    print(f"starting {start} to {end}")
    chunk = df_tropes.iloc[start:end].copy()

    # Apply the search_movie function to the chunk
    chunk['imdb_'] = chunk.apply(
        lambda row: search_movie(imdb_link, row['Movie_strip'], row['year']),
        axis=1
    )
    
    # Save the chunk to a CSV or append to an existing one
    chunk.to_csv(f'{root}/Data/tropes_with_imfb.csv', mode='a', header=not pd.io.common.file_exists('results.csv'), index=False)
    print(f"completed {start} to {end} \n\n")

# %%
# df_tropes[["Movie", "year"]].compare(
df_merged[["Movie", "year"]]
# Out:
#             Movie  year
# 0            roma  1972
# 1           venom  2018
# 2           bliss  2021
# 3      witchboard   NaN
# 4         orlando   NaN
# ..            ...   ...
# 599      silenced   NaN
# 600       armored   NaN
# 601     mannequin   NaN
# 602  intermission   NaN
# 603       berserk  1967
#
# [604 rows x 2 columns]

# %%
# Out:
#             Movie                                             Tropes  \
# 0            Roma   AnachronicOrder,AsideGlance,AutoErotica,Blood...
# 1           Venom   ADHD,AbledInTheAdaptation,AbortedArc,Acclaime...
# 2           Bliss   AmbiguousDisorder,ChangelingFantasy,Deconstru...
# 3      Witchboard   AnAxeToGrind,ArchEnemy,ArtisticLicenseHistory...
# 4         Orlando   AsideGlance,Bifauxnen,BittersweetEnding,Break...
# ..            ...                                                ...
# 546      Silenced   AdultFear,AngerBornOfWorry,AssholeVictim,BigE...
# 547       Armored   BestFriendsInLaw,BigBad,BrokenPedestal,ChaseS...
# 548     Mannequin   AbhorrentAdmirer,ActorAllusion,AmbiguouslyGay...
# 549  Intermission   ArsonMurderAndJaywalking,AttentionWhore,BadBo...
# 550       Berserk   AlphaBitch,BerserkButton,BloodlessCarnage,Bra...
#
#       Movie_strip  year      ImdbId         _id  \
# 0            Roma  1972   tt0069191   tt0069191
# 1           Venom  2018   tt1270797   tt1270797
# 2           Bliss  2021  tt10333426  tt10333426
# 3      Witchboard   NaN   tt2256055   tt2256055
# 4         Orlando   NaN   tt4686656   tt4686656
# ..            ...   ...         ...         ...
# 546      Silenced   NaN  tt13206338  tt13206338
# 547       Armored   NaN  tt13857278  tt13857278
# 548     Mannequin   NaN  tt12427228  tt12427228
# 549  Intermission   NaN   tt5565680   tt5565680
# 550       Berserk  1967   tt0061398   tt0061398
#
#                                             poster_url certificate  runtime  \
# 0    https://m.media-amazon.com/images/M/MV5BZTk5Zj...           R  120 min
# 1    https://m.media-amazon.com/images/M/MV5BNzAwNz...       PG-13  112 min
# 2    https://m.media-amazon.com/images/M/MV5BYmFjNW...           R  103 min
# 3    https://m.media-amazon.com/images/M/MV5BMTc5Nz...         NaN      NaN
# 4    https://m.media-amazon.com/images/S/sash/NapCx...         NaN      NaN
# ..                                                 ...         ...      ...
# 546  https://m.media-amazon.com/images/M/MV5BY2M0ZW...         NaN      NaN
# 547  https://m.media-amazon.com/images/S/sash/NapCx...         NaN      NaN
# 548  https://m.media-amazon.com/images/M/MV5BNWEzNm...         NaN      NaN
# 549  https://m.media-amazon.com/images/S/sash/NapCx...         NaN      NaN
# 550  https://m.media-amazon.com/images/M/MV5BM2Q3MD...    Approved   96 min
#
#                                    genre  ratingValue  \
# 0                   ['Comedy', ' Drama']          7.4
# 1    ['Action', ' Adventure', ' Sci-Fi']          6.7
# 2       ['Drama', ' Romance', ' Sci-Fi']          5.3
# 3    ['Horror', ' Mystery', ' Thriller']          NaN
# 4                             ['Sci-Fi']          NaN
# ..                                   ...          ...
# 546                            ['Drama']          NaN
# 547              ['Action', ' Thriller']          NaN
# 548                           ['Horror']          NaN
# 549                           ['Comedy']          NaN
# 550  ['Horror', ' Mystery', ' Thriller']          5.3
#
#                                           summary_text ratingCount  \
# 0    A fluid, unconnected and sometimes chaotic pro...      11,885
# 1    A failed reporter is bonded to an alien entity...     371,819
# 2    A mind-bending love story following Greg who, ...      12,342
# 3            A re-imagining of the 1986 Horror Classic         NaN
# 4    Lost in the depths of their memory, Niels' and...         NaN
# ..                                                 ...         ...
# 546  Two female intelligence officers risk everythi...         NaN
# 547                                         Add a Plot         NaN
# 548  When Alison takes a job at a new vintage cloth...         NaN
# 549  An ambitious young man, down on his luck after...         NaN
# 550  A scheming circus owner finds her authority ch...       1,948
#
#                                               director  \
# 0    {'name': 'Federico Fellini', 'name_id': 'nm000...
# 1    {'name': 'Ruben Fleischer', 'name_id': 'nm0281...
# 2      {'name': 'Mike Cahill', 'name_id': 'nm2648685'}
# 3    {'name': 'Chuck Russell', 'name_id': 'nm0751080'}
# 4                                                  NaN
# ..                                                 ...
# 546                                                NaN
# 547                                                NaN
# 548  {'name': 'Louise E. Lathey', 'name_id': 'nm108...
# 549   {'name': 'Dartel McRae', 'name_id': 'nm2869419'}
# 550  {'name': "Jim O'Connolly", 'name_id': 'nm06402...
#
#                                                   cast
# 0    [{'name': 'Britta Barnes', 'name_id': 'nm00555...
# 1    [{'name': 'Tom Hardy', 'name_id': 'nm0362766'}...
# 2    [{'name': 'Owen Wilson', 'name_id': 'nm0005562...
# 3    [{'name': 'Sofia Milos', 'name_id': 'nm0590499'}]
# 4                                                  NaN
# ..                                                 ...
# 546                                                NaN
# 547                                                NaN
# 548  [{'name': 'Joanna Gaskell', 'name_id': 'nm3667...
# 549  [{'name': 'E.J. Bonilla', 'name_id': 'nm212590...
# 550  [{'name': 'Joan Crawford', 'name_id': 'nm00010...
#
# [551 rows x 15 columns]
