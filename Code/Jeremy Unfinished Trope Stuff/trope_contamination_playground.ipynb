# %%
from collections import defaultdict

f = open("C:/Users/jbro0/OneDrive/Desktop/College_Stuff/PoCSVerse/Project/Github Stuff/Pocs_Film_Project/Data/movies-vs-tropes.csv")
tropes_dict = defaultdict(list)
for line in f:
    trope_string = line.split(";")[1] ### Find tropes associated with movie
    indiv_tropes = trope_string.split(",") ### Seperate into individual tropes
    movie = line.split(";")[0]
    for trope in indiv_tropes:
        tropes_dict[trope].append(movie)

f.close()

# %%
for trope in list(tropes_dict.keys()): ### Make values lists 
    movies = tropes_dict[trope]
    tropes_dict[trope] = movies

# %%
current_test_trope = "VasquezAlwaysDies"
alien_movies = tropes_dict[current_test_trope] ### Test a trope and find associated movies, including years and IMDB IDs
years = []
imdb_ids = []
things_not_found = []
for thing in alien_movies:
    year_found = False
    with open("C:/Users/jbro0/OneDrive/Desktop/College_Stuff/PoCSVerse/Project/Github Stuff/Pocs_Film_Project/Data/tropes_imdb_year.csv", "r") as file:
        for line in file:
            title = (line.split(",")[0]).replace(" ", "")
            if title == thing:
                
                if line.split(",")[-2] == "":
                    year_found = False
                else:
                    years.append(line.split(",")[-2]) 
                    imdb_ids.append(line.split(",")[-1])
                    year_found = True
    if year_found == False:
        print(thing + " not found.")
        things_not_found.append(thing)

found_movies = alien_movies.copy() ### Collect all movies plus years that work
for thing in found_movies:
    if thing in things_not_found:
        found_movies.remove(thing)
# Out:
# BlackChristmas1974 not found.
# Annihilation2018 not found.
# Leviathan1989 not found.
# TwentyEightWeeksLater not found.
# YoureNext not found.
# ChoppingMall not found.

# %%
import letterboxdpy as lbd
from letterboxdpy import movie
scores = []
working_movies = alien_movies.copy()
working_years = years.copy()
for movie in alien_movies:
    print(movie)
    try:
        letterboxd_dict = lbd.movie.Movie(movie).__dict__
        letterboxd_rating = letterboxd_rating["rating"]
        score = letterboxd_rating.split(" ")[0]
        scores.append(score)
    except IndexError:
        print(str(movie) + " not available")
        working_movies.remove(movie)
        working_years.remove(years[alien_movies.index(movie)])
    except TypeError:
        print("Rating issue for " + str(movie))
        
print(scores)
# Out:
# ShockingDark
# ShockingDark not available
# Sharknado2TheSecondOne
# Sharknado2TheSecondOne not available
# TheDragonFighter
# TheDragonFighter not available
# SWAT
# Rating issue for SWAT
# AlienResurrection
# AlienResurrection not available
# Slither
# Rating issue for Slither
# BurningAmbition
# BurningAmbition not available
# TheReef
# TheReef not available
# StarshipTroopers3Marauder
# StarshipTroopers3Marauder not available
# Avatar
# Rating issue for Avatar
# BlackChristmas1974
# BlackChristmas1974 not available
# TheCollector
# TheCollector not available
# Leprechaun4InSpace
# Leprechaun4InSpace not available
# EscapeRoom
# EscapeRoom not available
# NewJackCity
# NewJackCity not available
# FastAndFurious6
# FastAndFurious6 not available
# ResidentEvilRetribution
# ResidentEvilRetribution not available
# MacheteKills
# MacheteKills not available
# AssaultOnPrecinct132005
# AssaultOnPrecinct132005 not available
# DeepRising
# DeepRising not available
# MoonZeroTwo
# MoonZeroTwo not available
# FastFive
# FastFive not available
# ANightmareOnElmStreet3DreamWarriors
# ANightmareOnElmStreet3DreamWarriors not available
# Solo
# Rating issue for Solo
# Annihilation2018
# Annihilation2018 not available
# TheAvengingQuartet
# TheAvengingQuartet not available
# RamboFirstBloodPartII
# RamboFirstBloodPartII not available
# SharkNight
# SharkNight not available
# AlienVsPredator
# AlienVsPredator not available
# DreamingTheReality
# DreamingTheReality not available
# IronAngels
# IronAngels not available
# Carnosaur
# Rating issue for Carnosaur
# BeautyInvestigator
# BeautyInvestigator not available
# TheCave
# TheCave not available
# TheStreetfighter
# TheStreetfighter not available
# ResidentEvil
# ResidentEvil not available
# HomeAlone
# HomeAlone not available
# StarshipTroopers
# StarshipTroopers not available
# StarshipTroopers2HeroOfTheFederation
# StarshipTroopers2HeroOfTheFederation not available
# TheMatrixRevolutions
# TheMatrixRevolutions not available
# FreddysDeadTheFinalNightmare
# FreddysDeadTheFinalNightmare not available
# TheRezort
# TheRezort not available
# BoyEatsGirl
# BoyEatsGirl not available
# WolfCreek
# WolfCreek not available
# RogueOne
# RogueOne not available
# ANightmareOnElmStreet4TheDreamMaster
# ANightmareOnElmStreet4TheDreamMaster not available
# Prometheus
# Rating issue for Prometheus
# Abominable
# Rating issue for Abominable
# MadMaxFuryRoad
# MadMaxFuryRoad not available
# SoldierBoyz
# SoldierBoyz not available
# GhostsOfMars
# GhostsOfMars not available
# Exam
# Rating issue for Exam
# Machete
# Rating issue for Machete
# Feast
# Rating issue for Feast
# Leviathan1989
# Leviathan1989 not available
# HaloNightfall
# HaloNightfall not available
# TheStreetFighter
# TheStreetFighter not available
# BattleLosAngeles
# BattleLosAngeles not available
# Alien3
# Alien3 not available
# Mindhunters
# Rating issue for Mindhunters
# Sharknado
# Rating issue for Sharknado
# TheDescentPart2
# TheDescentPart2 not available
# Terminator2JudgmentDay
# Terminator2JudgmentDay not available
# TwentyEightWeeksLater
# TwentyEightWeeksLater not available
# YoureNext
# YoureNext not available
# ChoppingMall
# ChoppingMall not available
# MadMax2TheRoadWarrior
# MadMax2TheRoadWarrior not available
# WhatHappenedToMonday
# WhatHappenedToMonday not available
# TheHungerGamesMockingjay
# TheHungerGamesMockingjay not available
# KillerAngels
# KillerAngels not available
# TheDescent
# TheDescent not available
# PrincessMadam
# PrincessMadam not available
# Battleship
# Rating issue for Battleship
# ResidentEvilTheFinalChapter
# ResidentEvilTheFinalChapter not available
# Aliens
# Rating issue for Aliens
# SmokinAces
# SmokinAces not available
# Underwater
# Rating issue for Underwater
# Alien
# Rating issue for Alien
# JurassicWorld
# JurassicWorld not available
# AliensVsPredatorRequiem
# AliensVsPredatorRequiem not available
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[115], line 9
#       8 try:
# ----> 9     letterboxd_dict = lbd.movie.Movie(movie).__dict__
#      10     letterboxd_rating = letterboxd_rating["rating"]
#
# File c:\Users\jbro0\anaconda3\Lib\site-packages\letterboxdpy\movie.py:24, in Movie.__init__(self, title, year)
#      23 self.movie_rating(page)
# ---> 24 self.movie_year(page)
#      25 self.movie_genre(page)
#
# File c:\Users\jbro0\anaconda3\Lib\site-packages\letterboxdpy\movie.py:60, in Movie.movie_year(self, page)
#      59 data = page.find_all("meta", attrs={'name': 'twitter:title'})
# ---> 60 data = data[0]['content']
#      61 self.year = None
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[115], line 16
#      14     print(str(movie) + " not available")
#      15     working_movies.remove(movie)
# ---> 16     working_years.remove(years[alien_movies.index(movie)])
#      17 except TypeError:
#      18     print("Rating issue for " + str(movie))
#
# IndexError: list index out of range

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(len(found_movies))
print(len(years))
int_years = [float(year) for year in years]
ax = sns.histplot(data = int_years, binwidth=1)
ax.set_title("Number of films with the " + current_test_trope + " trope, by year")
ax.set_xlabel("Years")
# Out:
# 76
# 76
# Text(0.5, 0, 'Years')

# %%
tropes = list(tropes_dict.keys())
associated_movies = list(tropes_dict.values())
print(len(tropes))
print(len(associated_movies))

### What qualities of a movie can we predict based on it's tropes?
# Out:
# 40689
# 40689

# %%
i = 0 
num_movies = []
while i <= len(tropes) - 1:
    length = len(associated_movies[i])
    num_movies.append(length)
    i += 1
ordered_list = num_movies.copy()
ordered_list.sort()
ordered_list.reverse()
print(ordered_list[0])
print(num_movies[0])
print(len(ordered_list))
# Out:
# 3056
# 1
# 40689

# %%
tropes_to_check = []
i =0
while i <= 200:
    num = ordered_list[i]
    index = num_movies.index(num)
    tropes_to_check.append(tropes[index])
    i += 1

# %%
print(type(tropes_to_check))
# Out:
# <class 'list'>

# %%
import csv
with open("C:/Users/jbro0/OneDrive/Desktop/College_Stuff/PoCSVerse/Project/Github Stuff/Pocs_Film_Project/Data/tropemakers.csv", "w") as file:
    writer = csv.writer(file)
    writer.writerow(tropes_to_check)

# %%
### Vasquez Always Dies
# Out:
# 566

# %%
import matplotlib.pyplot as plt
plt.scatter(range(len(ordered_list)), ordered_list)
plt.xlabel("Rank")
plt.ylabel("Number of Movies")
plt.title("Zipf plot for movie tropes")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(np.log10(range(len(ordered_list))), np.log10(ordered_list))
plt.xlabel("Log 10 of rank")
plt.ylabel("Log10 of number of Movies")
plt.title("Log-log Zipf plot for movie tropes")
plt.show()
# Out:
# C:\Users\jbro0\AppData\Local\Temp\ipykernel_44776\608522278.py:3: RuntimeWarning: divide by zero encountered in log10
#   plt.scatter(np.log10(range(len(ordered_list))), np.log10(ordered_list))

# %%
import matplotlib.pyplot as plt
genre_1 = [1/3, 7/24, 7/36]
genre_2 = [2/3, 11/24, 23/36]
genre_3 = [0, 6/24, 6/36]
time = [1/3,2/3,1]
plt.plot(time, genre_1)
plt.plot(time, genre_2)
plt.plot(time, genre_3)
plt.scatter(time, genre_1, label = "Genre 1")
plt.scatter(time, genre_2, label = "Genre 2")
plt.scatter(time, genre_3, label = "Genre 3")
plt.xlabel("Time proportional to total movie time")
plt.ylabel("Percentage")
plt.title("Genre make up of example movie over time")
plt.legend()
plt.show()
