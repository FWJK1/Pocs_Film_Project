# %%
from collections import defaultdict ###Import stuff and make dictionaries
import seaborn as sns
import matplotlib.pyplot as plt

f = open("C:/Users/jbro0/OneDrive/Desktop/College_Stuff/PoCSVerse/Project/Github Stuff/Pocs_Film_Project/Data/movies-vs-tropes.csv")
tropes_dict = defaultdict(list)
for line in f:
    trope_string = line.split(";")[1] ### Find tropes associated with movie
    indiv_tropes = trope_string.split(",") ### Seperate into individual tropes
    movie = line.split(";")[0]
    for trope in indiv_tropes:
        tropes_dict[trope].append(movie)
f.close()

for trope in list(tropes_dict.keys()): ### Make values lists 
    movies = tropes_dict[trope]
    tropes_dict[trope] = movies

# %%
### Pick a trope and find the movies with good data
current_test_trope = "ArgentineMedia"
alien_movies = tropes_dict[current_test_trope] ### Test a trope and find associated movies, including years and IMDB IDs
years = []
imdb_ids = []
things_not_found = []
for thing in alien_movies:
    year_found = False
    with open("C:/Users/jbro0/OneDrive/Desktop/College_Stuff/PoCSVerse/Project/Github Stuff/Pocs_Film_Project/Data/tropes_imdb_year.csv", "r") as file:
        for line in file:
            title = (line.split(",")[0]).replace(" ", "")
            if title == thing:
                
                if line.split(",")[-2] == "":
                    year_found = False
                else:
                    years.append(line.split(",")[-2]) 
                    imdb_ids.append(line.split(",")[-1])
                    year_found = True
    if year_found == False:
        print(thing + " not found.")
        things_not_found.append(thing)

found_movies = alien_movies.copy() ### Collect all movies plus years that work
for thing in found_movies:
    if thing in things_not_found:
        found_movies.remove(thing)
# Out:
# Delirium2014 not found.

# %%
#Plot
#print(len(found_movies))
#print(len(years))
binsize = 1
int_years = [float(year) for year in years]
ax = sns.histplot(data = int_years, binwidth=binsize)
ax.set_title("Number of films with the " + current_test_trope + " trope over time, Bin size = " +str(binsize))
ax.set_xlabel("Years")
# Out:
# Text(0.5, 0, 'Years')

# %%
print(found_movies)
print(imdb_ids)
# Out:
# ['FunSize', 'SuperTroopers', 'TheGoddess', 'PiratesOfTheCaribbeanAtWorldsEnd', 'YouOnlyLiveTwice', 'TheBurning', 'TheRacket', 'TheSlumberPartyMassacre', 'LEclisse', 'TheTransporter', 'VanHelsing', 'FortySecondStreet', 'JamesBond', 'TheVisitor', 'Gilda', 'DOADeadOrAlive', 'ThatsMyBoy', 'MinorityReport', 'TheAnthropophagusBeast', 'KillersKiss', 'Waiting', 'OutCold', 'SwampThing', 'Xanadu', 'Ms45', 'TrueLies', 'TheMuppetMovie', 'TheLostSkeletonOfCadavra', 'ReeferMadnessTheMusical', 'TheTransporterRefueled', 'WildWildWest', 'KingsmanTheSecretService', 'DeathOnDemand', 'BringItOn', 'ScottPilgrimVsTheWorld', 'TheAdventuresOfSharkboyAndLavagirl', 'TheLover', 'ANightmareOnElmStreet4TheDreamMaster', 'FlamingBrothers', 'TheSinglesWard', 'TheGraduate', 'IndianaJonesAndTheKingdomOfTheCrystalSkull', 'TransformersAgeOfExtinction', 'BloodOnTheLand', 'StarshipInvasions', 'MortalKombatTheMovie', 'TheEigerSanction', 'TheProposal', 'KinkyBoots', 'FateOfAMan', 'Creepshow2', 'DirtyRottenScoundrels', 'TheLairOfTheWhiteWorm', 'Closer', 'AmericanGraffiti', 'HighPlainsDrifter', 'ForYourEyesOnly', 'TuckerAndDaleVsEvil', 'Hook', 'SuckerPunch', 'AmericanPie', 'TheBigLebowski', 'CrazyStupidLove', 'TheRockyHorrorPictureShowLetsDoTheTimeWarpAgain', 'InspectorGadget2', 'YouDontMessWithTheZohan', 'GeorgeOfTheJungle', 'GentlemansFate']
# ['1663143\n', '0247745\n', '0051667\n', '0449088\n', '0062512\n', '0082118\n', '0043955\n', '0084695\n', '0056736\n', '0293662\n', '0338526\n', '0024034\n', '4896340\n', '0857191\n', '0038559\n', '6739896\n', '1232200\n', '0181689\n', '0082479\n', '0356476\n', '0348333\n', '0253798\n', '0084745\n', '0081777\n', '0082776\n', '0111503\n', '0079588\n', '0307109\n', '0404364\n', '2938956\n', '0120891\n', '2802144\n', '0902274\n', '0204946\n', '0446029\n', '0424774\n', '0101316\n', '0095742\n', '0093305\n', '0306069\n', '0061722\n', '0367882\n', '2109248\n', '0449845\n', '0076760\n', '20938382\n', '0072926\n', '1041829\n', '0434124\n', '6125576\n', '0092796\n', '0095031\n', '0095488\n', '0376541\n', '0069704\n', '0068699\n', '0082398\n', '1465522\n', '0102057\n', '0978764\n', '0163651\n', '0118715\n', '1570728\n', '1267299\n', '0301454\n', '0960144\n', '0119190\n', '0021906\n']
