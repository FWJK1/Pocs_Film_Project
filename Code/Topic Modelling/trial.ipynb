# %% [markdown]
# # Import libraries and setup git root

# %%
from transformers import DistilBertTokenizer, DistilBertModel
import torch
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import fastparquet ## make sure environment has fastparquet and NOT pyarrow
import itertools

# %%
import os

def find_repo_root(start_path):
    """
    useful general function for finding the (first, closest) repo root so github file paths work the same on different machines 
    """
    current_path = os.path.abspath(start_path)
    
    while True:
        # Check for the existence of the .git directory or other indicators
        if os.path.isdir(os.path.join(current_path, '.git')) or \
           os.path.isfile(os.path.join(current_path, 'README.md')):
            return current_path
        
        parent_path = os.path.dirname(current_path)
        
        # Stop if we reach the root directory
        if parent_path == current_path:
            break
        
        current_path = parent_path

    return None  # Return None if not found

root = find_repo_root(os.getcwd())
root = root.replace('\\', '/')
print(root)
# Out:
# c:/Users/fitsl/Documents/Programming/UVM Programming Classes/PoCS/pocs_project

# %% [markdown]
# # Import the comments data

# %%
df = pd.read_parquet(f"{root}/Data/Whole_sets/merged_tropes_comments.parquet")

# %%
df.head(2)
# Out:
#                                    letterboxd_search  \
# 0  https://letterboxd.com/search/Puerta+De+Hierro...
# 1  https://letterboxd.com/search/Better+Off+Dead....
#
#                                             comments  \
# 0  [{'stars': '★★★★', 'review': 'Yo no entendí bi...
# 1  [{'stars': '★★★★½', 'review': "this fucking gu...
#
#                                    reviews_extracted  \
# 0  [Yo no entendí bien la película, Perón sabía q...
# 1  [this fucking guy took a shower with socks on ...
#
#                                         review_stars  \
# 0  [8.0, 9.0, 4.0, 10.0, 6.0, 5.0, 1.0, 10.0, 8.0...
# 1  [9.0, 10.0, 8.0, 8.0, 10.0, 10.0, 9.0, 8.0, 7....
#
#                                         review_dates             genres  \
# 0  [09 Nov 2020, 17 Jul 2020, 08 Mar 2021, 21 Aug...                 []
# 1  [18 Dec 2021, 06 Apr 2016, 29 Feb 2020, 25 Aug...  [Romance, Comedy]
#
#    avg_rating                              directors  Year  \
# 0        6.60  [Víctor Laplace, Dieguillo Fernández]  2013
# 1        7.08                 [Savage Steve Holland]  1985
#
#                                                  url                 Title  \
# 0  https://letterboxd.com/film/puerta-de-hierro-e...    Puerta  De  Hierro
# 1       https://letterboxd.com/film/better-off-dead/  Better  Off  Dead...
#
#        imdb_                                          nu_tropes  \
# 0  2512204.0  [ ArgentineMedia, BlackMagic, ChekhovsGun, Che...
# 1    88794.0  [ AbhorrentAdmirer, AcceptableTargets, ActorAl...
#
#    double_first_number
# 0                 6.60
# 1                 7.08

# %% [markdown]
# # Try some some code for bert generally

# %%
# Load BERT model and tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased')


# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Sample documents
documents = df['reviews_extracted'].iloc[0]

# Tokenize and get BERT embeddings for each document
def get_bert_embeddings(documents):
    embeddings = []
    for doc in documents:
        inputs = tokenizer(doc, return_tensors='pt', truncation=True, padding=True, max_length=512)
        with torch.no_grad():
            outputs = model(**inputs)
        # Take the embeddings of [CLS] token (first token)
        doc_embedding = outputs.last_hidden_state[0][0].numpy()
        embeddings.append(doc_embedding)
    return np.array(embeddings)

# Obtain embeddings
embeddings = get_bert_embeddings(documents)

# Perform K-Means clustering
num_topics = 2  # Define the number of topics
kmeans = KMeans(n_clusters=num_topics)
kmeans.fit(embeddings)

# Print the cluster assignments
for i, label in enumerate(kmeans.labels_):
    print(f"Document {i}: Cluster {label}")

# Cluster centers (topics)
print("Cluster Centers (Topics):")
print(kmeans.cluster_centers_)
# Out:
# Document 0: Cluster 0
# Document 1: Cluster 0
# Document 2: Cluster 0
# Document 3: Cluster 0
# Document 4: Cluster 1
# Document 5: Cluster 1
# Document 6: Cluster 0
# Document 7: Cluster 1
# Document 8: Cluster 0
# Document 9: Cluster 1
# Document 10: Cluster 0
# Document 11: Cluster 0
# Document 12: Cluster 1
# Document 13: Cluster 0
# Document 14: Cluster 1
# Document 15: Cluster 0
# Document 16: Cluster 0
# Document 17: Cluster 1
# Document 18: Cluster 0
# Document 19: Cluster 0
# Document 20: Cluster 0
# Document 21: Cluster 0
# Document 22: Cluster 0
# Document 23: Cluster 1
# Document 24: Cluster 0
# Document 25: Cluster 1
# Document 26: Cluster 1
# Document 27: Cluster 1
# Document 28: Cluster 1
# Document 29: Cluster 1
# Document 30: Cluster 1
# Document 31: Cluster 1
# Document 32: Cluster 1
# Document 33: Cluster 0
# Document 34: Cluster 0
# Document 35: Cluster 0
# Document 36: Cluster 0
# Document 37: Cluster 0
# Document 38: Cluster 0
# Document 39: Cluster 0
# Document 40: Cluster 1
# Document 41: Cluster 1
# Document 42: Cluster 0
# Document 43: Cluster 1
# Document 44: Cluster 0
# Document 45: Cluster 0
# Cluster Centers (Topics):
# [[-0.22782998 -0.09829892 -0.00429099 ... -0.16812424  0.32819104
#    0.33524463]
#  [-0.25660604 -0.06599882  0.01801264 ... -0.1929885   0.25130072
#    0.33949566]]

# %%
df.sort_values(by='avg_rating', ascending=False, inplace=True)
df
# Out:
#                                        letterboxd_search  \
# 4905        https://letterboxd.com/search/Harakiri+1962/
# 11893  https://letterboxd.com/search/Stop+Making+Sens...
# 11281  https://letterboxd.com/search/Fullmetal+Alchem...
# 76     https://letterboxd.com/search/Twelve+Angry+Men...
# 10995  https://letterboxd.com/search/Twelve+Twelve+Tw...
# ...                                                  ...
# 12058         https://letterboxd.com/search/Axeman+2013/
# 12060  https://letterboxd.com/search/Torn+Dark+Bullet...
# 12062  https://letterboxd.com/search/The+Running+Man+...
# 12071   https://letterboxd.com/search/Wonder+Seven+1994/
# 12072          https://letterboxd.com/search/Julia+2022/
#
#                                                 comments  \
# 4905   [{'stars': '★★★★★', 'review': 'I am an idiot.W...
# 11893  [{'stars': '★★★★★', 'review': 'SAME AS IT EVER...
# 11281  [{'stars': '★★★★', 'review': 'this is one fuck...
# 76     [{'stars': '★★★★★', 'review': "That was the be...
# 10995  [{'stars': '★★★★★', 'review': "That was the be...
# ...                                                  ...
# 12058  [{'stars': '★', 'review': "And I guess they ma...
# 12060                                                 []
# 12062                                                 []
# 12071  [{'stars': '★★★★', 'review': "This film is so ...
# 12072  [{'stars': '★★', 'review': 'it’s not that i di...
#
#                                        reviews_extracted  \
# 4905   [I am an idiot.Why is it that I still dread wa...
# 11893  [SAME AS IT EVER WASSAME AS IT EVER WASSAME AS...
# 11281  [this is one fucken long ass movie, *Fullmetal...
# 76     [That was the best 1.5 hours of middle aged wh...
# 10995  [That was the best 1.5 hours of middle aged wh...
# ...                                                  ...
# 12058  [And I guess they made a re-make of this..Hope...
# 12060                                                 []
# 12062                                                 []
# 12071  [This film is so fucking good! It's like a Joh...
# 12072  [it’s not that i didn’t like it. i think it’s ...
#
#                                             review_stars  \
# 4905   [10.0, 10.0, None, 10.0, 10.0, 10.0, None, 9.0...
# 11893  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....
# 11281  [8.0, 10.0, 8.0, 10.0, 10.0, 10.0, 10.0, 10.0,...
# 76     [10.0, 10.0, 8.0, 9.0, 10.0, 10.0, 10.0, 10.0,...
# 10995  [10.0, 10.0, 8.0, 9.0, 10.0, 10.0, 10.0, 10.0,...
# ...                                                  ...
# 12058  [2.0, 4.0, 3.0, 3.0, 4.0, 1.0, 1.0, 1.0, 1.0, ...
# 12060                                                 []
# 12062                                                 []
# 12071  [8.0, 6.0, 6.0, 4.0, 6.0, 4.0, 7.0, 7.0, 9.0, ...
# 12072                                         [4.0, 4.0]
#
#                                             review_dates  \
# 4905   [01 Dec 2013, , 26 Jan 2024, 21 Jun 2021, 06 S...
# 11893  [27 Mar 2020, 18 Sep 2023, 06 Aug 2013, 13 Jul...
# 11281  [06 Sep 2016, , 16 Feb 2022, 15 Apr 2020, 21 M...
# 76     [23 Nov 2014, 28 Mar 2018, 01 Aug 2020, 29 Jun...
# 10995  [23 Nov 2014, 28 Mar 2018, 01 Aug 2020, 29 Jun...
# ...                                                  ...
# 12058  [15 Aug 2022, 19 Jan 2022, 10 Aug 2022, 14 May...
# 12060                                                 []
# 12062                                                 []
# 12071  [22 Feb 2024, 15 Mar 2023, 25 Mar 2023, 13 Jan...
# 12072                         [08 Nov 2022, 18 Oct 2022]
#
#                             genres  avg_rating  \
# 4905      [History, Drama, Action]        9.38
# 11893         [Music, Documentary]        9.36
# 11281          [Comedy, Animation]        9.32
# 76                         [Drama]        9.26
# 10995                      [Drama]        9.26
# ...                            ...         ...
# 12058                     [Horror]         NaN
# 12060                   [Thriller]         NaN
# 12062  [Science Fiction, Thriller]         NaN
# 12071                     [Action]         NaN
# 12072                [Documentary]         NaN
#
#                                                directors  Year  \
# 4905                                  [Masaki Kobayashi]  1962
# 11893                                   [Jonathan Demme]  1984
# 11281  [Takahiro Ikezoe, Kiyomitsu Sato, Hiroshi Ikeh...  2009
# 76                                        [Sidney Lumet]  1957
# 10995                                     [Sidney Lumet]  1957
# ...                                                  ...   ...
# 12058                                    [Joston Theney]  2013
# 12060                                                 []  2020
# 12062                                     [Edgar Wright]  2025
# 12071                              [Tony Ching Siu-Tung]  1994
# 12072                                  [Hanna Trofimova]  2022
#
#                                                      url  \
# 4905               https://letterboxd.com/film/harakiri/
# 11893     https://letterboxd.com/film/stop-making-sense/
# 11281  https://letterboxd.com/film/fullmetal-alchemis...
# 76             https://letterboxd.com/film/12-angry-men/
# 10995          https://letterboxd.com/film/12-angry-men/
# ...                                                  ...
# 12058  https://letterboxd.com/film/axeman-at-cutters-...
# 12060     https://letterboxd.com/film/torn-dark-bullets/
# 12062  https://letterboxd.com/film/the-running-man-2025/
# 12071          https://letterboxd.com/film/wonder-seven/
# 12072  https://letterboxd.com/film/when-will-the-wint...
#
#                         Title       imdb_  \
# 4905                 Harakiri     56058.0
# 11893     Stop  Making  Sense     88178.0
# 11281    Fullmetal  Alchemist   1355642.0
# 76         Twelve  Angry  Men     50083.0
# 10995  Twelve  Twelve  Twelve     50083.0
# ...                       ...         ...
# 12058                  Axeman   2357866.0
# 12060     Torn  Dark  Bullets   8386654.0
# 12062       The  Running  Man  14107334.0
# 12071           Wonder  Seven    110923.0
# 12072                   Julia  10975574.0
#
#                                                nu_tropes  double_first_number
# 4905   [ AHandfulForAnEye, AnAesop, ArchEnemy, BestSe...                 9.38
# 11893  [ AlbumTitleDrop, AmericanMusic, AndNowForSome...                 9.36
# 11281  [ AdaptationDyeJob, AdaptationPersonalityChang...                 9.32
# 76     [ AngryBlackMan, FilmsOf19951999, HiddenDepths...                 9.26
# 10995  [ AgainstMyReligion, BMovie, BedMateReveal, Be...                 9.26
# ...                                                  ...                  ...
# 12058  [ AnAxeToGrind, AntagonistTitle, BMovie, BigBa...                  NaN
# 12060  [ BewareTheNiceOnes, CanadianMovies, DiesWideO...                  NaN
# 12062  [ AMatchMadeInStockholm, ATasteOfTheirOwnMedic...                  NaN
# 12071  [ ActionGirl, ActionPrologue, BadassBiker, Bar...                  NaN
# 12072  [ AwardBait, BasedOnAGreatBigLie, BasedOnAgrea...                  NaN
#
# [12076 rows x 14 columns]

# %% [markdown]
# # bertopic library gives more intuitive topic representations

# %%
# documents = df['reviews_extracted'].loc[df['Title'] == 'Stop Making Sense']
documents = df['reviews_extracted'].loc[11893]
documents
# for i, doc in enumerate(documents):c
#     print(i)
#     if not isinstance(doc, str): print(doc)
# Out:
# ['SAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WAS',
#  'sweat my ass off dancing from “slippery people” on in a big suit at a vidiots screening with the band (inc. ednah holt, lynn mabry, and steve scales) in attendance. lynn and ednah joined us and did laps around the audience. tina weymouth gave me a near empty glass of champagne and said my suit was nice. i took two gummies and drank a grapefruit radler. vidiots cofounder saw me hitting the choreo and asked “how many times have you…',
#  'A polite man is driven to murder. He becomes a prophet and screams manifestos on love, war, and the increasingly alarming impact of technology and progress. Driven to insanity by his own insights into the human condition, he travels to a river in an attempt to drown himself but instead is baptized and absolved of sin. He dies, crosseyed yet painless.This is the definitive fairytale of my generation, and the moral is "watch out, you might get what you\'re after". Jesus lives, and he\'s wearing a giant suit.',
#  'me::(david byrne:*gets on stage wearing the big suit*me::)',
#  'ME: oh cool, stop making sense is streaming for free with ads. i\'ll put it on while i write2 SONG LATER: i\'m gonna rent it from amazon for a better stream3 SONGS LATER: [screeching "turn like a wheeel inside a wheeel!" as i tap on my keyboard]2 SONGS LATER: i can buy it for cheaper on itunes, but i can watch it on my tv if i do google play hmm3 SONGS LATER: [dancing around the…',
#  'The most joyous film ever made. The little moments where David Byrne is trying to perform stone-faced but can\'t help but smile could power me for weeks. Nothing makes me feel so exuberant, happy, nostalgic, and full of love as "This Must Be The Place." It breaks my heart that Talking Heads aren\'t friends anymore because more than anything, this movie feels like it works as an ode to/view on their friendship and how they work so perfectly together as…',
#  'A manifesto on how you and your friends (with the help of some instruments, a couple of lights, a few cameras and platforms, a cartoonishly oversized suit and a standard house lamp) can see the face of god. Opens with an anxious man alone in what looks like an abandoned factory hitting play on a tape and within the span of a few songs you are watching a transcendent celebration of pure music and art and collaboration where everyone and…',
#  'Had the pleasure of catching this in IMAX, they’ve done a lot of work in the A24 remaster to round off any of the rough edges of the original cut. The edit and visuals are much cleaner, had a lot more work done than I was anticipating to help with the overall timing and flow. The colour correction and 4k work really makes the lighting pop. Even utilising completely different takes and extended versions of tracks that I’m fairly certain…',
#  'david byrne looks like oppenheimer?',
#  '100The most persuasive argument for cocaine usage in the whole entire history of anything and everything. Moves like water, vibrates on its own level of existence.',
#  'one of the most profound “oh… igetit” moments of my life',
#  "pretty amazing how this is humanity's greatest achievement",
#  "There's an entire movie happening inside of David Byrne.",
#  'play that funky music white boy!!!',
#  'Absolutely life-affirming on the big screen.',
#  'I’ve been listening to Stop Making Sense nonstop for the past few months since I did talked about it on the Blank Check podcast (great cast good boys!!!!) and I keep forgetting to log it. So here are a bunch of the very unorganized notes I took from when I last watched it (on the 35th anniversary of the film!!)----------------------------------------–– I’m embarrassed to admit this but… this is the only Jonathan Demme movie I have ever seen. Yes,…',
#  'They got the song from GTA 5 in this',
#  'I nearly lost my fucking mind watching this movie. A slow, deliberate start becomes nearly an hour of the most infectious, jubilant, ebullient energy you’ll ever experience. “Girlfriend is Better” slaps incredibly hard.Greatest concert film ever made, and an incredible monument to artistry, musical charisma, and cocaine.',
#  'Never wanted to be a lamp so bad',
#  'does anybody have any questions?',
#  ':)',
#  "LOVE ME 'TIL MY HEART STOPS!LOVE ME 'TIL I'M DEAD!",
#  'Great as ever. The part where he’s pleasantly surprised that the lamp doesn’t fall over really hit this time around.',
#  'exceeded astronomical expectations',
#  "96/100This was the first movie I ever reviewed, for my high school newspaper at the time of its release. (Alas, the text has been lost.) Wonder which would surprise my 16-year-old self more: that I'd one day become a member of the New York Film Critics Circle, or that I'd one day weep tears of joy ever time I watchStop Making Sense? Because Talking Heads were a super-cerebral band with a seemingly borderline-autistic frontman, the show's sense of…",
#  'this is who matty healy thinks he is',
#  'This film makes me feel like all my muscles are being suspended like an inch higher than usual and my heart is being pumped full of gold dust',
#  'david and alex dancing during “burning down the house” :)',
#  "Home is where I want to bePick me up and turn me 'roundI feel numb, born with a weak heartI guess I must be having funThe less we say about it, the betterWe'll make it up as we go alongFeet on the ground, head in the skyIt's okay, I know nothing's wrong, nothing.",
#  'watching this ruined my night because from this moment on I now must live with the weight of knowing I’ll never be cooler than David Byrne dancing on stage with a lamp to “This Must Be the Place”',
#  "100Theatrical re-release. In-person intro with the legendary Jerry Harrison. Those tight close-ups during 'What a Day That Was' are genuinely miraculous. You can try to compare this with other concert films, but Demme's film will always win. Every single time.",
#  'rewatched twice in a row and the second time i took notes LMAO. here\'s what i wrote:• this is just one gal\'s opinion, but cutting "cities" out and leaving "swamp" in was crazy work• jerry harrison\'s shoes look at times like his bare feet and it always takes me out• during "burning down the house" i was drumming so hard on my leg with the pen i was holding that it unscrewed without me…',
#  "I'm just so happy",
#  'quirked up white boy with a little bit of swag busts it down sexual style … is he goated with the sauce?',
#  'that’s my big suited serotonin provider',
#  "one of those movies where i'm grateful to my younger self for not getting the dvd from the library so i could see it for the first time like this",
#  'rewatched it last night, (as i have many nights this week, month, year, all in incomplete ways), rewound the vhs tape, watched it again, rewound it one more time, watched the first half again. late summer is typically a melancholy time for me, the past decade’s balmy air streaked with grief. this tape has been a recent comfort during my late night loneliness, like a group of friends to keep me companyit’s hard to imaginethat nothing at allcould be so excitingcould be this much fun',
#  'You think it’s a big suit and then you see it in imax and then wow yeah big suit',
#  "100(35mm)MKE Film Fest #3A coked-out, energized, miraculous face-melter of a communal gathering. Artistry, creativity and movement as one big happy family, collaborative with the void surrounding their band on stage. Track by track, member by member, anxiety is slowly replaced with honest-to-god jubilation; blissful and radiant, searing and uncommonly truthful, startling and grooving. Each space explored, each emotional plateau, and each harmonious movement is uncharted. Even though it's more than 30 years old,Stop Making Sense-…",
#  'Once in a lifetime for so many reasons. How did I get here! Or, well,here(I photographed the band and asked David Byrne for his four favourite movies. The rest speaks for itself!)',
#  'my father had an old car. it stunk of a dirty bike and sweat. my friends used to groan whenever he would pick us up from swimming practice and referred to it as the "cow car" (it smelled like a cow... get it). it made hissing noises and the air conditioner never quite worked the way it should.my father and i ran together. it began when i quit the swim team and told him i didn\'t want to be…',
#  'Everyone say thank you A24',
#  'same as it ever was, but better every time',
#  'CILLIAN MURPHY I FOUND YOUR NEXT OSCAR',
#  "david byrne's best quality: his wiggles",
#  "Here's the thing with concert documentaries: if you're a fan of the band/artist, it will be an automatic 10. For documentaries like these, your enjoyment is dependent on the music, and musical taste can be very subjective. But there's something special aboutStop Making Sense. Director Jonathan Demme actually puts in the effort to make this documentary a work of art rather than simply being a performance recording.The setlist is perfect. It starts slow with just David Byrne performing…",
#  'IS DAVID BYRNE THE COOLEST DUDE TO WALK THE PLANET???I had an ear to ear grin the whole time! I was expecting it to be awesome, but it was so much fucking fun!I think there’s something so inspiring about how confident David Byrne is in his weirdness. His antics are just off the charts cool. That being said, the backup singers and the rest of the band are amazing dancers and add so much to the feel of…',
#  "100MKE Film Fest #3I'll always remember the sight of a small old lady losing her absolute shit at the intro of 'Girlfriend is Better'. You've never truly seen this movie until you've watched it with a packed auditorium which quickly morphs into a dance party in the aisles. There is no screen. Just pictures and sound. Total, full-fledged masterwork: one for the time capsules.",
#  "hi. i've got a tape i want to play.this feels like magic precisely because there is no magic - the magicians stand open and vulnerable, without curtains or hiding places, looking tiny among the platforms and instruments and construction flotsam in the background. the trick is that there is no trick. there's something very powerful about seeing these big interesting shadows moving across the back wall, then realizing they're made by a dude just walking around with a spotlight.…",
#  "This ain't no party, this ain't no discoThis ain't no fooling aroundNo time for dancing, or lovey doveyI ain't got time for that nowAn utterly hypnotic, frenetic, Lynchian, drug-fuelled spiritual communion celebrating artistry and creativity in its purest form. From the comically oversized suits to the pendulum-swinging kneecaps to David Byrne running laps around the stage,Stop Making Senseis more than a typical concert film; it is a blisteringly radiant, unrelenting, psychedelic fever dream that is possibly the greatest concert film ever made.Jesus lives and his name is David Byrne...but then again, did he dance likethis?",
#  'david byrne dancing around like a pigeon & yelling about the suburbs procures me an insane amount of serotonin',
#  "rewatched in imax!!!! physically could not keep still!!! so many little moments and cuts that i'm obsessed with at this point... watching my vhs tape a lot has deepened my appreciation for it, but seeing it in a packed house felt so electric and joyful. this is kinda what life is all about",
#  "the only reason behind the tiny head and the massive suit is that he's four toddlers stacked on top of each other",
#  "This felt like a once in a lifetime experience in IMAX that I wouldn't have missed even if a psycho killer was after me. What a day it was.",
#  "There's something about seeing this with a crowd that makes you completely reevaluate every other time you ever saw it. You go through this period of self-reflection, maybe all those times you saw it in your bedroom you were exaggerating about how good it was. Maybe you're just that autistic kid who is too excited about music. But then you look around the packed theatre and see all the smiling faces, trying their best not to jump out of their…",
#  "half-asleep crying watching David Byrne playing with the lamp while eating pizza and chicken wings on my 18th birthday. this is the first day of the rest of my life and I've already peaked, its all downhill from here",
#  'he suit too big for he gotdamn body',
#  'I LOVE YOU FATHER AUTISM',
#  "Begins in total silence, and steadily escalates from there to pure celebration. Byrne is a madman, seizing and jolting to and from all corners of the stage, morphing from a nervy introvert to alternate universe evangelist, and is very nearly upstaged by Tina Weymouth's knees.",
#  'hahahahahahahahahahshdhahahah oh nooooooooookay this is a movie friends were often surprised i’d never seen. so for years I stayed intentionally ignorant because I knew, whenever I saw it, I wanted to go in completely cold. And I did that successfully! I knew it was a Talking Heads concert film and that was it. Didn’t even know who directed it. Only specific to the film I knew was a big suit would appear at some point. Whatever, my life story…',
#  'cant explain how much serotonin this gives to me',
#  '9 years ago I had a crush on a girl named Diane and Diane\'s two favorite bands were Talking Heads and...Kings of Leon(!!) I spent a few months listening to nothing but these two equally excellent bands that are the same in every way. Before then my only experience with TH was the forgotten 2000 Nicolas Cage movieThe Family Manwhich usesOnce In A Lifetimein the trailer. When David Byrne sings "This is not my beautiful house! This…',
#  'This is what world peace sounds like.Alex weir drenched in sweat fucking shredding on Crosseyed and Painless while the entire band cheers in awe means more to me than the entire Obama administration',
#  'seeing this in theaters was transcendent.',
#  "If I were David ByrneI'd go to galleries and not be too concernedWell I would have a cup of coffeeAnd I'd find my surroundings quite amusing andPeople would ask me which were my favorite paintingsSo I went through a slight Crash Test Dummies phase in college. Mock me if you must. Blame my roommate. We were pretentious, precocious sophomores enamored with anything that dealt with death and God and art. Naturally my favorite song on…",
#  "an argument could be made this is the first movie we should send out into space in hopes an advanced alien civilization will find it, where they would see the best of humanity's efforts. operates on an entirely new realm of existence where all get lost in the gravitational pull of david byrne and his suit.",
#  'WHEN HE GIVES THE LAMP A LITTLE KISS... FHGFHFHGHFGEBVWEOUBVUWBIVEWBVIYRBGWEPEGNWNEUGWRBGOBDFVBREONGEOG',
#  "funny how the most exercise i've had in 3 months is jumping around for 88 minutes imagining im david byrne in a big suit",
#  'David Byrne will "Stop Making Sense",With music and movement so dense.Looking so cute,In an big suit,Making it all feel less tense.',
#  'David Lynch EraserheadDavid Byrne Talking HeadsDavid Cronenberg exploding heads',
#  'Whoa.So cool to see the guy who played Oppenheimer’s first movie.',
#  'Pure joy.',
#  "“We'd like to thank our crew... goodnight.”After being recommended numerous times by different friends to watchStop Making Sense, I finally decided to watch it tonight and, wow, what an unbelievable musical experience this film is.Stop Making Senseunfolds as an ensemble piece with each musician being introduced as a different character. As each song develops, the cast grows and expands eventually until we have a full band of every instrument imaginable. This is by far the greatest…",
#  'a truly mesmerising experience. desperate to try out some of these moves in the club as soon as possible',
#  'downright religious in IMAX. true autistic excellence. only bad thing is that the setlist doesn’t include the best song from Remain In Light (Born Under Punches) but Girlfriend Is Better makes up for it. i am going to direct the Car Seat Headrest equivalent to this one day just you all wait',
#  'okay so my friend matt told me this story forever ago that i basically never stop thinking about: he was at a wedding up at Big Bear in the woods in California. a DJ and a dance floor was set up outdoors, and at one point the DJ got on the mic and yelled“Let’s show these trees what humans can do!”anyway, this is what humans can do!!! a towering achievement, an ode to moving around. big demme faces,…',
#  'There was a moment, I think during "This Must Be the Place", when I wrenched my eyes away from the screen for a few seconds and glanced around the cinema and noticed that Tina had fixed a pair of glow-sticks together and wrapped them around her neck like some kind of chemiluminescent choker, and Neil seemed to be vibrating in a synesthetic trance, and Ben and Matt Hoffman were leading a posse-wide chant in time to Byrne\'s "oh-ohh" bit like…',
#  "it's like cocomelon for me",
#  'This was more of a “throw on in the background while I’m hanging with friends” watch that turned into “I’m dancing to Talking Heads while my friends hang out” watch. Incredible.',
#  'Talking PerfectionAnd you may ask yourselfWhy is this movie so good?And you ask yourselfDo they ever stop moving?And you may say to yourselfIt’s so simple, yet so enthralling.And you may say to yourself,My God! What have they done!Cinematic Playlist – MusicologyCinematic Time Capsule - 1984 Ranked1984 U.S. Release Schedule',
#  'if my doctor ever says i only have 88 minutes left to live i know EXACTLY what i’m watching',
#  "You know those lightning-in-a-bottle moments that happen every so often when you're watching a film? The feeling that you've witnessed something so rare, so special, that it takes you to a transcendental plane of consciousness? Well,Stop Making Senseis that, non-stop for 88 minutes, and stays that way every time I watch it.I guess my favourite band is The Beatles (boring, I know), but Talking Heads is the answer I'm more likely to give if you ask me…",
#  'my cat kept reaching out to touch david byrne’s face with his paw. we love the big suited man <3',
#  "My only concert experience was seeing Bryce Vine in my university's gym parking lot.Stop Making Sense starts with Talking Head's biggest hit, Psycho Killer. Then, the other band members come in, bringing a different vibe to each song. Each song is a different experience. I caught myself looking up the tracklist to add songs I liked. Not every song was for me; I gravitated to the faster-paced and soulful songs.The camera work is so well done, too! It…",
#  '“Home is where I want to be“an absolutely spectacle. just pure fun. choreographed chaos. stunning visuals, those backdrops were crazy. insane vibes. revolutionary dance music, dance moves, outfits, the big suit are u kidding me. not to mention the white vans, white socks and first suit set up (!!!). just aesthetics, before people had any clue. i’m a much bigger talking heads fan after seeing this, what a unique forward thinking group, who made (psycho) killer music. imax does…',
#  "I was, am and will always be a Radiohead, but after this experience (but don't let anyone fool you or tell you otherwise, this is what this is), you can count me as Talking Heads fan.Seriously, when I watched that 100% on RT and everyone singing praises to this concert film, I was pretty perplexed, but also intrigued. I've known Heads been a pretty popular band andPsycho Killerhas been the soundtrack for some legit great and only…",
#  'the happiness i experience while watching this is absolutely astronomical',
#  'The coolest shit maybe ever. Imagine being as happy as David Byrne was during “Once in a Lifetime.” Imagine making both this andThe Silence of the Lambs!!',
#  'a single tear streamed down my face during this must be the place',
#  "Us tall skinny white guys don't have many style icons. David Byrne circa 1984 might be as cool as we get.*First of all, the music is great. I don't think I've ever seen a concert film from a musician or band I didn't already like, I wonder how a film like this would play to someone who has no idea who the Talking Heads were, or even better, to someone who actively disliked their music.It's built, like all…",
#  'Demme\'s approach to filming music is a knife-edge balance of procedural mechanics and intimate observation. As he would for New Order\'s "The Perfect Kiss" video or his later concert docs, Demme tracks the basic nuts and bolts of making music, here narrativized by the Heads\' ingenious conceit of slowly building up from an introduction of Byrne\'s loner ingenuity into the mutant funk outfit that Talking Heads became at its peak. The slow accumulation of gear and members around the frontman…',
#  'well i got to meet david byrne and thank him for his art and then i danced with my crush to “this must be the place” so yeah probably best theatrical experience of my life',
#  "The art of performance. It's hard to imagine a better concert film thanStop Making Sense. It is pretty much the ideal version of one, with great music and careful cinematic craftsmanship. There are so many varied stylistic choices, giving each song a unique feel. David Byrne's very physical presence on stage also contributes, producing something different each time. The film is shot so intimately that it feels like a performance for the cameras, though it isn't. The audience is…",
#  'Before settling in to watch the brand new 4K restoration* of Stop Making Sense, I dropped by its Metacritic page and was amused by this user review:"Hard to like this "movie" if you don\'t like the music much, because there is no story, no dialogue, just a concert."Aside from giggling at them for complaining that a concert film is a concert film, what struck me on this viewing is how that statement doesn\'t just miss the point, but…',
#  'Talking Heads did the impossible, the live music is better than the original. The whole show is insanely fun as it’s filled with tons of energy and dedication. Demme does a great job at making you feel like you’re in the concert. David Bryne is an absolute maniac and a musical genius on stage!It’s easily the best concert film by far!',
#  'best thing ever']

# %%
import itertools
from transformers import pipeline
entity_recognition_nlp  = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english")


def replace_named_entities_with_bert(text, nlp_ner):
    # Use BERT NER pipeline to extract named entities
    entities = nlp_ner(text)
    
    # Replace each recognized entity with a placeholder
    for entity in entities:
        text = text.replace(entity['word'], f"[{entity['entity']}]")
        
    return text
index = df[df['Title'] == 'Alien'].index[0]
documents = df['reviews_extracted'].iloc[index:index+1]
documents = list(itertools.chain.from_iterable(documents))
masked_documents = [replace_named_entities_with_bert(doc, entity_recognition_nlp) for doc in documents]
for mdoc, doc in zip(masked_documents,documents):
    print(mdoc, '\n', doc, '\n\n')
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Damn! This started out so interesting with a couple biologists going into the woods and finding "something".But then there's the crushing disappointment when the story instead cuts to a bunch of asshole teens/twenty-somethings. I have no idea why filmmakers always want to show a group of "friends" who apparently HATE each other in these found footage films. And the usual trope of the cameraman (who the audience can never figure out why he's filming anything that's happening) not saying anything unless it's mean or unpleasant.Didn't take long after that for me to completely lose interst.
#  Damn! This started out so interesting with a couple biologists going into the woods and finding "something".But then there's the crushing disappointment when the story instead cuts to a bunch of asshole teens/twenty-somethings. I have no idea why filmmakers always want to show a group of "friends" who apparently HATE each other in these found footage films. And the usual trope of the cameraman (who the audience can never figure out why he's filming anything that's happening) not saying anything unless it's mean or unpleasant.Didn't take long after that for me to completely lose interst.
#
#
# Straight up bologna cake. Even [I-PER]mork from The [I-MISC]ending [I-MISC] in the 80s was a more believable and realistic wolf.
#  Straight up bologna cake. Even Gmork from The Neverending Story in the 80s was a more believable and realistic wolf.
#
#
# [I-MISC] [I-MISC] [I-MISC] [I-MISC]made me fall asleep(literally)a few times dur[I-MISC]g its runtime, and that's really not a good th[I-MISC]g when [I-MISC] movie is supposed to scare me.I really had a different idea of what this movie was go[I-MISC]g to be about, until I got about fifteen m[I-MISC]utes [I-MISC] and realized it's just ano[I-MISC]r found footage horror movie about a creature [I-MISC] [I-MISC] woods and its stupid, annoy[I-MISC]g victims. If your go[I-MISC]g to do a movie that's been done…
#  Eyes in the Darkmade me fall asleep(literally)a few times during its runtime, and that's really not a good thing when the movie is supposed to scare me.I really had a different idea of what this movie was going to be about, until I got about fifteen minutes in and realized it's just another found footage horror movie about a creature in the woods and its stupid, annoying victims. If your going to do a movie that's been done…
#
#
# starring [I-PER]aul [I-PER][I-PER]nhoorn from this is martin bonn[I-PER]r! that was a [I-PER]l[I-PER]asant sur[I-PER]ris[I-PER].th[I-PER] monst[I-PER]rs ar[I-PER] a bit laughabl[I-PER], but it is oth[I-PER]rwis[I-PER] not t[I-PER]rribl[I-PER]. it follows a lot of your standard ff clich[I-PER]s - s[I-PER]xy young coll[I-PER]g[I-PER] stud[I-PER]nts go to a cabin for th[I-PER] w[I-PER][I-PER]k[I-PER]nd - but it mov[I-PER]s along d[I-PER]c[I-PER]ntly and has som[I-PER] good mom[I-PER]nts in a cav[I-PER].nothing too m[I-PER]morabl[I-PER], but it's not th[I-PER] worst!
#  starring paul eenhoorn from this is martin bonner! that was a pleasant surprise.the monsters are a bit laughable, but it is otherwise not terrible. it follows a lot of your standard ff cliches - sexy young college students go to a cabin for the weekend - but it moves along decently and has some good moments in a cave.nothing too memorable, but it's not the worst!
#
#
# Hard to rate this one. This is a "micro-budget" movie, so it's a little unfair to rate it next to films that have things like "effects" and "props" and "sets". Most of this consists of a couple of people in a location with a camera and a lot of determination, and for that, it's a very admirable effort.I mean that: This aces out a lot of found-footage flicks in terms of structure, storytelling, character, and judicious use of absolutely…
#  Hard to rate this one. This is a "micro-budget" movie, so it's a little unfair to rate it next to films that have things like "effects" and "props" and "sets". Most of this consists of a couple of people in a location with a camera and a lot of determination, and for that, it's a very admirable effort.I mean that: This aces out a lot of found-footage flicks in terms of structure, storytelling, character, and judicious use of absolutely…
#
#
# Nothing much going on here. mostly inoffensive because it's pretty cliche. A servicable effort i guess, but not fun to sit through. The creature is just so low effort it dissapointed me even though my expectations were pretty low by the time it showed up. The whole thing feels like a state college movie project, and not in a good way.
#  Nothing much going on here. mostly inoffensive because it's pretty cliche. A servicable effort i guess, but not fun to sit through. The creature is just so low effort it dissapointed me even though my expectations were pretty low by the time it showed up. The whole thing feels like a state college movie project, and not in a good way.
#
#
# Sure it has shaky cam stuff, sure one group ends up running through the woods at night, yes someone cries in front of the camera, all troupes checked. In spite of this, the story is great, the effects are great, and it's an overall pretty good film.
#  Sure it has shaky cam stuff, sure one group ends up running through the woods at night, yes someone cries in front of the camera, all troupes checked. In spite of this, the story is great, the effects are great, and it's an overall pretty good film.
#
#
# Surprisingly good little ff movie. Definitely worth a watch
#  Surprisingly good little ff movie. Definitely worth a watch
#
#
# Microbudget misadventure that starts off on a promising note and delves into the well-worn annoying group dynamic. By the time things go sideways, it isn’t interesting.
#  Microbudget misadventure that starts off on a promising note and delves into the well-worn annoying group dynamic. By the time things go sideways, it isn’t interesting.
#
#
# This $5,000 budgeted [I-LOC] [I-LOC],[I-LOC] lensed found footage horror feature from writer/director [I-PER]jorn [I-PER] is pure absolute garbage in the manner that it portrays two college aged guys and three college aged couples(who terribly portrayed by equally terrible actors and actresses) spending their wilderness weekends as an unknown evil presence stalks the woods in search of new victims and their souls to snatch,with [I-PER]'s boring storyline,unlikable characters,and woodenly helming doing nothing to enhance nor improve this disatserpiece of an avoidable film in any way or any fashion.
#  This $5,000 budgeted Cascade Mountains,Washington lensed found footage horror feature from writer/director Bjorn Anderson is pure absolute garbage in the manner that it portrays two college aged guys and three college aged couples(who terribly portrayed by equally terrible actors and actresses) spending their wilderness weekends as an unknown evil presence stalks the woods in search of new victims and their souls to snatch,with Anderson's boring storyline,unlikable characters,and woodenly helming doing nothing to enhance nor improve this disatserpiece of an avoidable film in any way or any fashion.
#
#
# This is hilariously awful.
#  This is hilariously awful.
#
#
# Field biologists can get pretty bitchy when feeling left out.
#  Field biologists can get pretty bitchy when feeling left out.
#
#
# Not very good. I really need to understand how come in found footage films, the 20-somethings are just insufferably annoying. So annoying that it doesn't matter who gets killed/gobbled up first.Then there's a unknown cave, located right on a well known trail and an [I-MISC] caretaker who happens to have a book that deciphers the markings in the cave. Sometimes less is more.
#  Not very good. I really need to understand how come in found footage films, the 20-somethings are just insufferably annoying. So annoying that it doesn't matter who gets killed/gobbled up first.Then there's a unknown cave, located right on a well known trail and an Australian caretaker who happens to have a book that deciphers the markings in the cave. Sometimes less is more.
#
#
# It's a pretty sophomoric effort with cheap writing and acting, but you can tell they tried when it comes to an area like sound effects (even if they didn't mic up the actors and just used camera audio as their base, leaving sound really uneven in volume). B for effort, C- for execution.
#  It's a pretty sophomoric effort with cheap writing and acting, but you can tell they tried when it comes to an area like sound effects (even if they didn't mic up the actors and just used camera audio as their base, leaving sound really uneven in volume). B for effort, C- for execution.
#
#
# Entertaining concept that just relies on the wrong actors for its payoff. Some good stuff but a poor end game.
#  Entertaining concept that just relies on the wrong actors for its payoff. Some good stuff but a poor end game.
#
#
# Well shot - cheap and horrifically acted: 3/10[I-MISC] [I-MISC] [I-MISC] [I-MISC] shows [I-PER]jorn [I-PER] knows how to shot an [I-MISC]terest[I-MISC]g look[I-MISC]g found footage film. And [I-MISC] story is fairly [I-MISC]terest[I-MISC]g and creative, resembl[I-MISC]g [I-MISC] [I-PER]ay [I-MISC] many ways. [I-MISC] problem is [I-MISC] [I-MISC] [I-MISC] [I-MISC] is [I-MISC]credibly low budget, thus mak[I-MISC]g most of [I-MISC] film look and feel cheap, especially concern[I-MISC]g [I-MISC] special effects. [I-MISC] act[I-MISC]g is also atrocious amongst [I-MISC] cast, [I-MISC]clud[I-MISC]g poorly written dialogue and characterization (never pick up [I-MISC] cursed rock). [I-MISC] [I-MISC] [I-MISC] [I-MISC] is watchable, but you’ll be laugh[I-MISC]g at it more than anyth[I-MISC]g.
#  Well shot - cheap and horrifically acted: 3/10Eyes in the Dark shows Bjorn Anderson knows how to shot an interesting looking found footage film. And the story is fairly interesting and creative, resembling The Bay in many ways. The problem is Eyes in the Dark is incredibly low budget, thus making most of the film look and feel cheap, especially concerning the special effects. The acting is also atrocious amongst the cast, including poorly written dialogue and characterization (never pick up the cursed rock). Eyes in the Dark is watchable, but you’ll be laughing at it more than anything.
#
#
# TOO [I-ORG]ETERO! also i used to live here im crying
#  TOO HETERO! also i used to live here im crying
#
#
# Another cheapie found footage [I-MISC]foot movie. For what it is it is mildly entertaining and does have a few genuinely creepy moments.
#  Another cheapie found footage Bigfoot movie. For what it is it is mildly entertaining and does have a few genuinely creepy moments.

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
import spacy
entity_recognition_nlp = spacy.load("en_core_web_sm") 

def replace_named_entities(text, nlp):
    doc = nlp(text)
    for ent in doc.ents:
        text = text.replace(ent.text, f"[{ent.label_}]")
    return text

documents = df['reviews_extracted'].iloc[:1]
masked_documents = [replace_named_entities(doc, entity_recognition_nlp) for doc in documents]
documents = list(itertools.chain.from_iterable(documents))

for doc in masked_documents:
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import spacy
#       2 entity_recognition_nlp = spacy.load("en_core_web_sm")
#       4 def replace_named_entities(text, nlp):
#
# ModuleNotFoundError: No module named 'spacy'

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
import torch



documents = df['reviews_extracted'].iloc[:500]
documents = list(itertools.chain.from_iterable(documents))

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# embedding_model = SentenceTransformer('all-MiniLM-L6-v2', device=device)
embedding_model = DistilBertModel.from_pretrained('distilbert-base-uncased')


# Initialize the CountVectorizer (already using stop words)
vectorizer_model = CountVectorizer(stop_words="english")

seed_topic_list = []
# seed_topic_list = [ 
#     ['movie', 'film', 'cinema'],
#     ['scary', 'spooky', 'eek', 'horror'],
#     ['laugh', 'joke' 'comedy', 'funny']
# ]


# Initialize BERTopic with the custom embedding model (GPU-enabled model)
topic_model = BERTopic(
    embedding_model=embedding_model, 
    vectorizer_model=vectorizer_model, 
    # seed_topic_list=seed_topic_list 
    )
topics, probs = topic_model.fit_transform(documents)
df = topic_model.get_topic_info()
df.head(10)

#outputs as a dataframe which is nice. Note that "-1" means outliers; not topics
# Out:
# cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 30
#      20 # seed_topic_list = [
#      21 #     ['movie', 'film', 'cinema'],
#      22 #     ['scary', 'spooky', 'eek', 'horror'],
#    (...)
#      26
#      27 # Initialize BERTopic with the custom embedding model (GPU-enabled model)
#      28 topic_model = BERTopic(
#      29     embedding_model=embedding_model, vectorizer_model=vectorizer_model, seed_topic_list=seed_topic_list )
# ---> 30 topics, probs = topic_model.fit_transform(documents)
#      31 topic_model.get_topic_info()
#
# File c:\Users\fitsl\anaconda3\envs\bert_topic_env\lib\site-packages\bertopic\_bertopic.py:446, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     444 # Guided Topic Modeling
#     445 if self.seed_topic_list is not None and self.embedding_model is not None:
# --> 446     y, embeddings = self._guided_topic_modeling(embeddings)
#     448 # Reduce dimensionality and fit UMAP model
#     449 umap_embeddings = self._reduce_dimensionality(embeddings, y)
#
# File c:\Users\fitsl\anaconda3\envs\bert_topic_env\lib\site-packages\bertopic\_bertopic.py:3954, in BERTopic._guided_topic_modeling(self, embeddings)
#    3952 seed_topic_list = [" ".join(seed_topic) for seed_topic in self.seed_topic_list]
#    3953 seed_topic_embeddings = self._extract_embeddings(seed_topic_list, verbose=self.verbose)
# -> 3954 seed_topic_embeddings = np.vstack([seed_topic_embeddings, embeddings.mean(axis=0)])
#    3956 # Label documents that are most similar to one of the seeded topics
#    3957 sim_matrix = cosine_similarity(embeddings, seed_topic_embeddings)
#
# File c:\Users\fitsl\anaconda3\envs\bert_topic_env\lib\site-packages\numpy\_core\shape_base.py:287, in vstack(tup, dtype, casting)
#     285 if not isinstance(arrs, tuple):
#     286     arrs = (arrs,)
# --> 287 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 0 and the array at index 1 has size 384

# %%
from itertools import chain
# the top 100 best reviewed movies we have in our trope set
documents = list(chain(*df['reviews_extracted'].iloc[:300]))
topics, probs = topic_model.fit_transform(documents)
df_topics = topic_model.get_topic_info()

# %%
# df_topics.to_csv(f"{root}/Data/Topic Modelling/top_100_best_rated_movies_topics.csv")

# %%
df_topics.head(10)
