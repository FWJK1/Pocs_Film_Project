# %% [markdown]
# # Import libraries and setup git root

# %%
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.cluster import KMeans
import torch
import numpy as np
import pandas as pd
import re
import fastparquet
from itertools import chain
import ast

# %%
import os

def find_repo_root(start_path):
    """
    useful general function for finding the (first, closest) repo root so github file paths work the same on different machines 
    """
    current_path = os.path.abspath(start_path)
    
    while True:
        # Check for the existence of the .git directory or other indicators
        if os.path.isdir(os.path.join(current_path, '.git')) or \
           os.path.isfile(os.path.join(current_path, 'README.md')):
            return current_path
        
        parent_path = os.path.dirname(current_path)
        
        # Stop if we reach the root directory
        if parent_path == current_path:
            break
        
        current_path = parent_path

    return None  # Return None if not found

root = find_repo_root(os.getcwd())
root = root.replace('\\', '/')
print(root)
# Out:
# c:/Users/fitsl/Documents/Programming/UVM Programming Classes/PoCS/pocs_project

# %% [markdown]
# # Import the comments data

# %%
df = pd.read_csv(f"{root}/Data/2020_trope_data/Scraped_Data/NER_parsed_reviews.csv")
df['NER_cleaned_reviews'] = df['NER_cleaned_reviews'].apply(ast.literal_eval)

# %%
df.head(2)
# Out:
#                                    letterboxd_search  \
# 0  https://letterboxd.com/search/ABCs+of+Death+2+...
# 1  https://letterboxd.com/search/A+Beautiful+Day+...
#
#                                                  url  \
# 0       https://letterboxd.com/film/abcs-of-death-2/
# 1  https://letterboxd.com/film/a-beautiful-day-in...
#
#                                               actors  \
# 0  ['Eric Jacobus', 'Julian Barratt', 'Ian Virgo'...
# 1  ['Matthew Rhys', 'Tom Hanks', 'Chris Cooper', ...
#
#                                                roles  \
# 0  ['Assassin (Segment "Amateur")', 'Peter Toland...
# 1  ['Lloyd Vogel', 'Fred Rogers', 'Jerry Vogel', ...
#
#                                               studio  \
# 0              ['Drafthouse Films', 'Timpson Films']
# 1  ['TriStar Pictures', 'Tencent Pictures', 'Big ...
#
#                                    reviews_extracted  \
# 0  ['To the creators of "P is for P-P-P-P SCARY!"...
# 1  ['therapy: expensivetom hanks as mr rogers bre...
#
#                                         review_stars  \
# 0  [6, 2, 7, 4, 9, 7, 5, 6, 4, 7, 6, 4, 6, 7, 2, ...
# 1  [6, 7, 7, 6, 7, 8, 8, 8, 8, 6, 6, 8, 8, 8, 8, ...
#
#                                         review_dates  \
# 0  ['14 Feb 2024', '16 Apr 2022', '17 Oct 2018', ...
# 1  ['13 Oct 2019', '27 Nov 2019', '22 Jan 2020', ...
#
#                                 letterboxd_directors  letterboxd_year  \
# 0  ['Rodney Ascher', 'Bill Plympton', 'Erik Matti...             2014
# 1                                ['Marielle Heller']             2019
#
#    letterboxd_rating     letterboxd_genres  \
# 0               5.48            ['Horror']
# 1               7.20  ['History', 'Drama']
#
#                               NameIMDB  IMDB_rating    IMDB_ID  \
# 0                      ABCs of Death 2          5.4  tt2926810
# 1  A Beautiful Day in the Neighborhood          0.0  tt3224458
#
#    letter_USD_Budget  letter_US_Gross  letter_WW_Gross  \
# 0                NaN              NaN           7171.0
# 1         25000000.0       61704055.0       67925733.0
#
#                                  NER_cleaned_reviews
# 0  [To the creators of P is for PPPP SCARY!Cmon g...
# 1  [therapy expensivetom [ACTOR] as [ROLE] breaki...

# %% [markdown]
# # Try some some code for bert generally

# %%
# # Load BERT model and tokenizer
# tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
# model = DistilBertModel.from_pretrained('distilbert-base-uncased')


# # Move model to GPU if available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.to(device)

# # Sample documents
# documents = df['reviews_extracted'].iloc[0]

# # Tokenize and get BERT embeddings for each document
# def get_bert_embeddings(documents):
#     embeddings = []
#     for doc in documents:
#         inputs = tokenizer(doc, return_tensors='pt', truncation=True, padding=True, max_length=512)
#         with torch.no_grad():
#             outputs = model(**inputs)
#         # Take the embeddings of [CLS] token (first token)
#         doc_embedding = outputs.last_hidden_state[0][0].numpy()
#         embeddings.append(doc_embedding)
#     return np.array(embeddings)

# # Obtain embeddings
# embeddings = get_bert_embeddings(documents)

# # Perform K-Means clustering
# num_topics = 2  # Define the number of topics
# kmeans = KMeans(n_clusters=num_topics)
# kmeans.fit(embeddings)

# # Print the cluster assignments
# for i, label in enumerate(kmeans.labels_):
#     print(f"Document {i}: Cluster {label}")

# # Cluster centers (topics)
# print("Cluster Centers (Topics):")
# print(kmeans.cluster_centers_)

# %%
df.sort_values(by='letterboxd_rating', ascending=False, inplace=True)
df
# Out:
#                                        letterboxd_search  \
# 3172        https://letterboxd.com/search/Harakiri+1962/
# 6934   https://letterboxd.com/search/Stop+Making+Sens...
# 1579    https://letterboxd.com/search/Come+and+See+1985/
# 6413   https://letterboxd.com/search/Seven+Samurai+1954/
# 8048   https://letterboxd.com/search/The+Godfather:+P...
# ...                                                  ...
# 10850  https://letterboxd.com/search/Angel+and+Big+Jo...
# 10863  https://letterboxd.com/search/Bakuryuu+Sentai+...
# 10869     https://letterboxd.com/search/Black+Rage+1988/
# 10870  https://letterboxd.com/search/Blood+of+Beasts+...
# 10884  https://letterboxd.com/search/East+of+Kensingt...
#
#                                                      url  \
# 3172               https://letterboxd.com/film/harakiri/
# 6934      https://letterboxd.com/film/stop-making-sense/
# 1579           https://letterboxd.com/film/come-and-see/
# 6413          https://letterboxd.com/film/seven-samurai/
# 8048   https://letterboxd.com/film/the-godfather-part...
# ...                                                  ...
# 10850    https://letterboxd.com/film/angel-and-big-joe//
# 10863  https://letterboxd.com/film/bakuryu-sentai-aba...
# 10869  https://letterboxd.com/film/catch-the-black-su...
# 10870  https://letterboxd.com/film/beauty-and-the-bea...
# 10884   https://letterboxd.com/film/east-of-kensington//
#
#                                                   actors  \
# 3172   ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima I...
# 6934   ['David Byrne', 'Chris Frantz', 'Jerry Harriso...
# 1579   ['Aleksei Kravchenko', 'Olga Mironova', 'Liubo...
# 6413   ['Toshirō Mifune', 'Takashi Shimura', 'Yoshio ...
# 8048   ['Al Pacino', 'Robert Duvall', 'Diane Keaton',...
# ...                                                  ...
# 10850                                                 []
# 10863  ['Kouichiro Nishi', 'Shou Tomita', 'Aiko Ito',...
# 10869  ['Ted Cassidy', 'Chris Robinson', 'Chauncey Lo...
# 10870  ['Jane March', 'William Gregory Lee', 'Justin ...
# 10884  ['Jack Griffo', 'River Alexander', 'Kelsey Lee...
#
#                                                    roles  \
# 3172   ['Hanshiro Tsugumo', 'Motome Chijiiwa', 'Miho ...
# 6934   ['Self - Vocals, Guitar', 'Self - Drums, Vocal...
# 1579   ['Flyora Gayshun', 'Glasha', 'Kosach', 'Rubezh...
# 6413   ['Kikuchiyo', 'Kambei Shimada', 'Gorobei Katay...
# 8048   ['Don Michael Corleone', 'Tom Hagen', 'Kay Cor...
# ...                                                  ...
# 10850                                                 []
# 10863  ['Ryouga Hakua / Aba Red', 'Yukito Sanjou / Ab...
# 10869  ['Striker', 'Sunshine', 'Levi (As Anthony Scot...
# 10870  ['Freya', 'Sven', 'Eric', 'Beast / Agnar', 'In...
# 10884  ['Peter Pan', 'Slightly', 'Wendy Darling', 'Mi...
#
#                                                   studio  \
# 3172                                        ['Shochiku']
# 6934   ['Talking Heads Films', 'Arnold Stiefel Company']
# 1579                          ['Belarusfilm', 'Mosfilm']
# 6413                                            ['TOHO']
# 8048   ['Paramount Pictures', 'The Coppola Company', ...
# ...                                                  ...
# 10850                                                 []
# 10863                                   ['Toei Company']
# 10869                    ['Camelot Entertainment Group']
# 10870    ['Crimson Knight', 'Peakviewing Transatlantic']
# 10884                                                 []
#
#                                        reviews_extracted  \
# 3172   ['I am an idiot.Why is it that I still dread w...
# 6934   ['SAME AS IT EVER WASSAME AS IT EVER WASSAME A...
# 1579   ['as soon as this film ended i went online and...
# 6413   ['too many sweaty ass cheeks, 5 stars', 'this ...
# 8048   ["young, totally fuckable al pacino and robert...
# ...                                                  ...
# 10850  ['The devil is a very big angel, but a very li...
# 10863  ['A bikini monster that shoots a beam that mak...
# 10869  ['In 1859, a pair of enslaved brothers, Sunshi...
# 10870                                                 []
# 10884  ['One Short Film Every Day:Film #72A unique tw...
#
#                                             review_stars  \
# 3172   [10, 10, <NA>, 10, 10, 10, <NA>, 9, 10, 10, 9,...
# 6934   [10, 10, 10, 10, 10, 10, 10, 10, 9, 10, 10, 10...
# 1579   [10, 10, 10, 9, 10, <NA>, 10, 10, 10, 10, 10, ...
# 6413   [10, 9, 10, 10, 8, 10, 10, 9, 10, 10, 10, 10, ...
# 8048   [10, 10, 10, <NA>, 10, 8, 9, 8, 10, 10, 8, 7, ...
# ...                                                  ...
# 10850         [5, 6, 7, 5, 6, 5, 5, 6, 6, <NA>, <NA>, 6]
# 10863        [6, <NA>, 5, 6, 6, 6, 7, 2, 10, 5, 7, 5, 7]
# 10869  [2, 1, 1, 2, 1, 6, 1, 2, 4, 5, 1, 1, 3, 1, 1, ...
# 10870                                                 []
# 10884  [8, 7, 9, 5, 9, 4, 8, <NA>, 10, 9, 8, 4, 6, 4,...
#
#                                             review_dates  \
# 3172   ['01 Dec 2013', '', '26 Jan 2024', '21 Jun 202...
# 6934   ['27 Mar 2020', '18 Sep 2023', '06 Aug 2013', ...
# 1579   ['10 Aug 2020', '25 Aug 2013', '09 Jan 2020', ...
# 6413   ['23 Apr 2020', '09 May 2020', '', '01 Mar 201...
# 8048   ['27 Oct 2019', '06 Oct 2017', '12 Jul 2019', ...
# ...                                                  ...
# 10850  ['25 Jul 2023', '20 Jun 2024', '01 May 2020', ...
# 10863  ['22 Nov 2022', '08 Sep 2022', '07 Mar 2018', ...
# 10869  ['19 Feb 2023', '08 Mar 2018', '09 Feb 2023', ...
# 10870                                                 []
# 10884  ['10 Jan 2014', '11 May 2023', '05 May 2023', ...
#
#            letterboxd_directors  letterboxd_year  letterboxd_rating  \
# 3172       ['Masaki Kobayashi']             1962               9.38
# 6934         ['Jonathan Demme']             1984               9.36
# 1579            ['Elem Klimov']             1985               9.26
# 6413         ['Akira Kurosawa']             1954               9.22
# 8048   ['Francis Ford Coppola']             1974               9.18
# ...                         ...              ...                ...
# 10850          ['Bert Salzman']             1975                NaN
# 10863        ['Satoshi Morota']             2003                NaN
# 10869        ['Chris Robinson']             1972                NaN
# 10870          ['David Lister']             2005                NaN
# 10884          ['Kellen Moore']             2013                NaN
#
#                                        letterboxd_genres  \
# 3172                      ['History', 'Drama', 'Action']
# 6934                            ['Music', 'Documentary']
# 1579                                    ['War', 'Drama']
# 6413                                 ['Drama', 'Action']
# 8048                                  ['Crime', 'Drama']
# ...                                                  ...
# 10850                                          ['Drama']
# 10863  ['Action', 'Science Fiction', 'Fantasy', 'Adve...
# 10869                                ['Action', 'Drama']
# 10870  ['Thriller', 'Drama', 'Adventure', 'Fantasy', ...
# 10884                               ['Drama', 'Fantasy']
#
#                                                 NameIMDB  IMDB_rating  \
# 3172                                            Harakiri          8.7
# 6934                                   Stop Making Sense          8.5
# 1579                                        Come and See          8.2
# 6413                                       Seven Samurai          8.7
# 8048                              The Godfather: Part II          9.0
# ...                                                  ...          ...
# 10850                                  Angel and Big Joe          6.8
# 10863  Bakuryuu Sentai Abaranger Deluxe: Abare Summer...          6.8
# 10869                                         Black Rage          0.0
# 10870                                    Blood of Beasts          4.3
# 10884                                 East of Kensington          7.5
#
#          IMDB_ID  letter_USD_Budget  letter_US_Gross  letter_WW_Gross  \
# 3172   tt0056058                NaN              NaN          15222.0
# 6934   tt0088178          1200000.0       10306902.0       12471520.0
# 1579   tt0091251          2500000.0              NaN       20929648.0
# 6413   tt0047478           580000.0              NaN              NaN
# 8048   tt0071562         13000000.0       47834595.0       47962897.0
# ...          ...                ...              ...              ...
# 10850  tt0072646                NaN              NaN              NaN
# 10863  tt0860893                NaN              NaN              NaN
# 10869  tt0180546                NaN              NaN              NaN
# 10870  tt0338769                NaN              NaN              NaN
# 10884  tt3211594                NaN              NaN              NaN
#
#                                      NER_cleaned_reviews
# 3172   [I am an idiot Why is it that I still dread wa...
# 6934   [SAME AS IT EVER WASSAME AS IT EVER WASSAME AS...
# 1579   [as soon as this film ended i went online and ...
# 6413   [too many sweaty ass cheeks, 5 stars, this is ...
# 8048   [young, totally fuckable [ACTOR] and [ACTOR] d...
# ...                                                  ...
# 10850  [The devil is a very big angel, but a very lit...
# 10863  [A bikini monster that shoots a beam that make...
# 10869  [In 1859, a pair of enslaved brothers, Sunshin...
# 10870                                                 []
# 10884  [One Short Film Every DayFilm 72A unique twist...
#
# [10928 rows x 19 columns]

# %%
# import os
# import time
# import numpy as np
# import torch
# from concurrent.futures import ProcessPoolExecutor, as_completed
# from sentence_transformers import SentenceTransformer
# from itertools import chain
# import traceback  # For better exception logging

# # Example data from your DataFrame (replace df with your actual DataFrame)
# documents = list(chain(*df['NER_cleaned_reviews'].iloc[:2000]))

# # Function to encode a batch of documents
# def process_batch(batch):
#     try:
#         print(f"Initializing model for batch with {len(batch)} documents", flush=True)
#         # Initialize the model inside the worker to avoid issues with multiprocessing
#         device = "cuda" if torch.cuda.is_available() else "cpu"
#         print(f"Using device: {device} for this batch", flush=True)
#         embedding_model = SentenceTransformer('all-MiniLM-L6-v2', device=device)

#         print(f"Processing batch with {len(batch)} documents", flush=True)
#         ret = embedding_model.encode(batch, show_progress_bar=True)
#         print(f"Batch with {len(batch)} documents processed", flush=True)
#         return ret
#     except Exception as e:
#         print(f"Error processing batch: {e}", flush=True)
#         # Log the full stack trace for better debugging
#         print("Stack trace:", flush=True)
#         traceback.print_exc()
#         return None  # Return None if there's an error

# # Function to test parallel processing with different numbers of processes
# def test_parallel_processing(documents, batch_size, num_processes_list):
#     # Split documents into batches
#     batches = [documents[i:i + batch_size] for i in range(0, min(10 * batch_size, len(documents)), batch_size)]
    
#     # Record performance for each process count
#     performance = {}

#     for num_processes in num_processes_list:
#         print(f"Trying {num_processes} processes at {time.time()}", flush=True)
#         start_time = time.time()

#         # Run the multiprocessing pool to calculate embeddings using ProcessPoolExecutor
#         with ProcessPoolExecutor(max_workers=num_processes) as executor:
#             futures = [executor.submit(process_batch, batch) for batch in batches]

#             # Process results as they come in
#             for future in as_completed(futures):
#                 try:
#                     result = future.result()  # This will raise an exception if the worker fails
#                     if result is None:
#                         print("One of the batches failed. Continuing with others.", flush=True)
#                 except Exception as e:
#                     print(f"{e} failed")
        

#         # Record the time taken for the current number of processes
#         end_time = time.time()
#         performance[num_processes] = end_time - start_time
#         print(f"Time with {num_processes} processes: {end_time - start_time} seconds", flush=True)

#     # Find the optimal number of processes (the one with the shortest time)
#     optimal_num_processes = min(performance, key=performance.get)
#     print(f"Optimal number of processes: {optimal_num_processes}", flush=True)

#     return optimal_num_processes


# # Main function to calculate embeddings
# def calculate_embeddings(documents):
#     # Use CPU only for debugging to avoid GPU memory issues
#     device = "cpu"  # Force using CPU
#     print(f"Using device: {device}", flush=True)

#     # Set batch size for splitting documents
#     batch_size = 3  # Small batch size to avoid memory overload

#     # Get number of CPU cores for reference
#     num_cores = os.cpu_count()
#     print(f"Number of CPU cores: {num_cores}", flush=True)

#     # Test different process counts (1, 2, 4, 8 for example)
#     num_processes_list = [2, 4]  # Start with smaller number of processes for testing

#     optimal_num_processes = test_parallel_processing(documents, batch_size, num_processes_list)

#     # Split documents into batches again for the optimal number of processes
#     batches = [documents[i:i + batch_size] for i in range(0, len(documents), batch_size)]

#     # Use the optimal number of processes to calculate embeddings
#     with ProcessPoolExecutor(max_workers=optimal_num_processes) as executor:
#         futures = [executor.submit(process_batch, batch) for batch in batches]

#         # Wait for all futures to complete
#         embeddings = []
#         for future in as_completed(futures):
#             result = future.result()
#             if result is not None:
#                 embeddings.append(result)

#     # Concatenate embeddings from all batches into a single array
#     embeddings = np.concatenate(embeddings, axis=0)

#     return embeddings


# # Call the main function to calculate embeddings
# embeddings = calculate_embeddings(documents)
# print(f"Calculated embeddings shape: {embeddings.shape}", flush=True)

# %% [markdown]
# # BerTopic gives more inutitive topics

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
from umap import UMAP


# sort to get the top reviews

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# chain from itertools to get the reviews into a bigger list
documents = list(chain(*df['NER_cleaned_reviews']))
print(documents[1])

# init bert and fit the model on the docs

embed_model = 'paraphrase-MiniLM-L3-v2'

embedding_model = SentenceTransformer('all-MiniLM-L6-v2', device=device)
vectorizer_model = CountVectorizer(stop_words='english', max_features=1000)
umap_model = UMAP(n_neighbors=15, n_components=5, metric='cosine', )  # n_jobs=-1 uses all cores

# Initialize BERTopic with custom UMAP and HDBSCAN models
topic_model = BERTopic(
    # vectorizer_model=vectorizer_model,
    embedding_model=embedding_model,
    umap_model=umap_model,
    verbose=True,
    top_n_words=10,
    min_topic_size=50
)

# Fit the topic model
topics, probabilities = topic_model.fit_transform(documents)

#Get the topic information and 
df_topics = topic_model.get_topic_info()
df_topics.head()
# Out:
# Using device: cpu
# honor in the individual is virtuehonor in a society is madness
# 2024-12-09 23:20:33,220 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/30708 [00:00<?, ?it/s]
# 2024-12-10 01:31:53,457 - BERTopic - Embedding - Completed ✓
# 2024-12-10 01:31:53,457 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-10 02:04:34,860 - BERTopic - Dimensionality - Completed ✓
# 2024-12-10 02:04:34,889 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-10 02:08:37,931 - BERTopic - Cluster - Completed ✓
# 2024-12-10 02:08:38,105 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-12-10 02:09:04,660 - BERTopic - Representation - Completed ✓
#    Topic   Count                                Name  \
# 0     -1  588743                     -1_and_to_it_of
# 1      0   15870                   0_und_der_die_ist
# 2      1   10069    1_horror_halloween_ghost_haunted
# 3      2    7934  2_director_his_filmmaker_directors
# 4      3    7630                  3_filme_um_uma_que
#
#                                       Representation  \
# 0  [and, to, it, of, the, is, that, actor, this, ...
# 1  [und, der, die, ist, ein, ich, mit, das, zu, den]
# 2  [horror, halloween, ghost, haunted, hunt, dail...
# 3  [director, his, filmmaker, directors, films, h...
# 4    [filme, um, uma, que, em, de, mas, com, da, os]
#
#                                  Representative_Docs
# 0  [For a movie that has a reputation for being p...
# 1  [Der Film fhlte sich nicht so lange an wie bef...
# 2  [I figured since we are so close to Halloween ...
# 3  [[DIRECTOR] O K, [DIRECTOR], [DIRECTOR] the di...
# 4  [esse um dos muitos filmes que meu pai me fez ...

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
topic_model.push_to_hf_hub(
    repo_id="FJK_letterboxd_review_vers2_bigger_topics",
    save_ctfidf=True,
    private=True)
# Out:
# ctfidf.safetensors:   0%|          | 0.00/44.6M [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# ctfidf_config.json:   0%|          | 0.00/22.5M [00:00<?, ?B/s]
# topic_embeddings.safetensors:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/fitzlikeglove/FJK_letterboxd_review_vers2_bigger_topics/commit/820691615b954c5f1138edb7bcf23b47e266caae', commit_message='Add BERTopic model', commit_description='', oid='820691615b954c5f1138edb7bcf23b47e266caae', pr_url=None, repo_url=RepoUrl('https://huggingface.co/fitzlikeglove/FJK_letterboxd_review_vers2_bigger_topics', endpoint='https://huggingface.co', repo_type='model', repo_id='fitzlikeglove/FJK_letterboxd_review_vers2_bigger_topics'), pr_revision=None, pr_num=None)

# %%
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 3), min_df=10)
topic_model.update_topics(documents, vectorizer_model=vectorizer_model)

# %%
topic_model.visualize_topics([i for i in range(200)])

# %%
topic_model.visualize_barchart([i for i in range(20)])

# %%
topic_model.visualize_heatmap([i for i in range(50)])

# %%
# createa dataframe with docs and topics and then update with topic representations, for easy storage.
df_labeled_reviews = pd.DataFrame({
    'review' : documents,
    'topic' : topics
})

topic_representations = {
    topic_num: ", ".join([word for word, _ in words[:3]])  # Top 3 words as representation
    for topic_num, words in topic_model.get_topics().items()
}
topic_representations[-1] = "Outlier"  # Optional: Label for outliers

# Step 3: Map topic numbers to their representations
df_labeled_reviews['topic_representation'] = df_labeled_reviews['topic'].map(topic_representations)

# # Step 4: Save the updated DataFrame
df_labeled_reviews.to_parquet(f"{root}/Data/Topic_Modelling/vers2_labeled_reviews_with_representations.parquet")

# %%
df.columns
# Out:
# Index(['letterboxd_search', 'url', 'actors', 'roles', 'studio',
#        'reviews_extracted', 'review_stars', 'review_dates',
#        'letterboxd_directors', 'letterboxd_year', 'letterboxd_rating',
#        'letterboxd_genres', 'NameIMDB', 'IMDB_rating', 'IMDB_ID',
#        'letter_USD_Budget', 'letter_US_Gross', 'letter_WW_Gross',
#        'NER_cleaned_reviews'],
#       dtype='object')

# %%
def safe_literal_eval(cell):
    if pd.isna(cell):  # Handle already missing cells
        return None
    try:
        # Replace '<NA>' with 'None' to make it valid Python
        cleaned_cell = re.sub(r"<NA>", "None", cell)
        return eval(cleaned_cell)  # Use eval here because it's safer for controlled input like this
    except (ValueError, SyntaxError):
        return None  # Return None for invalid formats
df = pd.read_csv(f"{root}/Data/2020_trope_data/Scraped_Data/NER_parsed_reviews.csv")
df['NER_cleaned_reviews'] = df['NER_cleaned_reviews'].apply(ast.literal_eval)
df['review_stars'] = df['review_stars'].apply(safe_literal_eval)
df['review_dates'] = df['review_dates'].apply(safe_literal_eval)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[88], line 10
#       8     except (ValueError, SyntaxError):
#       9         return None  # Return None for invalid formats
# ---> 10 df = pd.read_csv(f"{root}/Data/2020_trope_data/Scraped_Data/NER_parsed_reviews.csv")
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory

# %%
df_exploded=None
df_merged_no_outlier=None

# %%
df_exploded =df.explode(['review_stars_parse', 'NER_cleaned_reviews','review_dates_parse' ])
df_exploded.shape
# Out:
# (982686, 21)

# %%
df_merged = pd.merge(
    left=df_labeled_reviews,
    right=df_exploded,
    right_on='NER_cleaned_reviews',
    left_on='review',
    how='left'
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df_merged = pd.merge(
#       2     left=df_labeled_reviews,
#       3     right=df_exploded,
#       4     right_on='NER_cleaned_reviews',
#       5     left_on='review',
#       6     how='left'
#       7 )
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\reshape\merge.py:863, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     858 left.index = join_index
#     860 if right_indexer is not None and not is_range_indexer(
#     861     right_indexer, len(right)
#     862 ):
# --> 863     rmgr = right._mgr.reindex_indexer(
#     864         join_index,
#     865         right_indexer,
#     866         axis=1,
#     867         copy=False,
#     868         only_slice=True,
#     869         allow_dups=True,
#     870         use_na_proxy=True,
#     871     )
#     872     right = right._constructor_from_mgr(rmgr, axes=rmgr.axes)
#     873 right.index = join_index
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 669. MiB for an array with shape (5, 17547121) and data type float64

# %%
df_merged = df_merged.drop(columns=['NER_cleaned_reviews', 'reviews_extracted'])

# %%
df_merged_no_outlier = df_merged[df_merged['topic'] != -1]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df_merged_no_outlier = df_merged[df_merged['topic'] != -1]
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\frame.py:4155, in DataFrame._getitem_bool_array(self, key)
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
# -> 4155 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\fitsl\anaconda3\envs\fjk_bertopic\lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 1.37 GiB for an array with shape (11, 16694756) and data type object

# %%
df_merged_no_outlier.head(3)
# Out:
#                                               review  topic  \
# 3  God damn what an impeccable film Not dated in ...     11
# 5  Probably the greatest film ever a film about h...    107
# 8  Absolutely riveting I didnt look away for a si...     61
#
#                         topic_representation  \
# 3                   japanese, samurai, japan
# 5  best movie, greatest film, greatest movie
# 8       letterboxd, reviews, film letterboxd
#
#                               letterboxd_search  \
# 3  https://letterboxd.com/search/Harakiri+1962/
# 5  https://letterboxd.com/search/Harakiri+1962/
# 8  https://letterboxd.com/search/Harakiri+1962/
#
#                                      url  \
# 3  https://letterboxd.com/film/harakiri/
# 5  https://letterboxd.com/film/harakiri/
# 8  https://letterboxd.com/film/harakiri/
#
#                                               actors  \
# 3  ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima I...
# 5  ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima I...
# 8  ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima I...
#
#                                                roles        studio  \
# 3  ['Hanshiro Tsugumo', 'Motome Chijiiwa', 'Miho ...  ['Shochiku']
# 5  ['Hanshiro Tsugumo', 'Motome Chijiiwa', 'Miho ...  ['Shochiku']
# 8  ['Hanshiro Tsugumo', 'Motome Chijiiwa', 'Miho ...  ['Shochiku']
#
#                                         review_stars  \
# 3  [10, 10, <NA>, 10, 10, 10, <NA>, 9, 10, 10, 9,...
# 5  [10, 10, <NA>, 10, 10, 10, <NA>, 9, 10, 10, 9,...
# 8  [10, 10, <NA>, 10, 10, 10, <NA>, 9, 10, 10, 9,...
#
#                                         review_dates  letterboxd_directors  \
# 3  ['01 Dec 2013', '', '26 Jan 2024', '21 Jun 202...  ['Masaki Kobayashi']
# 5  ['01 Dec 2013', '', '26 Jan 2024', '21 Jun 202...  ['Masaki Kobayashi']
# 8  ['01 Dec 2013', '', '26 Jan 2024', '21 Jun 202...  ['Masaki Kobayashi']
#
#    letterboxd_year  letterboxd_rating               letterboxd_genres  \
# 3             1962               9.38  ['History', 'Drama', 'Action']
# 5             1962               9.38  ['History', 'Drama', 'Action']
# 8             1962               9.38  ['History', 'Drama', 'Action']
#
#    NameIMDB  IMDB_rating    IMDB_ID  letter_USD_Budget  letter_US_Gross  \
# 3  Harakiri          8.7  tt0056058                NaN              NaN
# 5  Harakiri          8.7  tt0056058                NaN              NaN
# 8  Harakiri          8.7  tt0056058                NaN              NaN
#
#    letter_WW_Gross
# 3          15222.0
# 5          15222.0
# 8          15222.0

# %%
import seaborn as sns

# %%
# Verify the new documents
new_documents = list(chain(*df['NER_cleaned_reviews'].iloc[:10]))
assert all(isinstance(doc, str) for doc in new_documents), "All documents must be strings"

# Optional: Use precomputed embeddings
# embeddings = embedding_model.encode(new_documents)
# print("Embeddings shape:", embeddings.shape)

# Transform the new documents
topics, probabilities = topic_model.transform(new_documents)

# Output results
print(topics)
print(probabilities)

# %%
-- break
# Out:
#   Cell In[60], line 1
#     -- break
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now turn it into a function

# %%
def topic_model(documents):

    # init bert and fit the model on the docs
    vectorizer_model = CountVectorizer(stop_words='english', max_features=1000)
    topic_model = BERTopic(vectorizer_model=vectorizer_model, verbose=True)
    __, __ = topic_model.fit_transform(documents)

    df_topics = topic_model.get_topic_info()
    return df_topics

# %%
df_topics = topic_model(list(chain(*df['reviews_extracted'].iloc[:800])))
df_topics.head()
# Out:
# 2024-11-23 12:31:56,035 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 2396/2396 [14:23<00:00,  2.77it/s]
# 2024-11-23 12:46:22,708 - BERTopic - Embedding - Completed ✓
# 2024-11-23 12:46:22,708 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-11-23 12:46:42,747 - BERTopic - Dimensionality - Completed ✓
# 2024-11-23 12:46:42,749 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-11-23 12:46:49,023 - BERTopic - Cluster - Completed ✓
# 2024-11-23 12:46:49,045 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-11-23 12:46:53,278 - BERTopic - Representation - Completed ✓
#    Topic  Count                              Name  \
# 0     -1  28516           -1_peak_just_love_movie
# 1      0    877                0_um_uma_filme_com
# 2      1    792                    1_el_en_una_la
# 3      2    561  2_memories_memory_existence_past
# 4      3    542            3_youre_hold_know_want
#
#                                       Representation  \
# 0  [peak, just, love, movie, im, like, good, watc...
# 1   [um, uma, filme, com, em, os, mais, da, na, mas]
# 2   [el, en, una, la, pelcula, es, lo, las, los, ms]
# 3  [memories, memory, existence, past, fear, deat...
# 4  [youre, hold, know, want, dont, miss, live, lo...
#
#                                  Representative_Docs
# 0  [Taking place in Allied-occupied Germany, Ross...
# 1  ["O Tango de Satã" é um filme do Béla Tarr que...
# 2  [Una visión cruda e incómoda de la población m...
# 3  [Doubt lurks behind every step, and every conc...
# 4  ["You talk of showing things... I don't know, ...

# %%
df_topics.head(15)
# Out:
#     Topic  Count                                Name  \
# 0      -1  28516             -1_peak_just_love_movie
# 1       0    877                  0_um_uma_filme_com
# 2       1    792                      1_el_en_una_la
# 3       2    561    2_memories_memory_existence_past
# 4       3    542              3_youre_hold_know_want
# 5       4    540                   4_und_der_ich_den
# 6       5    302                     5_et_le_des_est
# 7       6    255          6_wars_star_trilogy_george
# 8       7    250         7_crying_tears_sad_emotions
# 9       8    247  8_soundtrack_musical_music_concert
# 10      9    246      9_chaplin_charlie_12_suffering
# 11     10    231           10_dad_mom_father_parents
# 12     11    229    11_chaplin_charlie_silent_comedy
# 13     12    223        12_lynch_david_straight_road
# 14     13    222   13_war_message_william_impressive
#
#                                        Representation  \
# 0   [peak, just, love, movie, im, like, good, watc...
# 1    [um, uma, filme, com, em, os, mais, da, na, mas]
# 2    [el, en, una, la, pelcula, es, lo, las, los, ms]
# 3   [memories, memory, existence, past, fear, deat...
# 4   [youre, hold, know, want, dont, miss, live, lo...
# 5   [und, der, ich, den, zu, ein, ist, das, wie, mit]
# 6     [et, le, des, est, plus, la, mais, en, si, que]
# 7   [wars, star, trilogy, george, episode, origina...
# 8   [crying, tears, sad, emotions, started, heartb...
# 9   [soundtrack, musical, music, concert, song, so...
# 10  [chaplin, charlie, 12, suffering, kid, son, 10...
# 11  [dad, mom, father, parents, mother, age, famil...
# 12  [chaplin, charlie, silent, comedy, modern, gen...
# 13  [lynch, david, straight, road, ride, filmograp...
# 14  [war, message, william, impressive, wars, powe...
#
#                                   Representative_Docs
# 0   [Taking place in Allied-occupied Germany, Ross...
# 1   ["O Tango de Satã" é um filme do Béla Tarr que...
# 2   [Una visión cruda e incómoda de la población m...
# 3   [Doubt lurks behind every step, and every conc...
# 4   ["You talk of showing things... I don't know, ...
# 5   [City of Life and Death wird häufig mit Schind...
# 6   [Beaucoup de longueurs et de répétitions avant...
# 7   [I would love to see a whole Star Wars movie f...
# 8   [I'm crying after laughing so hard. WHAT A PER...
# 9   [midsommar (2019) if it was a horny musical, T...
# 10  [رحلتي مع القصة لم تنتهي مع إنتهاء مدة الفيلم،...
# 11  [That one dad from Jimmy Neutron be like:, Ste...
# 12  [charlie chaplin seems like the fella to text ...
# 13  [david lynch had absolutely no business making...
# 14  [there is no such thing as a good war movie, t...

# %% [markdown]
# Works okay, but topics are largely jus specific movies; we want NER to make it more robust.

# %% [markdown]
# # Named Entity Recognition

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = " Straight up bologna cake. Even Gmork from The Neverending Story in the 80s was a more believable and realistic wolf."

ner_results = nlp(example)
print(ner_results)
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'entity': 'B-PER', 'score': 0.9953448, 'index': 9, 'word': 'G', 'start': 32, 'end': 33}, {'entity': 'I-PER', 'score': 0.8693475, 'index': 10, 'word': '##mor', 'start': 33, 'end': 36}, {'entity': 'I-PER', 'score': 0.82671, 'index': 11, 'word': '##k', 'start': 36, 'end': 37}, {'entity': 'B-MISC', 'score': 0.9859154, 'index': 13, 'word': 'The', 'start': 43, 'end': 46}, {'entity': 'I-MISC', 'score': 0.9771259, 'index': 14, 'word': 'Never', 'start': 47, 'end': 52}, {'entity': 'I-MISC', 'score': 0.9806553, 'index': 15, 'word': '##ending', 'start': 52, 'end': 58}, {'entity': 'I-MISC', 'score': 0.9830625, 'index': 16, 'word': 'Story', 'start': 59, 'end': 64}]

# %%
def replace_named_entities_with_bert(text, nlp_ner):
    # Use BERT NER pipeline to extract named entities
    entities = nlp_ner(text)
    # Replace each recognized entity with a placeholder
    # Sort entities by their position (from end to start)
    for entity in sorted(entities, key=lambda x: x['start'], reverse=True):
        text = text[:entity['start']] + f"[{entity['entity']}]"+ text[entity['end']:]

    text = re.sub(r'\[B-([A-Z]+)\](\s*\[I-\1\])+', r'[\1]', text)
    text = re.sub(r'\[[BI]-(\w+)\]', r'[\1]', text)


    # text = re.sub(r'\[B-|I-](PER|ORG|LOC|MISC)\]', r'[\1]', text)
    # print(text)
    return text

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification

# Load the pre-trained NER model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

# Sample dataframe structure (make sure your dataframe is set correctly)
try:
    documents = df.loc[df['Title'] == 'Alien', 'reviews_extracted']
    documents = list(chain.from_iterable(documents))
    
    # Apply entity replacement on each document
    masked_documents = [replace_named_entities_with_bert(doc, nlp) for doc in documents]

    # Print the original and masked documents
    for mdoc, doc in zip(masked_documents, documents):
        print(doc, '\n', mdoc, '\n\n')
except IndexError:
    print("No documents found with the title 'Alien'. Please check the dataframe.")
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# I'm starting to feel like the Weyland-Yutani Corporation does not have our best interests at heart.
#  I'm starting to feel like the [ORG] does not have our best interests at heart.
#
#
# every time they bullied andy i wanted to punch a hole thru the fucking screen
#  every time they bullied andy i wanted to punch a hole thru the fucking screen
#
#
# I can just feel the people who are getting ready to complain about "fan service", but I'm a fan and I wasfucking SERVICED!
#  I can just feel the people who are getting ready to complain about "fan service", but I'm a fan and I wasfucking SERVICED!
#
#
# things not to bring into space• pregnant women• british people
#  things not to bring into space• pregnant women• british people
#
#
# Priscilla Presley goes to space, only this time, the Xenomorphs are so much meaner than Elvis.
#  [PER][PER] goes to space, only this time, the [MISC] are so much meaner than [PER].
#
#
# Uncanny CGI recreation of the dead is arguablyscarier than any xenomorph
#  Uncanny [MISC]GI recreation of the dead is arguablyscarier than any xenomorph
#
#
# The partsthat are an ALIEN splatter movie are a real blast. The parts that are an ALIEN legacy sequel are mostly fucking stupid.
#  The partsthat are an [MISC][ORG][MISC] splatter movie are a real blast. The parts that are an [MISC][ORG][MISC] legacy sequel are mostly fucking stupid.
#
#
# from now on when i think about God i’m going to envision cailee spaeny with a gun
#  from now on when i think about [PER] i’m going to envision cailee spaeny with a gun
#
#
# Stupidly well directed and tense for what is ultimately a pretty standard legacy sequel. Multiple sequences had me gripped and temporarily paralyzed with fear (shout out to the anti-gravity acid scene for being particularly unique) before I remembered "Oh yeah, I don't need to speculate about anyone's survival since I've seen the original Alien." It feels like a crime to waste Fede Álvarez, Cailee Spaeny, and David Jonsson's immense talents on something so predictable and unambitious, but I'd be lying…
#  Stupidly well directed and tense for what is ultimately a pretty standard legacy sequel. Multiple sequences had me gripped and temporarily paralyzed with fear (shout out to the anti-gravity acid scene for being particularly unique) before I remembered "Oh yeah, I don't need to speculate about anyone's survival since I've seen the original [MISC]." It feels like a crime to waste [PER]l[PER][PER], [PER], and [PER]'s immense talents on something so predictable and unambitious, but I'd be lying…
#
#
# i could be a good mu/th/ur
#  i could be a good mu/th/ur
#
#
# Would've definitely appreciated subtitles for some of these characters
#  Would've definitely appreciated subtitles for some of these characters
#
#
# Well it’s the best film I’ve seen with an acid vagina
#  Well it’s the best film I’ve seen with an acid vagina
#
#
# It was only a matter of time until anAlienfilm caved to the pressures of fan service. Whether this is a byproduct of the Disney acquisition or the writers own insecurities, we’ll never really know, but it’s a sad day when theAlienseries turns into the MCU and regurgitates iconic lines then awkwardly pauses for some applause.It’s a movie that’s so focused on being a “love letter” it has no motivation to be interesting itself or establish an…
#  It was only a matter of time until an[ORG][ORG] caved to the pressures of fan service. Whether this is a byproduct of the [ORG] acquisition or the writers own insecurities, we’ll never really know, but it’s a sad day when the[ORG][ORG] turns into the [ORG] and regurgitates iconic lines then awkwardly pauses for some applause.It’s a movie that’s so focused on being a “love letter” it has no motivation to be interesting itself or establish an…
#
#
# they grow up so fast
#  they grow up so fast
#
#
# ALIEN: ROMULUS brings the ALIEN franchise back to its roots: Scary Creature on Spaceship Slowly Killing Everyone On Board.Fede Alvarez can direct the hell out of a slasher set piece and the movie’s combination of visual and practical effects is spectacular. There are a handful of tie-ins to ALIEN lore but by and large this is a movie that can be enjoyed on its own.I loved it.Read my review at Decoding Everything
#  AL[MISC][MISC]: [PER][ORG][PER] brings the [MISC] franchise back to its roots: [MISC] on [MISC] Slowly Killing Everyone On Board.[PER][PER] can direct the hell out of a slasher set piece and the movie’s combination of visual and practical effects is spectacular. There are a handful of tie-ins to [MISC] lore but by and large this is a movie that can be enjoyed on its own.I loved it.Read my review at Decod[MISC] [MISC]
#
#
# it's got the ambient Normal Evil of a legacy sequel that's just a rehash of every single previous entry but it enters bold new territories of Repulsive Evil by making the main antagonist a ghoulish AI deepfake of ian holm. prison for all involved
#  it's got the ambient [MISC] of a legacy sequel that's just a rehash of every single previous entry but it enters bold new territories of [MISC][MISC] by making the main antagonist a ghoulish AI deepfake of ian holm. prison for all involved
#
#
# I don’t even hate The Force Awakens but I’m not sure if Alien needed its own Force Awakens
#  I don’t even hate [MISC] but I’m not sure if [MISC] needed its own [MISC]
#
#
# id recommend wearing a diaper because shitting your pants is a guarantee
#  id recommend wearing a diaper because shitting your pants is a guarantee
#
#
# Somehow, the Xenomorph returned.More specifically — if I can dare to reveal what happens in the very first shot of “Alien: Romulus” — employees of the Weyland-Yutani Corporation fished around deep space until they found the exact specimen that Ellen Ripley ejected from the airlock of the Nostromo at the end of “Alien,” and then decided to bring its seemingly lifeless body aboard the space station Renaissance for further study. Bad idea! It turns out that “the perfect organism”…
#  Somehow, the [MISC] returned.More specifically — if I can dare to reveal what happens in the very first shot of “[MISC]om[MISC]” — employees of the [ORG] fished around deep space until they found the exact specimen that [PER] ejected from the airlock of the [ORG][LOC] at the end of [MISC][MISC],” and then decided to bring its seemingly lifeless body aboard the space station [LOC] for further study. Bad idea! It turns out that “the perfect organism”…
#
#
# Fede Alvarez cleverly crafted a story weaving in the best elements from ALL the past movies. Perfect balance of Horror & Action. Breathtaking visuals! Spaeny & Jonsson are the MVPs. AND MY GOD THAT 3RD ACT! While the story & characters might not be the most compelling of the franchise. Along with the expansion of the world being pretty minimal. The movie working as a celebration of everything that came before it while still delivering unique spins of old tropes is an achievement.
#  [PER][PER] cleverly crafted a story weaving in the best elements from ALL the past movies. Perfect balance of Horror & Action. Breathtaking visuals! [PER][PER] & [PER] are the MVPs. AND MY GOD THAT 3RD ACT! While the story & characters might not be the most compelling of the franchise. Along with the expansion of the world being pretty minimal. The movie working as a celebration of everything that came before it while still delivering unique spins of old tropes is an achievement.
#
#
# Face-hugger effects:amazingXenomorph effects:phenomenal[OTHER] effects:god-likePerfectly normal CGI human face:fucking terrifyingPalpable horror, grim lighting, booming sound design, intense chase sequences, grotesque gore, and a third act that swallows your stomach and baby-birds it back into your mouth. These are the reasons you hire Fede Alvarez.The majority ofRomulusis by all accounts a “good”Alienmovie; or, at least, a good sci-fi/horror creature feature (might low key be the best ever “spiders attack”…
#  Face-hugger effects:amazingXenomorph effects:phenomenal[OTHER] effects:god-likePerfectly normal CGI human face:fucking terrifyingPalpable horror, grim lighting, booming sound design, intense chase sequences, grotesque gore, and a third act that swallows your stomach and baby-birds it back into your mouth. These are the reasons you hire [PER].The majority ofRomulusis by all accounts a “good”[MISC]; or, at least, a good sci-fi/horror creature feature (might low key be the best ever “spiders attack”…
#
#
# WHYYYYYYYYYYYYYY WHY WHY WHY WHYEXTENDED REVIEW HERE👽There’s a part of me that really wants to lower this score honestly, but there’s another part of me that can see so much talent and passion behind true craftsmanship in this movie.That talent is very sadly soiled by disrespectful and downright unholy choices bogging down any enjoyment I was having.I was fully onboard with EVERYTHING. There is so much here that works and is a fantastic addition to…
#  WHYYYYYYYYYYYYYY WHY WHY WHY WHY[PER]TENDED REVIEW HERE👽There’s a part of me that really wants to lower this score honestly, but there’s another part of me that can see so much talent and passion behind true craftsmanship in this movie.That talent is very sadly soiled by disrespectful and downright unholy choices bogging down any enjoyment I was having.I was fully onboard with EVERYTHING. There is so much here that works and is a fantastic addition to…
#
#
# a decently structured reflection of the alien franchise that regrettably kinda only really exists as a somewhat uninspired rehash of the first film, not to say that’s absolutely all it is, but it’s really hard to look past much of what occurs. Throwing in a slew of cheap references to remind you of the franchise's better days. And, without going into detail (you already know), it has the most perplexing callback that will undoubtedly irritate many people, including myself. It's…
#  a decently structured reflection of the alien franchise that regrettably kinda only really exists as a somewhat uninspired rehash of the first film, not to say that’s absolutely all it is, but it’s really hard to look past much of what occurs. Throwing in a slew of cheap references to remind you of the franchise's better days. And, without going into detail (you already know), it has the most perplexing callback that will undoubtedly irritate many people, including myself. It's…
#
#
# One of the truly most frustrating moviegoing experiences I’ve ever had because there is plenty that I adored about it and that felt like a step in the right direction for the franchise…yet SO MUCH more that I absolutely despised and repulsed me.The Good- the first act/the mining colony. Loved the slow, deliberate pace and narratively it felt like the right move to ground it in a working class rebel refugee corporate prison planet setting. Really set a…
#  One of the truly most frustrating moviegoing experiences I’ve ever had because there is plenty that I adored about it and that felt like a step in the right direction for the franchise…yet SO MUCH more that I absolutely despised and repulsed me.[MISC]- the first act/the mining colony. Loved the slow, deliberate pace and narratively it felt like the right move to ground it in a working class rebel refugee corporate prison planet setting. Really set a…
#
#
# Cailee Spaeny learns again that you can’t always fix a man
#  [PER] learns again that you can’t always fix a man
#
#
# 4 star movie dragged down by THAT creative decision (if I can't excuse the Flash, I can't excuse this)
#  4 star movie dragged down by THAT creative decision (if I can't excuse the [MISC], I can't excuse this)
#
#
# xenomorphs rule and i had a good time with this movie.
#  xenomorphs rule and i had a good time with this movie.
#
#
# 83Cozies up in a nice middle ground between Ridley Scott's prequel cynicism and the adventurous reverence of Jim Cameron'sAliens. People have been comparing it to the original masterpiece but as much as the 1979 film is clearly an aesthetic model,Romulusfunctions more like a bottle episode in the xenomorph universe than anything overtly substantial, with a thin layer of heady corporatism to cover all that splatter and screaming. Director Fede Alvarez starts off with solid bones on…
#  83Cozies up in a nice middle ground between [PER]'s prequel cynicism and the adventurous reverence of [PER]'s[MISC][MISC]. People have been comparing it to the original masterpiece but as much as the 1979 film is clearly an aesthetic model,[MISC]om[MISC]functions more like a bottle episode in the xenomorph universe than anything overtly substantial, with a thin layer of heady corporatism to cover all that splatter and screaming. Director [PER] starts off with solid bones on…
#
#
# People need to stop playing with these aliens, they are dangerous
#  People need to stop playing with these aliens, they are dangerous
#
#
# FACEHUGGER$.
#  FACEHUGGER$.
#
#
# god must’ve missed me when he was handing out the “indomitable will of the human spirit to survive against all odds” gene because I would’ve peaced and let the alien kill me about 30 seconds into this shit
#  god must’ve missed me when he was handing out the “indomitable will of the human spirit to survive against all odds” gene because I would’ve peaced and let the alien kill me about 30 seconds into this shit
#
#
# “Get away from her, you… b-b!tch.”Look, it’s odd enough when fictional characters know something they said in an earlier film is a meme - “I’m something of a scientist myself” or “some motherf&!kers always trying to ice skate uphill.” However, it is even stranger to have a character quote an iconic line that a franchise lead who they will never meet will say at some random point in future continuity, to get a cheap cheer from the audience. It’s…
#  “Get away from her, you… b-b!tch.”Look, it’s odd enough when fictional characters know something they said in an earlier film is a meme - “I’m something of a scientist myself” or “some motherf&!kers always trying to ice skate uphill.” However, it is even stranger to have a character quote an iconic line that a franchise lead who they will never meet will say at some random point in future continuity, to get a cheap cheer from the audience. It’s…
#
#
# DERS SUMFIN IN THE WA’UR💦💦EXTENDED REVIEW HERE🫣🫣
#  [ORG]RS SUMFIN IN THE [LOC][ORG]UR💦💦EXTENDED REVIEW HERE🫣🫣
#
#
# this is the first alien movie i’ve seen (i know i should be locked up for this) and i was so thoroughly entertained through this movie. i appreciated the fact that with no knowledge of the alien franchise i was able to keep up with the plot lines. and i was NOT disappointed by it the body horror and big monster alien by the end of the movie.freaky ass alien impregnating people is so delish!!!!!!!!  can’t wait to watch the rest of the movies
#  this is the first alien movie i’ve seen (i know i should be locked up for this) and i was so thoroughly entertained through this movie. i appreciated the fact that with no knowledge of the alien franchise i was able to keep up with the plot lines. and i was NOT disappointed by it the body horror and big monster alien by the end of the movie.freaky ass alien impregnating people is so delish!!!!!!!!  can’t wait to watch the rest of the movies
#
#
# bruh these aliens got no rizz you cant just hug someones face and shove an alien down their throat and expect them to like it man
#  bruh these aliens got no rizz you cant just hug someones face and shove an alien down their throat and expect them to like it man
#
#
# sequels prequels and reboots are so interesting nowadays... kinda like the viral videos of that guy who turns cookies into pancakes into milkshakes into cereal and back into cookies or whatever... for what it's worth though this was fucking GNARLY
#  sequels prequels and reboots are so interesting nowadays... kinda like the viral videos of that guy who turns cookies into pancakes into milkshakes into cereal and back into cookies or whatever... for what it's worth though this was fucking GNARLY
#
#
# Oh Fede Álvarez you fucking freak (complimentary)
#  Oh [PER] you fucking freak (complimentary)
#
#
# But… you are not allowed to create. Even a simple tune. Damn frustrating, I’d say.You disturbed people. You were too human. Too idiosyncratic, thinking for yourself. Made people uncomfortable. So they made the following models with fewer complications.More like machines.——————————————————————————The most common criticism I see of my belovedAlien: Covenantfrom people who aren’t outright dismissive of the film’s sensibilities lies with its final act aboard the titular ship. The film’s gothic aesthetic and existential ruminations…
#  But… you are not allowed to create. Even a simple tune. Damn frustrating, I’d say.You disturbed people. You were too human. Too idiosyncratic, thinking for yourself. Made people uncomfortable. So they made the following models with fewer complications.More like machines.——————————————————————————The most common criticism I see of my beloved[PER][PER]n: Covenantfrom people who aren’t outright dismissive of the film’s sensibilities lies with its final act aboard the titular ship. The film’s gothic aesthetic and existential ruminations…
#
#
# I should have just stayed home and watchedTrue Blood.Edit:I’ve calmed down a bit, but I’m heartbroken. Cailee Spaeny and David Jonsson are spectacular. Fede Alvarez is so talented. That’s what makes this so egregious.Second Edit: I’m angry again.Third Edit: Calmed down again.
#  I should have just stayed home and watched[MISC].Edit:I’ve calmed down a bit, but I’m heartbroken. [PER][PER] and [PER] are spectacular. [PER] is so talented. That’s what makes this so egregious.Second Edit: I’m angry again.Third Edit: Calmed down again.
#
#
# What’s here isn’t necessarily boring or bad, but it represents a back-to-basics approach forAlienthat feels like a betrayal of something central to the Xenomorph’s toxic DNA, which is forever mutating into another deadly creature. Fittingly then, everyAliensequel for a long time took a flamethrower to the previous entry. Each one burned down what had come before as part of its transformation into something new.Alien: Romulusjust hands the characters some flamethrowers, because that’s what they used in the earlier movies.Full review atScreenCrush.
#  What’s here isn’t necessarily boring or bad, but it represents a back-to-basics approach forAlienthat feels like a betrayal of something central to the [MISC]’s toxic DNA, which is forever mutating into another deadly creature. Fittingly then, every[MISC][MISC]quel for a long time took a flamethrower to the previous entry. Each one burned down what had come before as part of its transformation into something new.[MISC]: [PER]omulusjust hands the characters some flamethrowers, because that’s what they used in the earlier movies.Full review atScreen[MISC][MISC].
#
#
# in space no one can hear you scream… unless you’re isabela motherfucking merced
#  in space no one can hear you scream… unless you’re isabela motherfucking merced
#
#
# Despite my affection for the strange nihilistic musings on the act of creation Ridley Scott had been trying to Dr. Frankenstein hisoriginal perfect formal organismof claustrophobic sci-fi horror into withPrometheusandCovenant(would've loved to have seen what he might have done with a third movie dedicated entirely to Fassbender'sAndroid of Arabia), I was honestly game for a lean, mean "back-to-basics" body horror/creature feature/slasher in a tangible spaceship again. I'm largely impartial to Fede, but being…
#  Despite my affection for the strange nihilistic musings on the act of creation [PER] had been trying to Dr. [PER] hisoriginal perfect formal organismof claustrophobic sci-fi horror into withP[PER]theusandCovenant(would've loved to have seen what he might have done with a third movie dedicated entirely to [PER]ben[PER]'s[MISC]), I was honestly game for a lean, mean "back-to-basics" body horror/creature feature/slasher in a tangible spaceship again. I'm largely impartial to [PER], but being…
#
#
# Handsomely shot and appropriately gross, but it’s still a glossy franchise homunculus: there’s only vapor inside. AnAlienmovie about nothing but its own IP, I was longing for something a tenth as interesting as Ridley’s unfinished David trilogy, or evenResurrection. Throw in some disgusting CGI necromancy of a certain actor and you’ve got one of the biggest disappointments of the year.
#  Handsomely shot and appropriately gross, but it’s still a glossy franchise homunculus: there’s only vapor inside. An[MISC][MISC][ORG] about nothing but its own IP, I was longing for something a tenth as interesting as [PER]’s unfinished [PER] trilogy, or evenResurrection. Throw in some disgusting [MISC]GI necromancy of a certain actor and you’ve got one of the biggest disappointments of the year.
#
#
# ALIEN: ROMULUS leans heavily into its horror origins to craft a relentless, visceral thrill ride that starts off slowly and increases in intensity until you’re left gasping for breath by the end. Devoid of any thematic depth, it incorporates so many winks, nods, and moments of fan service it often feels more like a greatest hits entry than trying to provide anything new or profound. Still, the grounded performances from Cailee Spaeny & David Jonsson provide just enough emotional weight to keep audiences invested during the slaughter. Definitely the most straightforward of the franchise.Next Best Picture’s full reviewhere
#  ALIEN: [MISC][ORG][ORG][MISC] leans heavily into its horror origins to craft a relentless, visceral thrill ride that starts off slowly and increases in intensity until you’re left gasping for breath by the end. Devoid of any thematic depth, it incorporates so many winks, nods, and moments of fan service it often feels more like a greatest hits entry than trying to provide anything new or profound. Still, the grounded performances from [PER][PER] & [PER] provide just enough emotional weight to keep audiences invested during the slaughter. Definitely the most straightforward of the franchise.[MISC]’s full reviewhere
#
#
# Fede Álvarez, you are a sick, sick man. Thanks for the nightmare fuel.
#  [PER], you are a sick, sick man. Thanks for the nightmare fuel.
#
#
# Right off the bat, this is currently sitting at the number one spot of my movies for this year.This film is absolutely amazing. Not a single person I talked to after walking out of this screening thought it was bad.Now I will be the first to admit. I saw it last week at an unbelievable event with live actors and gifts and we watched in a 4DX theater and I was surrounded by good friends. So I 100%…
#  Right off the bat, this is currently sitting at the number one spot of my movies for this year.This film is absolutely amazing. Not a single person I talked to after walking out of this screening thought it was bad.Now I will be the first to admit. I saw it last week at an unbelievable event with live actors and gifts and we watched in a 4DX theater and I was surrounded by good friends. So I 100%…
#
#
# They did it, guys! I actually want to cry because they gave us a great movie of this franchise after all these years (I appreciatedPrometheusandAlien: Covenantbut they're not among my fav.) and I can say that it's as scary and terrifying as the first one directed by the master Ridley Scott. I loved how they handled all of it, the tension is great, the atmosphere is haunting and I personally loved the practical effect Alvarez decided to use. It seems a movie made in the 80s', in the best way possible.I hope you all enjoy it as much as I did.
#  They did it, guys! I actually want to cry because they gave us a great movie of this franchise after all these years (I appreciatedPrometheusandA[MISC]: [MISC]but they're not among my fav.) and I can say that it's as scary and terrifying as the first one directed by the master [PER]. I loved how they handled all of it, the tension is great, the atmosphere is haunting and I personally loved the practical effect [PER] decided to use. It seems a movie made in the 80s', in the best way possible.I hope you all enjoy it as much as I did.
#
#
# at what point does a series stop moving forward and becomes contented with exploring esoteric details within the same formula? i'd argue that, despite its fanboy bonafides with well-designed practical effects and devotion to the 'worn future' aesthetic of 1979 science-fiction, this finds easier sisterhood withalien: isolationand the rebellion/monolithAVPvideogames: the floaty tracking shots make the impressive production design here into an ambient enviorns that soaks into the viewer's cortex, without the patient slow-burn spookhouse built into…
#  at what point does a series stop moving forward and becomes contented with exploring esoteric details within the same formula? i'd argue that, despite its fanboy bonafides with well-designed practical effects and devotion to the 'worn future' aesthetic of 1979 science-fiction, this finds easier sisterhood withalien: isolationand the rebellion/monolithAVPvideogames: the floaty tracking shots make the impressive production design here into an ambient enviorns that soaks into the viewer's cortex, without the patient slow-burn spookhouse built into…
#
#
# In space nobody can hear your dad jokes
#  In space nobody can hear your dad jokes
#
#
# Alien Resurrectionarmy…, we fucking won!!!The horror in this movie is seeing that Gen Z kids exist 100 years from now. The good news is this is easily the best in the franchise sinceAliens. I was unsure about the first 30-45 minutes cause I wasn’t a fan of some of the characters and everybody had an obnoxious heavy British accent so I had no clue what was being said 85% of the time. But once some of the…
#  [MISC]…, we fucking won!!!The horror in this movie is seeing that [MISC] kids exist 100 years from now. The good news is this is easily the best in the franchise since[MISC][MISC]. I was unsure about the first 30-45 minutes cause I wasn’t a fan of some of the characters and everybody had an obnoxious heavy [MISC] accent so I had no clue what was being said 85% of the time. But once some of the…
#
#
# I’m ready for the David Jonsson and Cailee Spaeny take over.Full Thoughts on podcast Ep. 186- Alien: Romulus
#  I’m ready for the [PER] and [PER] take over.Full Thoughts on podcast Ep. 186- [MISC]: [MISC]om[MISC]
#
#
# AI-generated movie tie-in game for desktop and mac
#  [MISC]-generated movie tie-in game for desktop and mac
#
#
# Lowkey that’s what my wiener looks like
#  Lowkey that’s what my wiener looks like
#
#
# Thrilling!! Some scenes were a bit slow but when it went for it, it did it with full force which resulted in such a blast. Went to the premiere and they gave us our own little aliens to take home; i named mine roberto.
#  Thrilling!! Some scenes were a bit slow but when it went for it, it did it with full force which resulted in such a blast. Went to the premiere and they gave us our own little aliens to take home; i named mine roberto.
#
#
# handsomely made but deeply uninterested in doing anything new. a theme park imitation of the original. occasionally fun but by the time it wraps up i’m totally checked out of all its legacy sequel bullshit, especially that particularly egregious and excessive use of [REDACTED]. say what you will about Ridley’s prequels but they’re weird and mean and wholly unique in their feverish psychosexual worship, this is nothing. made for the fans (derogatory)
#  handsomely made but deeply uninterested in doing anything new. a theme park imitation of the original. occasionally fun but by the time it wraps up i’m totally checked out of all its legacy sequel bullshit, especially that particularly egregious and excessive use of [REDACTED]. say what you will about [PER]’s prequels but they’re weird and mean and wholly unique in their feverish psychosexual worship, this is nothing. made for the fans (derogatory)
#
#
# physically winced whenever they showed cgi ian holm and then locked back in when they showed cailee spaeny
#  physically winced whenever they showed cgi ian holm and then locked back in when they showed cailee spaeny
#
#
# First impression: A decent, juicy best-of and Xenomorph-festival, which unfortunately works a little too much along the lines of the first 4 films (plus prequel) instead of developing its own identity. But the direction, set, mood, action, toughness, as well as Spaeny and Jonsson(!) make up for a lot. Also a really crude "effect". I want and need to see it again.==================================Ersteindruck: Ein anständiges, saftiges Best-of und Xenomorph-Festival, das sich leider etwas zu sehr an den ersten 4…
#  First impression: A decent, juicy best-of and [MISC]festival, which unfortunately works a little too much along the lines of the first 4 films (plus prequel) instead of developing its own identity. But the direction, set, mood, action, toughness, as well as [PER][PER] and [PER](!) make up for a lot. Also a really crude "effect". I want and need to see it again.==================================Ersteindruck: Ein anständiges, saftiges [MISC]-[MISC] und [MISC], das sich leider etwas zu sehr an den ersten 4…
#
#
# WE ARE SO BACK!!!! thank you for your service fede you and the whole cast/crew did a truly tremendous job and have made a pretty excellent alien movie good job keep it up i’ll happily take at least five more of these if you’re up for it 👍
#  WE ARE SO BACK!!!! thank you for your service fede you and the whole cast/crew did a truly tremendous job and have made a pretty excellent alien movie good job keep it up i’ll happily take at least five more of these if you’re up for it 👍
#
#
# after the first death in the film i thought to myself “sheesh! that must be the worst possible way a human could die”… i was immediately proven wrong as there were multiple far worse deaths to come 🙃
#  after the first death in the film i thought to myself “sheesh! that must be the worst possible way a human could die”… i was immediately proven wrong as there were multiple far worse deaths to come 🙃
#
#
# I’ve never been the biggest Alien fan but man this movie absolutely fucks. Such an incredible theater experience. Hope everyone goes and checks it out! 💯2024 Ranked
#  I’ve never been the biggest [MISC] fan but man this movie absolutely fucks. Such an incredible theater experience. Hope everyone goes and checks it out! 💯2024 Ranked
#
#
# Easily the scariest Disney movie of the year.
#  Easily the scariest [ORG] movie of the year.
#
#
# A love letter to all of the Alien Franchise. Yes, even including the most hated ones. Depending on your views on the sequels, this will be a hit or a miss. Fede Alvarez knows how to capture a dark and beautiful atmosphere. Callee Spaney is no Ripley, but she does stands on her own and I love her so much.
#  A love letter to all of the [ORG][MISC][MISC][ORG]. Yes, even including the most hated ones. Depending on your views on the sequels, this will be a hit or a miss. [PER][PER] knows how to capture a dark and beautiful atmosphere. [PER] is no [PER], but she does stands on her own and I love her so much.
#
#
# Fuera de Serie: Dicklien and the Lost StarshipsI knew that Bjorn dude was a scum the moment I watched those trailers and he pronounced “Water” without the “T”. Never trust someone like that. Never!Ok, but (half) seriously, this was a film that took me by surprise in the sense that I wasn’t expecting a lot of the huge positive reception it got. I mean, other than that Girl With The Dragon Tattoo movie he did, his past work…
#  [MISC]: [PER][MISC] [MISC] [MISC] [MISC] [MISC][MISC]I knew that [PER][PER][PER] dude was a scum the moment I watched those trailers and he pronounced “[MISC] without the “T”. Never trust someone like that. Never!Ok, but (half) seriously, this was a film that took me by surprise in the sense that I wasn’t expecting a lot of the huge positive reception it got. I mean, other than that [MISC] movie he did, his past work…
#
#
# “run”let me just start off by saying.. the third act… holy shit.. I kept gasping for fucking air 🤯 it’s genuinely fucking scary and disgusting.. my type of stuff!gross goopy gore! face huggers! xenomorphs! chest busters! body horror! oh my!fede alvarez is a sicko freak and I love him for it. any horror franchise this man touches instantly becomes a classic. batshit sequences gorgeous visuals & impressive practical sets. a fantastic addition to the alien franchise that fits…
#  “run”let me just start off by saying.. the third act… holy shit.. I kept gasping for fucking air 🤯 it’s genuinely fucking scary and disgusting.. my type of stuff!gross goopy gore! face huggers! xenomorphs! chest busters! body horror! oh my!fede alvar[PER] is a sicko freak and I love him for it. any horror franchise this man touches instantly becomes a classic. batshit sequences gorgeous visuals & impressive practical sets. a fantastic addition to the alien franchise that fits…
#
#
# Alien: The Force Awakens.
#  [MISC].
#
#
# “do what’s best for us” 🥹what’s more powerful? isabela merced’s scream or caliee spaeny‘s final girlismbonkers third act.. brilliant performances, xenomorphs going full sicko mode & phenomenal direction.. man this movie fucks..
#  “do what’s best for us” 🥹what’s more powerful? is[PER][PER] me[PER][PER]’s scream or caliee spaeny‘s final girlismbonkers third act.. brilliant performances, xenomorphs going full sicko mode & phenomenal direction.. man this movie fucks..
#
#
# cailee spaeny world domination is well and truly in motion and fede álvarez is a sick twisted man. we are so fucking back
#  cailee spaeny world domination is well and truly in motion and fede [PER]l[PER][PER] is a sick twisted man. we are so fucking back
#
#
# When ur best friend supports u through ur abortion ❤️
#  When ur best friend supports u through ur abortion ❤️
#
#
# The solid production value, frequent use of practical effects, and assured co-leads of Cailee Spaeny and David Jonsson cannot escape the cheap fan service, a dozen different endings, and a nagging question ofwhy?Alien: Romulusis a xenomorph eating its tail. Painfully fine. But Fede Alvarez shows us pockets of an original movie that could've done far more instead of just hitting the beats. It's beholden to legacy to a fault. But there's a frustrating amount of evidence of…
#  The solid production value, frequent use of practical effects, and assured co-leads of [PER][PER] and [PER] cannot escape the cheap fan service, a dozen different endings, and a nagging question ofwhy?[MISC]: [MISC]om[MISC]is a xenomorph eating its tail. Painfully fine. But [PER] shows us pockets of an original movie that could've done far more instead of just hitting the beats. It's beholden to legacy to a fault. But there's a frustrating amount of evidence of…
#
#
# Zur Videokritik:youtu.be/a7y2lmkLkDw?si=xpYN-6oCjFSTIhRGIch schätze, es ist ein bisschen meine Schuld. Meine Vorfreude auf „Alien Romulus“ hatte sich irgendwann in Regionen gesteigert, die jeder reellen Wahrscheinlichkeit entbehrt. Und überhaupt: was will ich eigentlich von einer Alien-Fortsetzung? Mehr vom Gleichen? Ja, schon irgendwie, aber diese Formel begann schon mit den Fortsetzungen zu schwinden. Zumal gerne übersehen wird, dass die Geschichte des Aliens immer auch mit Ellen Ripley verbunden war. Mehr Aliens allein reißt nicht viel.Hätte ich lieber einen neuen, mutigen…
#  Zur Video[MISC][MISC][MISC]:youtu.be/a7y2lmkLkDw?si=xpYN-6oCjFSTIhRGIch schätze, es ist ein bisschen meine Schuld. Meine Vorfreude auf „[MISC]om[MISC]“ hatte sich irgendwann in [LOC][MISC] gesteigert, die jeder reellen Wahrscheinlichkeit entbehrt. Und überhaupt: was will ich eigentlich von einer [MISC]-[MISC]setzung? Mehr vom [MISC]leichen? Ja, schon irgendwie, aber diese Form[MISC] begann schon mit den Fortsetzungen zu schwinden. [PER]umal gerne übersehen wird, dass die Geschichte des [MISC] immer auch mit [PER] verbunden war. Mehr [MISC][MISC] allein reißt nicht viel.Hätte ich lieber einen neuen, mutigen…
#
#
# CAILEE FUCKING SPAENY
#  [ORG]ILEE FUCKING SPAENY
#
#
# Exhilarating watch. Found myself having to catch my breath on multiple occasions. Watched with my oldest son and daughter, and my daughter’s hand was clenching mine the entire time.Spaenywas excellent in lead but was incredibly impressed byDavid Jonssonand the turns his character takes. Really thought the visuals looked fantastic.  There’s not much in the way of thematic depth outside of a reprise of valuing corporate interests vs human life, but when I’m watching anAlienmovie,…
#  Exhilarating watch. Found myself having to catch my breath on multiple occasions. Watched with my oldest son and daughter, and my daughter’s hand was clenching mine the entire time.[PER][PER]was excellent in lead but was incredibly impressed by[PER][PER][PER]and the turns his character takes. Really thought the visuals looked fantastic.  There’s not much in the way of thematic depth outside of a reprise of valuing corporate interests vs human life, but when I’m watching an[MISC][MISC],…
#
#
# Finally.40 fucking years after Aliens, they made an Alien movie that isn’t dogshit.
#  Finally.40 fucking years after [MISC], they made an [MISC] movie that isn’t dogshit.
#
#
# In just a few hours since seeing the movie, I'm already intoxicated by it. Alien Romulus is definitely a few things: a stark love letter to the entire franchise, a distinct vision by Fede Alvarez, and a fearless entry into the Alien lore. It easily stands amongst the heavyweights of the franchise (I know for some only the fist 2 are great, but I happen to love most of the movies).It takes risks. Heavy risks that might not be…
#  In just a few hours since seeing the movie, I'm already intoxicated by it. [MISC] is definitely a few things: a stark love letter to the entire franchise, a distinct vision by [PER], and a fearless entry into the [MISC] lore. It easily stands amongst the heavyweights of the franchise (I know for some only the fist 2 are great, but I happen to love most of the movies).It takes risks. Heavy risks that might not be…
#
#
# would rather just play Isolation again
#  would rather just play [MISC]ola[MISC] again
#
#
# i guess mining ain’t lookin so bad anymore
#  i guess mining ain’t lookin so bad anymore
#
#
# put that thing back where it came from or so help meeee, so help me!
#  put that thing back where it came from or so help meeee, so help me!
#
#
# “Get away from her…”Lost me early on and could have very easily found me again if it didn’t keep repeating itself on that very specific point over and over and over.Making a franchise dance like a marionette. No soul, no challenge, no life. If the goal was to make a very Back To BasicsAlienfilm for modern audiences without any of the depth or nuance found in the original, then cool, but there was no doubling down…
#  “Get away from her…”Lost me early on and could have very easily found me again if it didn’t keep repeating itself on that very specific point over and over and over.Making a franchise dance like a marionette. No soul, no challenge, no life. If the goal was to make a very [MISC] for modern audiences without any of the depth or nuance found in the original, then cool, but there was no doubling down…
#
#
# ALIEN IS BACK!!Fede Alvarez crafted a faithful and exciting addition to the franchise which fans will undoubtedly love. The passion for the Alien world oozes on screen like acid blood
#  [ORG]N IS BACK!![PER] crafted a faithful and exciting addition to the franchise which fans will undoubtedly love. The passion for the [MISC] world oozes on screen like acid blood
#
#
# Alien Romulus' is freaking phenomenal and one of the best movies of the year. It's tense, terrifying, and has breathtaking visuals. I love seeing Cailee Spaeny shine; she's one of the best actresses of this generation. The use of sound is terrific; it gave me chills. The third act is one of the best I've ever seen. Fede Álvarez hit the mark.
#  [MISC]om[MISC]' is freaking phenomenal and one of the best movies of the year. It's tense, terrifying, and has breathtaking visuals. I love seeing [PER][PER] shine; she's one of the best actresses of this generation. The use of sound is terrific; it gave me chills. The third act is one of the best I've ever seen. [PER] hit the mark.
#
#
# Everyone's not nice to Andy,And hopes that he'll come in handy.But when a bug,Goes for a hug,Things may turn out less than dandy.
#  Everyone's not nice to [PER],And hopes that he'll come in handy.But when a bug,Goes for a hug,Things may turn out less than dandy.
#
#
# Far more my speed thanAlienssurprisingly, feels like a sequel toAlienfor people who really loveAlienspecifically. Genuinely great production design/effects throughout and justifies its existence with a simple yet effective plot, which is more than can be said for many franchise sequels these days. Perhaps it’ll prove to be forgettable in time and settle closer to a 3/5, but for now I reckon I was 4/5 glued to the screen. The chest burster sequence in IMAX was worth the pricey ticket alone, absolutely fantastic cross cutting and sound design.
#  Far more my speed than[MISC][MISC]surprisingly, feels like a sequel to[MISC][MISC]for people who really love[MISC][MISC]pecific[MISC]. Genuinely great production design/effects throughout and justifies its existence with a simple yet effective plot, which is more than can be said for many franchise sequels these days. Perhaps it’ll prove to be forgettable in time and settle closer to a 3/5, but for now I reckon I was 4/5 glued to the screen. The chest burster sequence in [MISC] was worth the pricey ticket alone, absolutely fantastic cross cutting and sound design.
#
#
# liked when this was Fede Alvarez being Fede Alvarez and didn't like this when it was doing soulless nostalgia slop. David Jonsson is awesome, the real breakout here; Spike Fearn is Bjorn.I wrote more coherently about the franchise's endurance for The Atlantic.
#  liked when this was [PER][MISC] [PER] being [PER] and didn't like this when it was doing soulless nostalgia slop. [PER] is awesome, the real breakout here; [PER] is [PER][PER][PER].I wrote more coherently about the franchise's endurance for [ORG].
#
#
# Yeah this might be my most intense theater experience sinceEvil Dead 2013! I was holding onto them armrests for dear life for the entire last half hour. This is theAlienmovie we have been waiting YEARS to see!This franchise has always been one of my favorites. I’ve been obsessed with it since I was a little kid who saw the trailer for the original while standing in line at Disney MGM Studios Great Movie Ride. While I’ve…
#  Yeah this might be my most intense theater experience since[MISC]! I was holding onto them armrests for dear life for the entire last half hour. This is the[MISC][MISC] we have been waiting YEARS to see!This franchise has always been one of my favorites. I’ve been obsessed with it since I was a little kid who saw the trailer for the original while standing in line at [MISC]. While I’ve…
#
#
# somewhere in me knew that an alien film directed by fede alvarez was too good to be true. the monkey's paw curls into a middle finger.full review
#  somewhere in me knew that an alien film directed by fede alvar[PER] was too good to be true. the monkey's paw curls into a middle finger.full review
#
#
# “fucking things hunting us”this film is my drug.. I CANT get enough.. inject the acid sequence into my veins. god tier performance from david jonsson, I’ve always been familiar with your game. final girl cailee spaeny & scream queen isabela merced have real nice rings to it. seriously would love to see this cast in more horror projects 🩸🪐
#  “fucking things hunting us”this film is my drug.. I CANT get enough.. inject the acid sequence into my veins. god tier performance from [PER][PER], I’ve always been familiar with your game. final girl cailee spaeny & scream queen [PER][PER][PER]rc[PER] have real nice rings to it. seriously would love to see this cast in more horror projects 🩸🪐
#
#
# This absolutely delivered on all my expectations. It was raw, visceral, and terrifying and felt like a real return to the roots of the series. Because the franchise is 45 years old it can't scare us the same way the first one did and so it plays on our knowledge instead. We know that the characters are in danger long before they do and the movie uses this to its advantage to ratchet up the tension.I also loved the…
#  This absolutely delivered on all my expectations. It was raw, visceral, and terrifying and felt like a real return to the roots of the series. Because the franchise is 45 years old it can't scare us the same way the first one did and so it plays on our knowledge instead. We know that the characters are in danger long before they do and the movie uses this to its advantage to ratchet up the tension.I also loved the…
#
#
# the alien franchise be like: you know there's something much worse coming when you think the film is going to end
#  the alien franchise be like: you know there's something much worse coming when you think the film is going to end
#
#
# justSUCH a good time at the movies! the zero gravity acid blood scene has to be one of the coolest things i’ve seen in a good while and that final act is pure bonkers i love it all a lot
#  justSUCH a good time at the movies! the zero gravity acid blood scene has to be one of the coolest things i’ve seen in a good while and that final act is pure bonkers i love it all a lot
#
#
# WE WON! -youtu.be/ByFocMJzVso?si=ypWwvxAnm8hQc6YE
#  WE WON! -youtu.be/ByFocMJzVso?si=ypWwvxAnm8hQc6YE
#
#
# Fede Alvarez didn't come here to play. For so long waited and hoped what would it take to see the proper and originalAlienfilm on the big screen, and when wishes granted, Alien franchise is gleefully comes back alive and shines more than ever. This is not a drill:Alien: Romulusis hands down one of the scariest and intenseAlienfilms since the second predecessor. I felt the threat, the suspense, the terror that delivers in such a…
#  [PER][PER] didn't come here to play. For so long waited and hoped what would it take to see the proper and original[MISC][MISC]film on the big screen, and when wishes granted, [MISC] franchise is gleefully comes back alive and shines more than ever. This is not a drill:[MISC]: [ORG]om[MISC]is hands down one of the scariest and intense[MISC][MISC]films since the second predecessor. I felt the threat, the suspense, the terror that delivers in such a…
#
#
# You’re hearing Force Awakens allegations and you’d be right. It’s like an amalgamation of all the coolest aspects of each preceding Alien film — which in turn gives it a void of originality. I can go back and watchAlienall the way toAlien Covenantand they’ll each give me something unique. This doesn’t quite have that except for the fantastic last 20 minutes. Which I must say, was so fucking cool why didn’t they just explore and do…
#  You’re hearing [MISC] allegations and you’d be right. It’s like an amalgamation of all the coolest aspects of each preceding [MISC] film — which in turn gives it a void of originality. I can go back and watch[MISC]lie[MISC][MISC] the way to[MISC]lie[MISC] [LOC]and they’ll each give me something unique. This doesn’t quite have that except for the fantastic last 20 minutes. Which I must say, was so fucking cool why didn’t they just explore and do…
#
#
# 🔥 4.4 / 5 🔥 —Alien: Romulusrevives the franchise's terrifying origins and horrifying pedigree, and I can't wait to see moreAlienfilms just like it!YES!!!Alien: Romulussteers away from the weird sci-fi philosophy, taking the franchise back to its terrifying horror roots. The claustrophobic spaceship corridors, jump scares, and gore are all back, enhanced by the retro aesthetics of the original 1979 film, which make the impressive practical creature effects stand out even more. The movie is…
#  🔥 4.4 / 5 🔥 —[MISC]: [MISC]revives the franchise's terrifying origins and horrifying pedigree, and I can't wait to see more[MISC][MISC]films just like it!YES!!![MISC]: [MISC]steers away from the weird sci-fi philosophy, taking the franchise back to its terrifying horror roots. The claustrophobic spaceship corridors, jump scares, and gore are all back, enhanced by the retro aesthetics of the original 1979 film, which make the impressive practical creature effects stand out even more. The movie is…
#
#
# I’m glad Cailee Spaeny could read those IKEA-like ship instructions so fast. This was killer. Facehuggers also really hit different in IMAX.
#  I’m glad [PER][ORG][ORG] [PER][ORG][ORG] could read those [MISC]-like ship instructions so fast. This was killer. [MISC]huggers also really hit different in [MISC].
#
#
# …Fede got the assignment.Imagine someone made the filmed adaptation of a popular Theme Park attraction based on the entire ALIEN saga.A total rollercoaster version of the ALIEN movies…it’s “The Mummy The Ride - ALIEN edition”, “Weyland Yutani Tours” that takes all of your recognition of the production design, sound effects, even story beats and character types (or actual characters) and builds a simple path through all the Greatest Hits seamlessly and shamelessly because hey, that’s what the public…
#  [PER][PER] got the assignment.Imagine someone made the filmed adaptation of a popular [MISC] attraction based on the entire [MISC] saga.A total rollercoaster version of the [MISC] movies…it’s “[MISC] - [MISC] edition”, “[ORG][ORG]” that takes all of your recognition of the production design, sound effects, even story beats and character types (or actual characters) and builds a simple path through all the [MISC] seamlessly and shamelessly because hey, that’s what the public…
#
#
# basically what happened when I met Ezra Miller
#  basically what happened when I met [PER]

# %% [markdown]
# Run the above on the dataframe as a whole

# %%
tokenizer = AutoTokenizer.from_pretrained("dslim/bert-large-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-large-NER")
nlp = pipeline("ner", model=model, tokenizer=tokenizer)

df_small = df.sort_values(by='avg_rating', ascending=False).iloc[:50].copy()
df_small['NER_reviews'] = df_small['reviews_extracted'].apply(
    lambda x: [replace_named_entities_with_bert(doc, nlp) for doc in x]
)
# Out:
# Some weights of the model checkpoint at dslim/bert-large-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
df_small['NER_reviews'].iloc[1]
# Out:
# ['SAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WASSAME AS IT EVER WAS',
#  'sweat my ass off dancing from “slippery people” on in a big suit at a vidiots screening with the band (inc. [PER]nah holt, [PER]ynn mabry, and steve scales) in attendance. [PER]ynn and ednah joined us and did laps around the audience. [PER]a weymouth gave me a near empty glass of champagne and said my suit was nice. i took two gummies and drank a grapefruit radler. vidiots cofounder saw me hitting the choreo and asked “how many times have you…',
#  'A polite man is driven to murder. He becomes a prophet and screams manifestos on love, war, and the increasingly alarming impact of technology and progress. Driven to insanity by his own insights into the human condition, he travels to a river in an attempt to drown himself but instead is baptized and absolved of sin. He dies, crosseyed yet painless.This is the definitive fairytale of my generation, and the moral is "watch out, you might get what you\'re after". [PER] lives, and he\'s wearing a giant suit.',
#  'me::(da[PER] byrne:*gets on stage wearing the big suit*me::)',
#  'ME: oh cool, stop making sense is streaming for free with ads. i\'ll put it on while i write2 SONG LATER: i\'m gonna rent it from amazon for a better stream3 SONGS LATER: [screeching "turn like a wheeel inside a wheeel!" as i tap on my keyboard]2 SONGS LATER: i can buy it for cheaper on itunes, but i can watch it on my tv if i do google play hmm3 SONGS LATER: [dancing around the…',
#  'The most joyous film ever made. The little moments where [PER] is trying to perform stone-faced but can\'t help but smile could power me for weeks. Nothing makes me feel so exuberant, happy, nostalgic, and full of love as "[MISC]." It breaks my heart that [ORG] aren\'t friends anymore because more than anything, this movie feels like it works as an ode to/view on their friendship and how they work so perfectly together as…',
#  'A manifesto on how you and your friends (with the help of some instruments, a couple of lights, a few cameras and platforms, a cartoonishly oversized suit and a standard house lamp) can see the face of god. Opens with an anxious man alone in what looks like an abandoned factory hitting play on a tape and within the span of a few songs you are watching a transcendent celebration of pure music and art and collaboration where everyone and…',
#  'Had the pleasure of catching this in [MISC], they’ve done a lot of work in the [MISC]4 remaster to round off any of the rough edges of the original cut. The edit and visuals are much cleaner, had a lot more work done than I was anticipating to help with the overall timing and flow. The colour correction and 4k work really makes the lighting pop. Even utilising completely different takes and extended versions of tracks that I’m fairly certain…',
#  'david byrne looks like oppenheimer?',
#  '100The most persuasive argument for cocaine usage in the whole entire history of anything and everything. Moves like water, vibrates on its own level of existence.',
#  'one of the most profound “oh… igetit” moments of my life',
#  "pretty amazing how this is humanity's greatest achievement",
#  "There's an entire movie happening inside of [PER].",
#  'play that funky music white boy!!!',
#  'Absolutely life-affirming on the big screen.',
#  'I’ve been listening to [MISC] nonstop for the past few months since I did talked about it on the [MISC] podcast (great cast good boys!!!!) and I keep forgetting to log it. So here are a bunch of the very unorganized notes I took from when I last watched it (on the 35th anniversary of the film!!)----------------------------------------–– I’m embarrassed to admit this but… this is the only [PER] movie I have ever seen. Yes,…',
#  'They got the song from [MISC] in this',
#  'I nearly lost my fucking mind watching this movie. A slow, deliberate start becomes nearly an hour of the most infectious, jubilant, ebullient energy you’ll ever experience. “[MISC]friend [MISC] [MISC]” slaps incredibly hard.Greatest concert film ever made, and an incredible monument to artistry, musical charisma, and cocaine.',
#  'Never wanted to be a lamp so bad',
#  'does anybody have any questions?',
#  ':)',
#  "LOVE ME 'TIL MY HEART STOPS!LOVE ME 'TIL I'M DEAD!",
#  'Great as ever. The part where he’s pleasantly surprised that the lamp doesn’t fall over really hit this time around.',
#  'exceeded astronomical expectations',
#  "96/100This was the first movie I ever reviewed, for my high school newspaper at the time of its release. (Alas, the text has been lost.) Wonder which would surprise my 16-year-old self more: that I'd one day become a member of the [ORG], or that I'd one day weep tears of joy ever time I watch[MISC][MISC]? Because [ORG] were a super-cerebral band with a seemingly borderline-autistic frontman, the show's sense of…",
#  'this is who matty healy thinks he is',
#  'This film makes me feel like all my muscles are being suspended like an inch higher than usual and my heart is being pumped full of gold dust',
#  'david and alex dancing during “burning down the house” :)',
#  "Home is where I want to bePick me up and turn me 'roundI feel numb, born with a weak heartI guess I must be having funThe less we say about it, the betterWe'll make it up as we go alongFeet on the ground, head in the skyIt's okay, I know nothing's wrong, nothing.",
#  'watching this ruined my night because from this moment on I now must live with the weight of knowing I’ll never be cooler than [PER] dancing on stage with a lamp to “This Must [MISC] the [MISC]”',
#  "100Theatrical re-release. In-person intro with the legendary [PER]. Those tight close-ups during '[MISC]' are genuinely miraculous. You can try to compare this with other concert films, but [PER]'s film will always win. Every single time.",
#  'rewatched twice in a row and the second time i took notes [ORG]. here\'s what i wrote:• this is just one gal\'s opinion, but cutting "cities" out and leaving "swamp" in was crazy work• j[PER]\'s shoes look at times like his bare feet and it always takes me out• during "burning down the house" i was drumming so hard on my leg with the pen i was holding that it unscrewed without me…',
#  "I'm just so happy",
#  'quirked up white boy with a little bit of swag busts it down sexual style … is he goated with the sauce?',
#  'that’s my big suited serotonin provider',
#  "one of those movies where i'm grateful to my younger self for not getting the dvd from the library so i could see it for the first time like this",
#  'rewatched it last night, (as i have many nights this week, month, year, all in incomplete ways), rewound the vhs tape, watched it again, rewound it one more time, watched the first half again. late summer is typically a melancholy time for me, the past decade’s balmy air streaked with grief. this tape has been a recent comfort during my late night loneliness, like a group of friends to keep me companyit’s hard to imaginethat nothing at allcould be so excitingcould be this much fun',
#  'You think it’s a big suit and then you see it in imax and then wow yeah big suit',
#  "100(35mm)[MISC] #3A coked-out, energized, miraculous face-melter of a communal gathering. Artistry, creativity and movement as one big happy family, collaborative with the void surrounding their band on stage. Track by track, member by member, anxiety is slowly replaced with honest-to-god jubilation; blissful and radiant, searing and uncommonly truthful, startling and grooving. Each space explored, each emotional plateau, and each harmonious movement is uncharted. Even though it's more than 30 years old,[MISC]-…",
#  'Once in a lifetime for so many reasons. How did I get here! Or, well,here(I photographed the band and asked [PER] for his four favourite movies. The rest speaks for itself!)',
#  'my father had an old car. it stunk of a dirty bike and sweat. my friends used to groan whenever he would pick us up from swimming practice and referred to it as the "cow car" (it smelled like a cow... get it). it made hissing noises and the air conditioner never quite worked the way it should.my father and i ran together. it began when i quit the swim team and told him i didn\'t want to be…',
#  'Everyone say thank you A24',
#  'same as it ever was, but better every time',
#  '[MISC][ORG][ORG][ORG][MISC] [ORG]URPHY I FOUND YOUR NEXT OSCAR',
#  "[PER][PER]'s best quality: his wiggles",
#  "Here's the thing with concert documentaries: if you're a fan of the band/artist, it will be an automatic 10. For documentaries like these, your enjoyment is dependent on the music, and musical taste can be very subjective. But there's something special about[MISC][MISC]. Director [PER] actually puts in the effort to make this documentary a work of art rather than simply being a performance recording.The setlist is perfect. It starts slow with just [PER] performing…",
#  'IS [ORG]YR[ORG] THE COOLEST DUDE TO WALK THE PLANET???I had an ear to ear grin the whole time! I was expecting it to be awesome, but it was so much fucking fun!I think there’s something so inspiring about how confident [PER] is in his weirdness. His antics are just off the charts cool. That being said, the backup singers and the rest of the band are amazing dancers and add so much to the feel of…',
#  "100MKE [MISC] [MISC] #3I'll always remember the sight of a small old lady losing her absolute shit at the intro of '[MISC]'. You've never truly seen this movie until you've watched it with a packed auditorium which quickly morphs into a dance party in the aisles. There is no screen. Just pictures and sound. Total, full-fledged masterwork: one for the time capsules.",
#  "hi. i've got a tape i want to play.this feels like magic precisely because there is no magic - the magicians stand open and vulnerable, without curtains or hiding places, looking tiny among the platforms and instruments and construction flotsam in the background. the trick is that there is no trick. there's something very powerful about seeing these big interesting shadows moving across the back wall, then realizing they're made by a dude just walking around with a spotlight.…",
#  "This ain't no party, this ain't no discoThis ain't no fooling aroundNo time for dancing, or lovey doveyI ain't got time for that nowAn utterly hypnotic, frenetic, [MISC]ian, drug-fuelled spiritual communion celebrating artistry and creativity in its purest form. From the comically oversized suits to the pendulum-swinging kneecaps to [PER] running laps around the stage,[MISC]is more than a typical concert film; it is a blisteringly radiant, unrelenting, psychedelic fever dream that is possibly the greatest concert film ever made.[PER] lives and his name is [PER]...but then again, did he dance likethis?",
#  '[PER][PER] byrne dancing around like a pigeon & yelling about the suburbs procures me an insane amount of serotonin',
#  "rewatched in imax!!!! physically could not keep still!!! so many little moments and cuts that i'm obsessed with at this point... watching my vhs tape a lot has deepened my appreciation for it, but seeing it in a packed house felt so electric and joyful. this is kinda what life is all about",
#  "the only reason behind the tiny head and the massive suit is that he's four toddlers stacked on top of each other",
#  "This felt like a once in a lifetime experience in [MISC] that I wouldn't have missed even if a psycho killer was after me. What a day it was.",
#  "There's something about seeing this with a crowd that makes you completely reevaluate every other time you ever saw it. You go through this period of self-reflection, maybe all those times you saw it in your bedroom you were exaggerating about how good it was. Maybe you're just that autistic kid who is too excited about music. But then you look around the packed theatre and see all the smiling faces, trying their best not to jump out of their…",
#  "half-asleep crying watching [PER] playing with the lamp while eating pizza and chicken wings on my 18th birthday. this is the first day of the rest of my life and I've already peaked, its all downhill from here",
#  'he suit too big for he gotdamn body',
#  'I LOVE YOU FATHER AUTISM',
#  "Begins in total silence, and steadily escalates from there to pure celebration. [PER] is a madman, seizing and jolting to and from all corners of the stage, morphing from a nervy introvert to alternate universe evangelist, and is very nearly upstaged by [PER]'s knees.",
#  'hahahahahahahahahahshdhahahah oh nooooooooookay this is a movie friends were often surprised i’d never seen. so for years I stayed intentionally ignorant because I knew, whenever I saw it, I wanted to go in completely cold. And I did that successfully! I knew it was a [ORG] concert film and that was it. Didn’t even know who directed it. Only specific to the film I knew was a big suit would appear at some point. Whatever, my life story…',
#  'cant explain how much serotonin this gives to me',
#  '9 years ago I had a crush on a girl named [PER] and [PER]\'s two favorite bands were [ORG] and...[ORG](!!) I spent a few months listening to nothing but these two equally excellent bands that are the same in every way. Before then my only experience with TH was the forgotten 2000 [MISC] [PER] movieT[MISC]which usesOnce [MISC] [MISC] [MISC]in the trailer. When [PER] sings "This is not my beautiful house! This…',
#  'This is what world peace sounds like.[PER] weir drenched in sweat fucking shredding on [MISC] while the entire band cheers in awe means more to me than the entire [PER] administration',
#  'seeing this in theaters was transcendent.',
#  "If I were [PER]I'd go to galleries and not be too concernedWell I would have a cup of coffeeAnd I'd find my surroundings quite amusing andPeople would ask me which were my favorite paintingsSo I went through a slight [MISC] phase in college. Mock me if you must. Blame my roommate. We were pretentious, precocious sophomores enamored with anything that dealt with death and [PER] and art. Naturally my favorite song on…",
#  "an argument could be made this is the first movie we should send out into space in hopes an advanced alien civilization will find it, where they would see the best of humanity's efforts. operates on an entirely new realm of existence where all get lost in the gravitational pull of [PER][PER] byrne and his suit.",
#  'WHEN HE GIVES THE LAMP A LITTLE KISS... FHGFHFHGHFGEBVWEOUBVUWBIVEWBVIYRBGWEPEGNWNEUGWRBGOBDFVBREONGEOG',
#  "funny how the most exercise i've had in 3 months is jumping around for 88 minutes imagining im david byrne in a big suit",
#  '[PER] will "Stop [MISC] [MISC]",With music and movement so dense.Looking so cute,In an big suit,Making it all feel less tense.',
#  '[PER] [ORG]D[PER][PER] [ORG]D[PER][PER] exploding heads',
#  'Whoa.So cool to see the guy who played [PER]pen[PER]’s first movie.',
#  'Pure joy.',
#  "“We'd like to thank our crew... goodnight.”After being recommended numerous times by different friends to watch[MISC][MISC], I finally decided to watch it tonight and, wow, what an unbelievable musical experience this film is.[MISC]unfolds as an ensemble piece with each musician being introduced as a different character. As each song develops, the cast grows and expands eventually until we have a full band of every instrument imaginable. This is by far the greatest…",
#  'a truly mesmerising experience. desperate to try out some of these moves in the club as soon as possible',
#  'downright religious in [MISC]X. true autistic excellence. only bad thing is that the setlist doesn’t include the best song from [MISC]main In [MISC] ([MISC]) but [MISC] makes up for it. i am going to direct the [MISC] equivalent to this one day just you all wait',
#  'okay so my friend matt told me this story forever ago that i basically never stop thinking about: he was at a wedding up at [LOC] in the woods in [LOC]. a DJ and a dance floor was set up outdoors, and at one point the DJ got on the mic and yelled“Let’s show these trees what humans can do!”anyway, this is what humans can do!!! a towering achievement, an ode to moving around. big demme faces,…',
#  'There was a moment, I think during "[MISC] the [MISC]", when I wrenched my eyes away from the screen for a few seconds and glanced around the cinema and noticed that [PER] had fixed a pair of glow-sticks together and wrapped them around her neck like some kind of chemiluminescent choker, and [PER] seemed to be vibrating in a synesthetic trance, and [PER] and [PER] were leading a posse-wide chant in time to [PER]\'s "oh-ohh" bit like…',
#  "it's like cocomelon for me",
#  'This was more of a “throw on in the background while I’m hanging with friends” watch that turned into “I’m dancing to [MISC] while my friends hang out” watch. Incredible.',
#  '[MISC]And you may ask yourselfWhy is this movie so good?And you ask yourselfDo they ever stop moving?And you may say to yourselfIt’s so simple, yet so enthralling.And you may say to yourself,My God! What have they done!Cinematic Playlist – MusicologyCinematic Time Capsule - 1984 Ranked1984 [LOC].[LOC]. Release Schedule',
#  'if my doctor ever says i only have 88 minutes left to live i know EXACTLY what i’m watching',
#  "You know those lightning-in-a-bottle moments that happen every so often when you're watching a film? The feeling that you've witnessed something so rare, so special, that it takes you to a transcendental plane of consciousness? Well,Stop [MISC] [MISC]is that, non-stop for 88 minutes, and stays that way every time I watch it.I guess my favourite band is [ORG] (boring, I know), but [ORG] is the answer I'm more likely to give if you ask me…",
#  'my cat kept reaching out to touch [PER][PER] by[PER]’s face with his paw. we love the big suited man <3',
#  "My only concert experience was seeing [PER] in my university's gym parking lot.[ORG] starts with [ORG]'s biggest hit, [MISC]. Then, the other band members come in, bringing a different vibe to each song. Each song is a different experience. I caught myself looking up the tracklist to add songs I liked. Not every song was for me; I gravitated to the faster-paced and soulful songs.The camera work is so well done, too! It…",
#  '“Home is where I want to be“an absolutely spectacle. just pure fun. choreographed chaos. stunning visuals, those backdrops were crazy. insane vibes. revolutionary dance music, dance moves, outfits, the big suit are u kidding me. not to mention the white vans, white socks and first suit set up (!!!). just aesthetics, before people had any clue. i’m a much bigger talking heads fan after seeing this, what a unique forward thinking group, who made (psycho) killer music. imax does…',
#  "I was, am and will always be a [ORG], but after this experience (but don't let anyone fool you or tell you otherwise, this is what this is), you can count me as [ORG] fan.Seriously, when I watched that 100% on [ORG] and everyone singing praises to this concert film, I was pretty perplexed, but also intrigued. I've known [ORG] been a pretty popular band andPsych[MISC] [MISC]has been the soundtrack for some legit great and only…",
#  'the happiness i experience while watching this is absolutely astronomical',
#  'The coolest shit maybe ever. Imagine being as happy as [PER] was during “[MISC].” Imagine making both this andT[MISC] [MISC]!!',
#  'a single tear streamed down my face during this must be the place',
#  "Us tall skinny white guys don't have many style icons. [PER] circa 1984 might be as cool as we get.*First of all, the music is great. I don't think I've ever seen a concert film from a musician or band I didn't already like, I wonder how a film like this would play to someone who has no idea who the [ORG] were, or even better, to someone who actively disliked their music.It's built, like all…",
#  '[PER]\'s approach to filming music is a knife-edge balance of procedural mechanics and intimate observation. As he would for [ORG]\'s "[MISC]" video or his later concert docs, [PER] tracks the basic nuts and bolts of making music, here narrativized by the [ORG]\' ingenious conceit of slowly building up from an introduction of [PER]\'s loner ingenuity into the mutant funk outfit that [ORG] became at its peak. The slow accumulation of gear and members around the frontman…',
#  'well i got to meet [PER][PER] byrne and thank him for his art and then i danced with my crush to “this must be the place” so yeah probably best theatrical experience of my life',
#  "The art of performance. It's hard to imagine a better concert film than[MISC]. It is pretty much the ideal version of one, with great music and careful cinematic craftsmanship. There are so many varied stylistic choices, giving each song a unique feel. [PER]'s very physical presence on stage also contributes, producing something different each time. The film is shot so intimately that it feels like a performance for the cameras, though it isn't. The audience is…",
#  'Before settling in to watch the brand new 4K restoration* of [MISC], I dropped by its [MISC] page and was amused by this user review:"Hard to like this "movie" if you don\'t like the music much, because there is no story, no dialogue, just a concert."Aside from giggling at them for complaining that a concert film is a concert film, what struck me on this viewing is how that statement doesn\'t just miss the point, but…',
#  '[ORG] did the impossible, the live music is better than the original. The whole show is insanely fun as it’s filled with tons of energy and dedication. [PER] does a great job at making you feel like you’re in the concert. [PER] is an absolute maniac and a musical genius on stage!It’s easily the best concert film by far!',
#  'best thing ever']

# %% [markdown]
# # Now we try NER Topic Modelling

# %%
df_topics = topic_model(list(chain(*df['NER_reviews'].iloc[:800])))
df_topics.head()
