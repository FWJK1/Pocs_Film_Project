# %%
import pandas as pd
import re
import os 
import ast
from Utility.toolbox import find_repo_root

root = find_repo_root()

# %%
df = pd.read_csv(f"{root}/Data/2020_trope_data/Scraped_Data/NER_parsed_reviews.csv")
df['NER_cleaned_reviews'] = df['NER_cleaned_reviews'].apply(ast.literal_eval)
df['reviews_mash'] = df['NER_cleaned_reviews'].apply(lambda x: '\n'.join(x))
df['length_reviews_mash'] = df['reviews_mash'].apply(len)
print("average length in characters: ", df['length_reviews_mash'].mean())
# Out:
# average length in characters:  24350.100201317717

# %%
df.columns
# Out:
# Index(['letterboxd_search', 'url', 'actors', 'roles', 'studio',
#        'reviews_extracted', 'review_stars', 'review_dates',
#        'letterboxd_directors', 'letterboxd_year', 'letterboxd_rating',
#        'letterboxd_genres', 'NameIMDB', 'IMDB_rating', 'IMDB_ID',
#        'letter_USD_Budget', 'letter_US_Gross', 'letter_WW_Gross',
#        'NER_cleaned_reviews', 'reviews_mash', 'length_reviews_mash'],
#       dtype='object')

# %%
df['reviews_mash'].iloc[0]
# Out:
# 'To the creators of P is for PPPP SCARY!Cmon guys You had one rule, and you couldnt even follow that Here are some Pwords you could have used insteadPathetic, Pleurisy, Pneumonia, Ponderous, Pterodactyl and that just off the top of my head\n26 different shorts and not [ROLE] single good one\nIf youve already seen this, what were your favorites?For everyone else, it anthology time! Wow, 26 stories crammed into [ROLE] single movie makes for [ROLE] more uneven group than the most uneven of anthologies Fear not! I often run random horror shorts and create homemade anthologies, so the random nature ofThe [TITLE] disorientate me Consider this if youre deciding to watch there is [ROLE] dizzying montage of styles including black and white, animated, subtitled, [ROLE]\nGood evening and welcome fellow Children of ChaosSorry, [ROLE] few of these may be fuzzy because I lost my notes But here we go [ROLE] is for [ROLE] Kind of [ROLE] cute little comedy of errors but really nothing great B is for [ROLE] This one was not great, just kind of this anticlimatic nothing of [ROLE] skit [ACTOR] is for Capital [ROLE] Ok so this one is [ROLE] good one and exactly why I dont believe\nAgain, it technically after midnight, but since I started this earlier I am going to count it towards my 31 Days of Horror There is one thing that has always held horror back from shining brightly, and that innovation Horror is [ROLE] tried and true genre that has survived on clichs and endless sequels for decades, with firmly rooted traditions and neverending patterns spawning millions of subpar directtoDVD flicks worthy of the garbage bin That why I likeABCs of\nSpooky [ROLE] Horrorthons Film 9A is for [ROLE] Air ducts are bad news B is for [ROLE] Badgers are bad news [ACTOR] is for Capitol [ROLE] Accusations are bad news D is for Deloused Demonic clown teddy bears are bad news [ROLE] is for [ROLE] Women are bad news F is for [ROLE] Gravity is bad news G is for [ROLE] Old people are bad news H is for Head Games Kissing is bad news I is for [ROLE]\nI absolutely hated the first one with the sole exception of L is for Libido which I love with all of my heart This one is LEAGUES better than the first but still not good or great to me My favorites were D, T, [ROLE] and Z The after credits scene was so great\nThis has such [ROLE] wacky combination of clips it hard to give it one star rating, yet Im not going to go through the effort of rating all 26 because I do not have the time and patience!There is definitely enough variety in this to enjoy hence the 3 stars rather than the 2 1 2 I originally gave it The quick vignettestyle clips mean that there never really the chance to get bored, as before you know it the film as moved on to the next story [ROLE] good combination of gore, humour, wackiness, and anxietyinducing animation\nThis entry is an immense improvement from the first, but there were stillveryfew shorts that I enjoyed Im completely onboard with this premise as [ROLE] whole; one letter is assigned to an intentional director, and then they must choose one word to make their short about It rare that we get to see directors with complete creative control, and I hope this series is continued; especially with most of the shorts giving their full effort in this entry Q,S, andVwere the real standouts for me\nI think anthologies like these are best enjoyed when youre in [ROLE] particular kind of mood, i [ROLE] when your attention span is shot to shit and you dont really feel like committing to anything Calling them stories is [ROLE] bit generous really, more bite sized morsels or as Letterboxd buddy pirateneckbeard referred to them once as Horror dourves! Brilliant Luckily that was exactly the kind of mood I was in so this worked quite well for me although I still\nAbsolute fun The format of the film is such that you have to at least like half the film made as [ROLE] compilation of twenty six films directed by genre directors If you dont you are disagreeing with the sensibi ...

# %%
exploded_genres = df['letterboxd_genres'].explode()
genre_types = exploded_genres.unique().tolist()
print(genre_types)
# Out:
# ["['Horror']", "['History', 'Drama']", "['Drama', 'Romance']", "['Drama', 'Crime', 'Action']", "['Comedy']", "['Drama', 'Action', 'Crime']", "['Science Fiction', 'Comedy', 'Drama']", "['Drama', 'Romance', 'Comedy']", "['TV Movie', 'Thriller']", "['Drama', 'History', 'War']", "['Drama', 'Crime', 'Romance']", "['Documentary']", "['Drama', 'Crime']", "['Horror', 'Comedy']", "['Western']", "['Drama', 'Mystery', 'War', 'Comedy']", "['Documentary', 'Animation']", "['Comedy', 'Animation']", "['Fantasy', 'Action']", "['Drama', 'Fantasy', 'Family']", "['Family', 'TV Movie', 'Drama', 'Fantasy']", "['Fantasy', 'Drama']", "['Family', 'Comedy']", "['Comedy', 'TV Movie']", "['Drama', 'TV Movie']", "['Fantasy', 'Horror']", "['TV Movie', 'Romance']", "['Comedy', 'Family', 'Romance']", "['Science Fiction', 'Crime']", "['Thriller', 'Action', 'Crime']", "['Drama']", "['Drama', 'Family', 'TV Movie']", "['Mystery', 'Science Fiction', 'Horror']", "['Drama', 'Thriller']", "['Fantasy', 'Mystery', 'Horror']", "['Music', 'Comedy']", "['Drama', 'Comedy', 'Romance']", "['Mystery', 'Comedy']", "['Drama', 'Comedy', 'Adventure', 'Fantasy', 'Family']", "['Horror', 'Thriller', 'Comedy']", "['Action', 'Fantasy', 'Adventure']", "['Thriller', 'Horror', 'Fantasy']", "['Mystery', 'Comedy', 'Thriller']", "['Crime', 'Comedy']", "['War', 'Drama']", "['TV Movie', 'Drama']", "['Horror', 'Romance']", "['Fantasy', 'Comedy', 'Adventure', 'Family']", "['Action', 'Thriller']", "['Romance', 'Drama', 'Comedy']", "['Crime', 'Drama']", "['Comedy', 'Crime']", "['Comedy', 'Western']", "['Fantasy', 'Drama', 'War', 'Romance']", "['Crime', 'Thriller', 'Mystery']", "['Comedy', 'Music']", "['Comedy', 'Horror']", "['Thriller', 'Crime', 'Drama']", "['Horror', 'Drama', 'Thriller']", "['Drama', 'Science Fiction', 'Adventure']", "['Fantasy', 'Family', 'Comedy', 'Adventure']", "['Drama', 'Romance', 'Adventure', 'Action']", "['Comedy', 'Drama']", "['Romance', 'Mystery', 'Drama']", "['Comedy', 'Fantasy', 'Romance']", "['Thriller', 'Crime', 'Action', 'Adventure']", "['Comedy', 'War', 'Romance', 'Drama', 'Fantasy']", "['History', 'War', 'Drama']", "['Romance', 'Comedy']", "['Thriller', 'Drama']", "['Western', 'Comedy']", "['Drama', 'Thriller', 'Crime']", "['Thriller', 'Crime', 'Action']", "['Thriller']", "['Comedy', 'Romance', 'Music']", "['Action', 'Drama', 'History']", "['Thriller', 'Fantasy', 'Horror']", "['Horror', 'Thriller']", "['Thriller', 'Horror']", "['Horror', 'Drama']", "['Romance', 'Drama']", "['History', 'Romance', 'Drama']", "['Mystery', 'Thriller', 'Adventure']", "['Crime', 'Thriller', 'Drama']", "['Romance', 'Drama', 'Crime']", "['Drama', 'Comedy', 'Music']", "['Romance', 'Drama', 'Family', 'TV Movie', 'Comedy']", "['Science Fiction', 'Thriller']", "['TV Movie', 'Mystery', 'Horror']", "['Drama', 'Family']", "['Drama', 'History', 'Romance']", "['Horror', 'Thriller', 'Crime']", "['Family', 'Adventure', 'Comedy']", "['Mystery', 'Comedy', 'Crime']", "['Thriller', 'Comedy', 'Crime']", "['Crime', 'Drama', 'Thriller']", "['Comedy', 'Adventure', 'Fantasy', 'Family']", "['Drama', 'Crime', 'Mystery']", "['Science Fiction', 'Action', 'Adventure', 'Thriller']", "['Romance', 'Music', 'Drama']", "['Music', 'Drama', 'Romance']", "['Music', 'Romance', 'Drama']", '[]', "['Mystery', 'Crime', 'Horror', 'Drama']", "['Comedy', 'Romance', 'Drama']", "['Comedy', 'Mystery', 'Drama']", "['Drama', 'Mystery', 'Horror']", "['Family', 'Fantasy', 'Comedy']", "['Drama', 'History', 'Action']", "['Drama', 'Comedy']", "['Comedy', 'Romance']", "['Drama', 'War']", "['Fantasy', 'Action', 'Adventure']", "['Science Fiction', 'Adventure']", "['Drama', 'History']", "['Drama', 'Romance', 'War']", "['Action', 'Adventure', 'Thriller']", "['Drama', 'Thriller', 'Crime', 'Mystery']", "['Action', 'Horror']", "['Science Fiction', 'TV Movie', 'Drama', 'Family']", "['Family', 'Fantasy', 'Adventure', 'Science Fiction']", "['Documentary', 'Crime']", "['Fantasy', 'Romance', 'Drama']", "['Action', 'Drama', 'Thriller']", "['Horror',  ...

# %%
unique_genres = set()
for genre in genre_types:
    unique_genres.update(ast.literal_eval(genre)) 
unique_genres = list(unique_genres)

# %%
from collections import Counter
def text_to_freqdf(text=None, text_file=None, lower_b=True, n_gram=1):
    """
    Strip all the words out of a file and put them into a frequency dataframe.
    By default casts everything to lowercase. Gets it ready for allotaxonometer.

    :param text str: a string with the text.
    :param text_file str:  The path to the text_file. 
    :param lower_b Bool: A boolean indicating whether to preserve case.
                             Enter False if you want to preserve capital versus not. 
    :returns pd.DataFrame: A DataFrame with word frequencies.
    """

    if text:
        if lower_b:
            text = text.lower()
    else:
        if text_file:
            with open(text_file, 'r') as f:
                text = f.read()
            if lower_b:
                text = text.lower()
        else:
            raise ValueError("Input either a string of text or a textfile.")
    
    words = re.findall(r"\b\w+'?\w*\b", text)
    if n_gram == 1:
        df = pd.DataFrame(words, columns=['types'])
        df = df.value_counts()
        df = df.reset_index(name='counts')
        df['probs'] = df['counts'] / df['counts'].sum()
        total_unique = len(df)
        df['total_unique'] = total_unique
        return df
    else:
        bigrams = [f'{words[i]} {words[i+1]}' for i in range(len(words)-1)]
        bigram_counts = Counter(bigrams)
        bigram_df = pd.DataFrame(bigram_counts.items(), columns=['types', 'counts'])
        bigram_df['probs'] = bigram_df['counts'] / bigram_df['counts'].sum()
        bigram_df['total_unique'] = len(bigram_df)
        return bigram_df

# %%
## get genre frequency csvs for all the movies we have so far
genre_types = unique_genres[1:]
for genre in genre_types:
    print(f"starting {genre}")
    gdf  =  df[df['letterboxd_genres'].apply(lambda lst: genre in lst)].copy()
    g_string = gdf['reviews_mash'].str.cat(sep=' ')
    g_string = re.sub(r"\\.\s*", '', g_string)


    g_freq = text_to_freqdf(text=g_string)
    g_freq.to_csv(f'{root}/Data/Subset_Data_NER/Unigrams/genre_freq/{genre}_word_freq.csv', index=False)
    g_freq_short = g_freq.iloc[:10000].copy()
    g_freq_short.to_csv(f'{root}/Data/Subset_Data_NER/Unigrams/genre_freq_short/{genre}_word_freq_short.csv', index=False)
    g_freq_short_trimmed = g_freq.iloc[150:10150].copy()                                                                             
    g_freq_short_trimmed.to_csv(f'{root}/Data/Subset Data/Unigrams/genre_freq_short_trimmed/{genre}_word_freq_short_trimmed.csv', index=False)


    g_freq_b = text_to_freqdf(text=g_string, n_gram=2)
    g_freq_b.to_csv(f'{root}/Data/Subset_Data_NER/Bigrams/genre_freq/{genre}_bi_word_freq.csv', index=False)
    g_freq_b_short = g_freq_b.iloc[:10000].copy()
    g_freq_b_short.to_csv(f'{root}/Data/Subset_Data_NER/Bigrams/genre_freq_short/{genre}_bi_word_freq_short.csv', index=False)
    g_freq_b_short_trimmed = g_freq_b.iloc[150:10150].copy()                                                                             
    g_freq_b_short_trimmed.to_csv(f'{root}/Data/Subset_Data_NER/Bigrams/genre_freq_short_trimmed/{genre}_bi_word_freq_short_trimmed.csv', index=False)
    with open(f"{root}/Data/Subset_Data_NER/genre_text/{genre}_words.txt", 'w') as f:
        f.write(g_string)
# Out:
# starting Fantasy
# starting Adventure
# starting Documentary
# starting TV Movie
# starting Comedy
# starting Animation
# starting Science Fiction
# starting Drama
# starting Thriller
# starting Western
# starting Music
# starting History
# starting Mystery
# starting Family
# starting Horror
# starting Action
# starting Romance
# starting Crime
